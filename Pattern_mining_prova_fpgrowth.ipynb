# %% [markdown]
# Questo codice parte da Pattern_mining_prova_durata_titletype e tenta di dividere i generi quando ne è presente più di uno per uno stesso elemento

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.core.display import display, HTML
# Out:
# C:\Users\tomma\AppData\Local\Temp\ipykernel_19368\2786719680.py:5: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython.display
#   from IPython.core.display import display, HTML

# %%
df = pd.read_csv("train_log.csv")

# %%
df.head()
# Out:
#                              originalTitle  rating  startYear  runtimeMinutes  \
# 0  Neogenic Nightmare Chapter 3: Hydro-Man  (7, 8]       1995              40
# 1                                  Looping  (5, 6]       1982              28
# 2                           Idealnaya para  (5, 6]       1992              92
# 3              MasterChef Celebrity México  (5, 6]       2021              53
# 4                              Seutateueob  (7, 8]       2020              80
#
#    awardWins  numVotes  totalImages  totalVideos  totalCredits  titleType  \
# 0   0.000000  6.659294     0.693147     0.000000            21  tvEpisode
# 1   0.000000  2.484907     0.693147     0.000000             1  videoGame
# 2   0.000000  3.663562     0.693147     0.000000            24      movie
# 3   0.000000  2.772589     3.135494     0.000000            56   tvSeries
# 4   0.693147  9.662625     5.852202     1.098612            47   tvSeries
#
#    AwNmExWins  canHaveEpisodes  isAdult  numRegions countryOfOrigin  \
# 0    0.000000            False    False           1          ['US']
# 1    0.000000            False    False           1         ['XWG']
# 2    0.000000            False    False           1          ['RU']
# 3    0.000000             True    False           1          ['MX']
# 4    0.693147             True    False          32          ['KR']
#
#                        genres  ratingMean  ReviewsTotal
# 0  Action,Adventure,Animation         7.5      0.693147
# 1                      Action         5.5      0.000000
# 2                      Comedy         5.5      0.693147
# 3                  Reality-TV         5.5      0.000000
# 4        Comedy,Drama,Romance         7.5      6.124683

# %%
# Raggruppa i dati per 'titleType' e calcola la durata media
durata_media_per_titletype = df.groupby('titleType')['runtimeMinutes'].mean()

# Mostra il risultato
print(durata_media_per_titletype)
# Out:
# titleType
# movie            92.740797
# short            13.493827
# tvEpisode        40.220651
# tvMiniSeries    124.090909
# tvMovie          81.049822
# tvSeries         50.222818
# tvShort           9.375000
# tvSpecial        82.533784
# video            71.577778
# videoGame        28.000000
# Name: runtimeMinutes, dtype: float64

# %%
count = df['numRegions'].value_counts()
pd.set_option('display.max_rows', None)  # None per mostrare tutte le righe
print(count)
pd.reset_option('display.max_rows')  # Resetta il numero di righe mostrate
# Out:
# numRegions
# 1     9247
# 2     1805
# 3      850
# 7      747
# 4      707
# 5      490
# 6      367
# 8      201
# 9      166
# 10     143
# 12     132
# 11     120
# 13      92
# 14      86
# 15      70
# 16      64
# 19      56
# 17      50
# 20      47
# 21      40
# 18      38
# 23      35
# 22      33
# 25      32
# 27      27
# 24      27
# 26      26
# 31      21
# 29      19
# 32      18
# 28      15
# 30      14
# 36      13
# 33      12
# 34      12
# 35      10
# 45       8
# 41       7
# 46       7
# 43       7
# 40       7
# 37       7
# 44       6
# 39       5
# 54       4
# 47       4
# 52       4
# 42       4
# 49       4
# 48       4
# 51       3
# 56       3
# 38       3
# 57       2
# 69       1
# 53       1
# 58       1
# 62       1
# Name: count, dtype: int64

# %%
# Seleziona le colonne numeriche del DataFrame
numeric_columns = df.select_dtypes(include='number').columns

# Calcola la percentuale di valori 0 per ogni colonna numerica
percent_zero = (df[numeric_columns] == 0).mean() * 100

# Stampa il risultato
print(percent_zero)
# Out:
# startYear          0.000000
# runtimeMinutes     0.006279
# awardWins         88.596546
# numVotes           0.000000
# totalImages       19.529042
# totalVideos       89.996860
# totalCredits       0.000000
# AwNmExWins        87.566719
# numRegions         0.000000
# ratingMean         0.000000
# ReviewsTotal      47.968603
# dtype: float64

# %%
df['rating'].unique()
# Out:
# array(['(7, 8]', '(5, 6]', '(8, 9]', '(6, 7]', '(2, 3]', '(4, 5]',
#        '(9, 10]', '(3, 4]', '(0, 1]', '(1, 2]'], dtype=object)

# %%
# Mappatura degli intervalli in categorie
rating_mapping = {
    '(0, 1]': 'very_low_rated',
    '(1, 2]': 'very_low_rated',
    '(2, 3]': 'very_low_rated',
    '(3, 4]': 'very_low_rated',
    '(4, 5]': 'low_rated',
    '(5, 6]': 'low_rated',
    '(6, 7]': 'good_rated',
    '(7, 8]': 'good_rated',
    '(8, 9]': 'high_rated',
    '(9, 10]': 'high_rated'
}

# Applicare la mappatura
df['rating_group'] = df['rating'].map(rating_mapping)

# %%
# Calcolo del numero di virgole per ogni riga nella colonna 'countryOfOrigin'
df['number_of_countries'] = df['countryOfOrigin'].apply(lambda x: x.count(',')+1)
df['more_than_one_country'] = df['number_of_countries'].apply(lambda x: 1 if x > 1 else 0)

del df['number_of_countries']

surv_dict = {0: "1_country", 1: "more_than_1_country"}
df["more_than_one_country"] = df["more_than_one_country"].map(surv_dict)

df.head()
# Out:
#                              originalTitle  rating  startYear  runtimeMinutes  \
# 0  Neogenic Nightmare Chapter 3: Hydro-Man  (7, 8]       1995              40
# 1                                  Looping  (5, 6]       1982              28
# 2                           Idealnaya para  (5, 6]       1992              92
# 3              MasterChef Celebrity México  (5, 6]       2021              53
# 4                              Seutateueob  (7, 8]       2020              80
#
#    awardWins  numVotes  totalImages  totalVideos  totalCredits  titleType  \
# 0   0.000000  6.659294     0.693147     0.000000            21  tvEpisode
# 1   0.000000  2.484907     0.693147     0.000000             1  videoGame
# 2   0.000000  3.663562     0.693147     0.000000            24      movie
# 3   0.000000  2.772589     3.135494     0.000000            56   tvSeries
# 4   0.693147  9.662625     5.852202     1.098612            47   tvSeries
#
#    AwNmExWins  canHaveEpisodes  isAdult  numRegions countryOfOrigin  \
# 0    0.000000            False    False           1          ['US']
# 1    0.000000            False    False           1         ['XWG']
# 2    0.000000            False    False           1          ['RU']
# 3    0.000000             True    False           1          ['MX']
# 4    0.693147             True    False          32          ['KR']
#
#                        genres  ratingMean  ReviewsTotal rating_group  \
# 0  Action,Adventure,Animation         7.5      0.693147   good_rated
# 1                      Action         5.5      0.000000    low_rated
# 2                      Comedy         5.5      0.693147    low_rated
# 3                  Reality-TV         5.5      0.000000    low_rated
# 4        Comedy,Drama,Romance         7.5      6.124683   good_rated
#
#   more_than_one_country
# 0             1_country
# 1             1_country
# 2             1_country
# 3             1_country
# 4             1_country

# %%
# remove useless variables
column2drop = ["originalTitle", "AwNmExWins", "ratingMean", "totalVideos","rating"]
df.drop(column2drop, axis=1, inplace=True)
df.head()
# Out:
#    startYear  runtimeMinutes  awardWins  numVotes  totalImages  totalCredits  \
# 0       1995              40   0.000000  6.659294     0.693147            21
# 1       1982              28   0.000000  2.484907     0.693147             1
# 2       1992              92   0.000000  3.663562     0.693147            24
# 3       2021              53   0.000000  2.772589     3.135494            56
# 4       2020              80   0.693147  9.662625     5.852202            47
#
#    titleType  canHaveEpisodes  isAdult  numRegions countryOfOrigin  \
# 0  tvEpisode            False    False           1          ['US']
# 1  videoGame            False    False           1         ['XWG']
# 2      movie            False    False           1          ['RU']
# 3   tvSeries             True    False           1          ['MX']
# 4   tvSeries             True    False          32          ['KR']
#
#                        genres  ReviewsTotal rating_group more_than_one_country
# 0  Action,Adventure,Animation      0.693147   good_rated             1_country
# 1                      Action      0.000000    low_rated             1_country
# 2                      Comedy      0.693147    low_rated             1_country
# 3                  Reality-TV      0.000000    low_rated             1_country
# 4        Comedy,Drama,Romance      6.124683   good_rated             1_country

# %%
# mapping = {
#     'short': 'short',
#     'tvShort': 'short',
#     'movie': 'movie',
#     'tvMovie': 'movie',
#     'tvSpecial': 'special',
#     'videogame': 'videogame',
#     'video': 'video',
#     'tvMiniSeries': 'tvseries_related',
#     'tvSeries': 'tvseries_related',
#     'tvEpisode': 'tvseries_related'
# }

# df['grouped_titleType'] = df['titleType'].replace(mapping)
# del df['titleType']

mapping = {
    'short': 'short',
    'tvShort': 'short',
    'movie': 'movie',
    'tvMovie': 'movie',
    'tvSpecial': 'other',
    'videoGame': 'other',
    'video': 'other',
    'tvMiniSeries': 'tvseries_related',
    'tvSeries': 'tvseries_related',
    'tvEpisode': 'tvseries_related'
}

df['grouped_titleType'] = df['titleType'].replace(mapping)
del df['titleType']

# %%
# Raggruppa i dati per 'titleType' e calcola la durata media
durata_media_per_titletype = df.groupby('grouped_titleType')['runtimeMinutes'].mean()

# Mostra il risultato
print(durata_media_per_titletype)
# Out:
# grouped_titleType
# movie               91.135668
# other               64.579505
# short               13.427126
# tvseries_related    45.168365
# Name: runtimeMinutes, dtype: float64

# %%
# Mappare i generi in 4 categorie equilibrate
genre_mapping = {
    'Action': 'genre_Action/Adventure',
    'Adventure': 'genre_Action/Adventure',
    'Thriller': 'genre_Action/Adventure',
    'Sci-Fi': 'genre_Action/Adventure',
    'Horror': 'genre_Action/Adventure',
    'Fantasy': 'genre_Action/Adventure',
    
    'Drama': 'genre_Drama/Crime',
    'Crime': 'genre_Drama/Crime',
    'Mystery': 'genre_Drama/Crime',
    'War': 'genre_Drama/Crime',
    'Film-Noir': 'genre_Drama/Crime',
    
    'Comedy': 'genre_Comedy/Family',
    'Family': 'genre_Comedy/Family',
    'Romance': 'genre_Comedy/Family',
    'Animation': 'genre_Comedy/Family',
    'Musical': 'genre_Comedy/Family',
    'Short': 'genre_Comedy/Family',
    
    'Documentary': 'genre_Doc/Others',
    'Biography': 'genre_Doc/Others',
    'Reality-TV': 'genre_Doc/Others',
    'History': 'genre_Doc/Others',
    'News': 'genre_Doc/Others',
    'Talk-Show': 'genre_Doc/Others',
    'Music': 'genre_Doc/Others',
    'Sport': 'genre_Doc/Others',
    'Game-Show': 'genre_Doc/Others',
    'Western': 'genre_Doc/Others',
    'Adult': 'genre_Doc/Others'
}

# Funzione per mappare i generi in categorie
def map_genres(genres_str, genre_mapping):
    # Split dei generi in una lista (separati da virgola)
    genres = genres_str.split(',')
    
    # Mappiamo ogni genere alla sua categoria (usando la mappatura)
    mapped_genres = set([genre_mapping.get(genre, 'Altro') for genre in genres])
    
    # Uniamo le categorie mappate in una stringa separata da virgola
    return ', '.join(sorted(mapped_genres))

# Applicare la funzione alla colonna 'genres'
df['mapped_genres'] = df['genres'].apply(lambda x: map_genres(x, genre_mapping))

del df['genres']

# Visualizzare il risultato
df.head()
# Out:
#    startYear  runtimeMinutes  awardWins  numVotes  totalImages  totalCredits  \
# 0       1995              40   0.000000  6.659294     0.693147            21
# 1       1982              28   0.000000  2.484907     0.693147             1
# 2       1992              92   0.000000  3.663562     0.693147            24
# 3       2021              53   0.000000  2.772589     3.135494            56
# 4       2020              80   0.693147  9.662625     5.852202            47
#
#    canHaveEpisodes  isAdult  numRegions countryOfOrigin  ReviewsTotal  \
# 0            False    False           1          ['US']      0.693147
# 1            False    False           1         ['XWG']      0.000000
# 2            False    False           1          ['RU']      0.693147
# 3             True    False           1          ['MX']      0.000000
# 4             True    False          32          ['KR']      6.124683
#
#   rating_group more_than_one_country grouped_titleType  \
# 0   good_rated             1_country  tvseries_related
# 1    low_rated             1_country             other
# 2    low_rated             1_country             movie
# 3    low_rated             1_country  tvseries_related
# 4   good_rated             1_country  tvseries_related
#
#                                  mapped_genres
# 0  genre_Action/Adventure, genre_Comedy/Family
# 1                       genre_Action/Adventure
# 2                          genre_Comedy/Family
# 3                             genre_Doc/Others
# 4       genre_Comedy/Family, genre_Drama/Crime

# %%
# Separare i generi e ottenere i generi unici
generi_singoli = df['mapped_genres'].dropna().apply(lambda x: x.split(','))

# Espandere la lista di generi in un'unica lista
tutti_i_generi = [genere.strip() for sublist in generi_singoli for genere in sublist]

# Determinare i generi distinti
generi_distinti = set(tutti_i_generi)

# Contare i generi distinti
numero_generi_distinti = len(generi_distinti)

print(f"I generi distinti sono: {generi_distinti}")
print(f"Il numero di generi distinti è: {numero_generi_distinti}")
# Out:
# I generi distinti sono: {'genre_Drama/Crime', 'genre_Doc/Others', 'genre_Comedy/Family', 'genre_Action/Adventure'}
# Il numero di generi distinti è: 4

# %%
# Contare le occorrenze di ogni genere
conteggio_generi = {genere: tutti_i_generi.count(genere) for genere in generi_distinti}

print("Occorrenze di ogni genere:")
for genere, conteggio in conteggio_generi.items():
    print(f"{genere}: {conteggio}")
# Out:
# Occorrenze di ogni genere:
# genre_Drama/Crime: 6699
# genre_Doc/Others: 4147
# genre_Comedy/Family: 8645
# genre_Action/Adventure: 4440

# %%
# Creare colonne binarie per ogni genere distinto
# for genere in generi_distinti:
#     df[genere] = df['mapped_genres'].apply(lambda x: int(genere in x.split(', ')) if pd.notna(x) else 0)


from sklearn.preprocessing import MultiLabelBinarizer
mlb = MultiLabelBinarizer()
genres_dummies = pd.DataFrame(
    mlb.fit_transform(df['mapped_genres'].apply(lambda x: x.split(', '))),
    columns=mlb.classes_,
    index=df.index
)

del df['mapped_genres']

# Concatenare tutto in un unico DataFrame binarizzato
df = pd.concat([df, genres_dummies], axis=1)



# del df['mapped_genres']

pd.set_option('display.max_columns', None)

# Mostra le prime righe del DataFrame aggiornato
df.head()

# Se vuoi ripristinare le impostazioni originali dopo
# pd.reset_option('display.max_columns')

# Visualizzare il DataFrame aggiornato
#df_train.head()
# Out:
#    startYear  runtimeMinutes  awardWins  numVotes  totalImages  totalCredits  \
# 0       1995              40   0.000000  6.659294     0.693147            21
# 1       1982              28   0.000000  2.484907     0.693147             1
# 2       1992              92   0.000000  3.663562     0.693147            24
# 3       2021              53   0.000000  2.772589     3.135494            56
# 4       2020              80   0.693147  9.662625     5.852202            47
#
#    canHaveEpisodes  isAdult  numRegions countryOfOrigin  ReviewsTotal  \
# 0            False    False           1          ['US']      0.693147
# 1            False    False           1         ['XWG']      0.000000
# 2            False    False           1          ['RU']      0.693147
# 3             True    False           1          ['MX']      0.000000
# 4             True    False          32          ['KR']      6.124683
#
#   rating_group more_than_one_country grouped_titleType  \
# 0   good_rated             1_country  tvseries_related
# 1    low_rated             1_country             other
# 2    low_rated             1_country             movie
# 3    low_rated             1_country  tvseries_related
# 4   good_rated             1_country  tvseries_related
#
#    genre_Action/Adventure  genre_Comedy/Family  genre_Doc/Others  \
# 0                       1                    1                 0
# 1                       1                    0                 0
# 2                       0                    1                 0
# 3                       0                    0                 1
# 4                       0                    1                 0
#
#    genre_Drama/Crime
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  1

# %%
df['number_of_us'] = df['countryOfOrigin'].apply(lambda x: x.count('US'))
df['produced_in_USA'] = df['number_of_us'].apply(lambda x: 1 if x > 0 else 0)
del df['number_of_us']

surv_dict = {0: "Not US", 1: "US"}
df["produced"] = df["produced_in_USA"].map(surv_dict)
del df['countryOfOrigin']
del df["produced_in_USA"]

df.head()
# Out:
#    startYear  runtimeMinutes  awardWins  numVotes  totalImages  totalCredits  \
# 0       1995              40   0.000000  6.659294     0.693147            21
# 1       1982              28   0.000000  2.484907     0.693147             1
# 2       1992              92   0.000000  3.663562     0.693147            24
# 3       2021              53   0.000000  2.772589     3.135494            56
# 4       2020              80   0.693147  9.662625     5.852202            47
#
#    canHaveEpisodes  isAdult  numRegions  ReviewsTotal rating_group  \
# 0            False    False           1      0.693147   good_rated
# 1            False    False           1      0.000000    low_rated
# 2            False    False           1      0.693147    low_rated
# 3             True    False           1      0.000000    low_rated
# 4             True    False          32      6.124683   good_rated
#
#   more_than_one_country grouped_titleType  genre_Action/Adventure  \
# 0             1_country  tvseries_related                       1
# 1             1_country             other                       1
# 2             1_country             movie                       0
# 3             1_country  tvseries_related                       0
# 4             1_country  tvseries_related                       0
#
#    genre_Comedy/Family  genre_Doc/Others  genre_Drama/Crime produced
# 0                    1                 0                  0       US
# 1                    0                 0                  0   Not US
# 2                    1                 0                  0   Not US
# 3                    0                 1                  0   Not US
# 4                    1                 0                  1   Not US

# %%
df["Year_bin"] = pd.cut(df["startYear"], 5)
df["runtime_bin"] = pd.qcut(df["runtimeMinutes"], 4)
df["Votes_bin"] = pd.qcut(df["numVotes"], 4)
#df["Images_bin"] = pd.cut(df["totalImages"], 4)
df["Credits_bin"] = pd.qcut(df["totalCredits"], 4)
#df["regions_bin"] = pd.cut(df["numRegions"], 4)

# df["Videos_bin"] = pd.cut(df["totalVideos"], 4)
# df["Reviews_bin"] = pd.cut(df["ReviewsTotal"], 4)


#IN CASO DI DIVISIONE CON CUT

# # Step 1: Filtrare i valori diversi da 0 per creare intervalli equispaziati
# non_zero_values = df[df["totalImages"] != 0]["totalImages"]

# # Step 2: Creare 3 intervalli equispaziati per i valori non uguali a 0, ottenendo anche i bordi
# intervals, bins = pd.cut(non_zero_values, bins=3, include_lowest=True, retbins=True)

# # Step 3: Creare i bordi finali degli intervalli, includendo 0 nel primo intervallo
# final_bins = [-float('inf'), 0] + list(bins[1:])

# # Step 4: Creare una nuova colonna "totalImages_bin" con i nuovi intervalli
# df["Images_bin"] = pd.cut(df["totalImages"], bins=final_bins)

#IN CASO DI DIVISIONE CON CUT

# Step 1: Separare gli elementi uguali a 1
df["is_one"] = df["numRegions"] == 1

# Step 2: Creare i bin automaticamente con pd.cut per valori > 1
num_bins = 3  # Numero di intervalli da creare
cut_bins = pd.cut(df.loc[~df["is_one"], "numRegions"], bins=num_bins)

# Step 3: Etichettare manualmente la categoria "1"
df["regions_bin"] = pd.cut(
    df["numRegions"],  # Applichiamo pd.cut su tutta la colonna
    bins=[-np.inf, 1] + list(cut_bins.cat.categories.right),  # Aggiungiamo manualmente il primo bin
    labels=["1"] + list(cut_bins.cat.categories),  # Etichetta manuale per la categoria "1"
    include_lowest=True,
)

# Step 4: Rimuovere la colonna temporanea "is_one"
df.drop(columns=["is_one"], inplace=True)

#IN CASO DI DIVISIONE CON QCUT

# Step 1: Filtrare i valori diversi da 0 per creare intervalli basati su quantili
non_zero_values = df[df["totalImages"] != 0]["totalImages"]

# Step 2: Creare 3 intervalli equispaziati per i valori non uguali a 0 usando qcut, ottenendo anche i bordi
intervals, bins = pd.qcut(non_zero_values, q=4, retbins=True, labels=False, duplicates='drop')

# Step 3: Creare i bordi finali degli intervalli, includendo 0 nel primo intervallo
final_bins = [-float('inf'), 0] + list(bins[1:])

# Step 4: Creare una nuova colonna "totalImages_bin" con i nuovi intervalli
df["Images_bin"] = pd.cut(df["totalImages"], bins=final_bins)

df.drop(["startYear", "runtimeMinutes", "awardWins", "numVotes", "totalImages", "totalCredits", "numRegions"], axis=1, inplace=True)
df.head()
# Out:
#    canHaveEpisodes  isAdult  ReviewsTotal rating_group more_than_one_country  \
# 0            False    False      0.693147   good_rated             1_country
# 1            False    False      0.000000    low_rated             1_country
# 2            False    False      0.693147    low_rated             1_country
# 3             True    False      0.000000    low_rated             1_country
# 4             True    False      6.124683   good_rated             1_country
#
#   grouped_titleType  genre_Action/Adventure  genre_Comedy/Family  \
# 0  tvseries_related                       1                    1
# 1             other                       1                    0
# 2             movie                       0                    1
# 3  tvseries_related                       0                    0
# 4  tvseries_related                       0                    1
#
#    genre_Doc/Others  genre_Drama/Crime produced          Year_bin  \
# 0                 0                  0       US  (1994.8, 2024.0]
# 1                 0                  0   Not US  (1965.6, 1994.8]
# 2                 0                  0   Not US  (1965.6, 1994.8]
# 3                 1                  0   Not US  (1994.8, 2024.0]
# 4                 0                  1   Not US  (1994.8, 2024.0]
#
#       runtime_bin                    Votes_bin    Credits_bin  \
# 0    (29.0, 53.0]              (5.056, 13.624]   (17.0, 35.0]
# 1  (-0.001, 29.0]  (1.7910000000000001, 2.773]  (0.999, 17.0]
# 2   (90.0, 570.0]               (2.773, 3.664]   (17.0, 35.0]
# 3    (29.0, 53.0]  (1.7910000000000001, 2.773]   (35.0, 66.0]
# 4    (53.0, 90.0]              (5.056, 13.624]   (35.0, 66.0]
#
#         regions_bin      Images_bin
# 0                 1    (0.0, 1.099]
# 1                 1    (0.0, 1.099]
# 2                 1    (0.0, 1.099]
# 3                 1  (2.197, 8.162]
# 4  (24.333, 46.667]  (2.197, 8.162]

# %%
# df["Year_bin"] = pd.cut(df["startYear"], 5)
# df["runtime_bin"] = pd.qcut(df["runtimeMinutes"], 4)
# df["Votes_bin"] = pd.cut(df["numVotes"], 4)
# df["Images_bin"] = pd.cut(df["totalImages"], 4)
# df["Credits_bin"] = pd.qcut(df["totalCredits"], 4)

# # df["awardWins_bin"] = pd.cut(df["awardWins"], 4)
# # df["Videos_bin"] = pd.cut(df["totalVideos"], 4)
# # df["Reviews_bin"] = pd.cut(df["ReviewsTotal"], 4)

# df.drop(["startYear", "runtimeMinutes", "numVotes", "totalImages", "totalCredits"], axis=1, inplace=True)
# df.head()

# %%
# Per qcut (per le variabili divise con qcut)
print("Intervalli per 'startYear':")
print(df["Year_bin"].unique())  # Mostra gli intervalli
print(df["Year_bin"].value_counts())  # Conta gli elementi per ciascun intervallo

print("\nIntervalli per 'runtimeMinutes':")
print(df["runtime_bin"].unique()) 
print(df["runtime_bin"].value_counts()) 

print("\nIntervalli per 'numVotes':")
print(df["Votes_bin"].unique())
print(df["Votes_bin"].value_counts()) 

print("\nIntervalli per 'totalImages':")
print(df["Images_bin"].unique())
print(df["Images_bin"].value_counts()) 

print("\nIntervalli per 'totalCredits':")
print(df["Credits_bin"].unique())
print(df["Credits_bin"].value_counts()) 

print("\nIntervalli per 'numRegions':")
print(df["regions_bin"].unique())
print(df["regions_bin"].value_counts()) 

# # Per cut (per le variabili divise con cut)
# print("\nIntervalli per 'awardWins':")
# print(df["awardWins_bin"].unique())  # Mostra gli intervalli
# print(df["awardWins_bin"].value_counts())  # Conta gli elementi per ciascun intervallo

# print("\nIntervalli per 'totalVideos':")
# print(df["Videos_bin"].unique())
# print(df["Videos_bin"].value_counts()) 

# print("\nIntervalli per 'ReviewsTotal':")
# print(df["Reviews_bin"].unique())
# print(df["Reviews_bin"].value_counts())
# Out:
# Intervalli per 'startYear':
# [(1994.8, 2024.0], (1965.6, 1994.8], (1936.4, 1965.6], (1877.854, 1907.2], (1907.2, 1936.4]]
# Categories (5, interval[float64, right]): [(1877.854, 1907.2] < (1907.2, 1936.4] < (1936.4, 1965.6] < (1965.6, 1994.8] < (1994.8, 2024.0]]
# Year_bin
# (1994.8, 2024.0]      8791
# (1965.6, 1994.8]      4765
# (1936.4, 1965.6]      1672
# (1907.2, 1936.4]       570
# (1877.854, 1907.2]     127
# Name: count, dtype: int64
#
# Intervalli per 'runtimeMinutes':
# [(29.0, 53.0], (-0.001, 29.0], (90.0, 570.0], (53.0, 90.0]]
# Categories (4, interval[float64, right]): [(-0.001, 29.0] < (29.0, 53.0] < (53.0, 90.0] < (90.0, 570.0]]
# runtime_bin
# (29.0, 53.0]      4242
# (-0.001, 29.0]    4063
# (53.0, 90.0]      3833
# (90.0, 570.0]     3787
# Name: count, dtype: int64
#
# Intervalli per 'numVotes':
# [(5.056, 13.624], (1.7910000000000001, 2.773], (2.773, 3.664], (3.664, 5.056]]
# Categories (4, interval[float64, right]): [(1.7910000000000001, 2.773] < (2.773, 3.664] < (3.664, 5.056] < (5.056, 13.624]]
# Votes_bin
# (1.7910000000000001, 2.773]    4149
# (5.056, 13.624]                3966
# (3.664, 5.056]                 3948
# (2.773, 3.664]                 3862
# Name: count, dtype: int64
#
# Intervalli per 'totalImages':
# [(0.0, 1.099], (2.197, 8.162], (1.099, 2.197], (-inf, 0.0]]
# Categories (4, interval[float64, right]): [(-inf, 0.0] < (0.0, 1.099] < (1.099, 2.197] < (2.197, 8.162]]
# Images_bin
# (0.0, 1.099]      6499
# (1.099, 2.197]    3198
# (2.197, 8.162]    3118
# (-inf, 0.0]       3110
# Name: count, dtype: int64
#
# Intervalli per 'totalCredits':
# [(17.0, 35.0], (0.999, 17.0], (35.0, 66.0], (66.0, 1885.0]]
# Categories (4, interval[float64, right]): [(0.999, 17.0] < (17.0, 35.0] < (35.0, 66.0] < (66.0, 1885.0]]
# Credits_bin
# (0.999, 17.0]     4206
# (66.0, 1885.0]    3972
# (35.0, 66.0]      3940
# (17.0, 35.0]      3807
# Name: count, dtype: int64
#
# Intervalli per 'numRegions':
# ['1', (24.333, 46.667], (1.933, 24.333], (46.667, 69.0]]
# Categories (4, object): ['1' < (1.933, 24.333] < (24.333, 46.667] < (46.667, 69.0]]
# regions_bin
# 1                   9247
# (1.933, 24.333]     6366
# (24.333, 46.667]     280
# (46.667, 69.0]        32
# Name: count, dtype: int64

# %%
# Recuperiamo gli ultimi due intervalli
intervals = df["regions_bin"].cat.categories
last_two_intervals = intervals[-2:]  # Ultimi due intervalli

# Creiamo un nuovo intervallo unito
new_interval = f"({last_two_intervals[0].left}, {last_two_intervals[1].right}]"

# Sostituire i vecchi intervalli con il nuovo intervallo
df["regions_bin"] = df["regions_bin"].replace(
    {last_two_intervals[0]: new_interval, last_two_intervals[1]: new_interval}
)

# Aggiornare le categorie della colonna
new_categories = list(intervals[:-2]) + [new_interval]
df["regions_bin"] = df["regions_bin"].astype("category").cat.set_categories(new_categories)




# 1. Ottenere i primi due intervalli
first_two_intervals = df["Year_bin"].cat.categories[:2]

# 2. Creare il nuovo intervallo unito come oggetto Interval
new_interval = pd.Interval(left=first_two_intervals[0].left, right=first_two_intervals[1].right, closed='right')

# 3. Sostituire i vecchi intervalli con il nuovo intervallo
df["Year_bin"] = df["Year_bin"].replace({
    first_two_intervals[0]: new_interval,
    first_two_intervals[1]: new_interval
})
# Out:
# C:\Users\tomma\AppData\Local\Temp\ipykernel_19368\2904848591.py:9: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df["regions_bin"] = df["regions_bin"].replace(
# C:\Users\tomma\AppData\Local\Temp\ipykernel_19368\2904848591.py:27: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df["Year_bin"] = df["Year_bin"].replace({

# %%
# Per cut (per le variabili divise con cut)
print("\nIntervalli per 'startYear':")
print(df["Year_bin"].unique())  # Mostra gli intervalli
print(df["Year_bin"].value_counts())  # Conta gli elementi per ciascun intervallo

# Per cut (per le variabili divise con cut)
print("\nIntervalli per 'numRegions':")
print(df["regions_bin"].unique())  # Mostra gli intervalli
print(df["regions_bin"].value_counts())  # Conta gli elementi per ciascun intervallo
# Out:
# Intervalli per 'startYear':
# [(1994.8, 2024.0], (1965.6, 1994.8], (1936.4, 1965.6], (1877.854, 1936.4]]
# Categories (4, interval[float64, right]): [(1877.854, 1936.4] < (1936.4, 1965.6] < (1965.6, 1994.8] < (1994.8, 2024.0]]
# Year_bin
# (1994.8, 2024.0]      8791
# (1965.6, 1994.8]      4765
# (1936.4, 1965.6]      1672
# (1877.854, 1936.4]     697
# Name: count, dtype: int64
#
# Intervalli per 'numRegions':
# ['1', '(24.333, 69.0]', (1.933, 24.333]]
# Categories (3, object): ['1' < (1.933, 24.333] < '(24.333, 69.0]']
# regions_bin
# 1                  9247
# (1.933, 24.333]    6366
# (24.333, 69.0]      312
# Name: count, dtype: int64

# %%
# Trasformare le colonne
df['isAdult'] = df['isAdult'].apply(lambda x: 'is_adult' if x else 'no_adult')
df['canHaveEpisodes'] = df['canHaveEpisodes'].apply(lambda x: 'episodes' if x else 'no_episodes')
df['Reviews'] = np.where(df['ReviewsTotal'] == 0, 'Reviews', 'No_reviews')

del df['ReviewsTotal']
# Visualizzare il DataFrame modificato
df.head()
# Out:
#   canHaveEpisodes   isAdult rating_group more_than_one_country  \
# 0     no_episodes  no_adult   good_rated             1_country
# 1     no_episodes  no_adult    low_rated             1_country
# 2     no_episodes  no_adult    low_rated             1_country
# 3        episodes  no_adult    low_rated             1_country
# 4        episodes  no_adult   good_rated             1_country
#
#   grouped_titleType  genre_Action/Adventure  genre_Comedy/Family  \
# 0  tvseries_related                       1                    1
# 1             other                       1                    0
# 2             movie                       0                    1
# 3  tvseries_related                       0                    0
# 4  tvseries_related                       0                    1
#
#    genre_Doc/Others  genre_Drama/Crime produced          Year_bin  \
# 0                 0                  0       US  (1994.8, 2024.0]
# 1                 0                  0   Not US  (1965.6, 1994.8]
# 2                 0                  0   Not US  (1965.6, 1994.8]
# 3                 1                  0   Not US  (1994.8, 2024.0]
# 4                 0                  1   Not US  (1994.8, 2024.0]
#
#       runtime_bin                    Votes_bin    Credits_bin     regions_bin  \
# 0    (29.0, 53.0]              (5.056, 13.624]   (17.0, 35.0]               1
# 1  (-0.001, 29.0]  (1.7910000000000001, 2.773]  (0.999, 17.0]               1
# 2   (90.0, 570.0]               (2.773, 3.664]   (17.0, 35.0]               1
# 3    (29.0, 53.0]  (1.7910000000000001, 2.773]   (35.0, 66.0]               1
# 4    (53.0, 90.0]              (5.056, 13.624]   (35.0, 66.0]  (24.333, 69.0]
#
#        Images_bin     Reviews
# 0    (0.0, 1.099]  No_reviews
# 1    (0.0, 1.099]     Reviews
# 2    (0.0, 1.099]  No_reviews
# 3  (2.197, 8.162]     Reviews
# 4  (2.197, 8.162]  No_reviews

# %%
# df["rating"] = df["rating"].astype(str) + "_rating"
df["regions_bin"] = df["regions_bin"].astype(str) + "_regions"
df["Year_bin"] = df["Year_bin"].astype(str) + "_year"
df["runtime_bin"] = df["runtime_bin"].astype(str) + "_minutes"
df["Votes_bin"] = df["Votes_bin"].astype(str) + "_votes"
df["Images_bin"] = df["Images_bin"].astype(str) + "_images"
df["Credits_bin"] = df["Credits_bin"].astype(str) + "_credits"
# df["awardWins_bin"] = df["awardWins_bin"].astype(str) + "awards"
#df["Videos_bin"] = df["Videos_bin"].astype(str) + "_votes"
#df["Reviews_bin"] = df["Reviews_bin"].astype(str) + "_reviews"

df.head()
# Out:
#   canHaveEpisodes   isAdult rating_group more_than_one_country  \
# 0     no_episodes  no_adult   good_rated             1_country
# 1     no_episodes  no_adult    low_rated             1_country
# 2     no_episodes  no_adult    low_rated             1_country
# 3        episodes  no_adult    low_rated             1_country
# 4        episodes  no_adult   good_rated             1_country
#
#   grouped_titleType  genre_Action/Adventure  genre_Comedy/Family  \
# 0  tvseries_related                       1                    1
# 1             other                       1                    0
# 2             movie                       0                    1
# 3  tvseries_related                       0                    0
# 4  tvseries_related                       0                    1
#
#    genre_Doc/Others  genre_Drama/Crime produced               Year_bin  \
# 0                 0                  0       US  (1994.8, 2024.0]_year
# 1                 0                  0   Not US  (1965.6, 1994.8]_year
# 2                 0                  0   Not US  (1965.6, 1994.8]_year
# 3                 1                  0   Not US  (1994.8, 2024.0]_year
# 4                 0                  1   Not US  (1994.8, 2024.0]_year
#
#               runtime_bin                          Votes_bin  \
# 0    (29.0, 53.0]_minutes              (5.056, 13.624]_votes
# 1  (-0.001, 29.0]_minutes  (1.7910000000000001, 2.773]_votes
# 2   (90.0, 570.0]_minutes               (2.773, 3.664]_votes
# 3    (29.0, 53.0]_minutes  (1.7910000000000001, 2.773]_votes
# 4    (53.0, 90.0]_minutes              (5.056, 13.624]_votes
#
#              Credits_bin             regions_bin             Images_bin  \
# 0   (17.0, 35.0]_credits               1_regions    (0.0, 1.099]_images
# 1  (0.999, 17.0]_credits               1_regions    (0.0, 1.099]_images
# 2   (17.0, 35.0]_credits               1_regions    (0.0, 1.099]_images
# 3   (35.0, 66.0]_credits               1_regions  (2.197, 8.162]_images
# 4   (35.0, 66.0]_credits  (24.333, 69.0]_regions  (2.197, 8.162]_images
#
#       Reviews
# 0  No_reviews
# 1     Reviews
# 2  No_reviews
# 3     Reviews
# 4  No_reviews

# %%
# X = df.values.tolist()

# Trasforma ogni riga in una transazione
X = df.apply(
    lambda row: [
        row['canHaveEpisodes'],
        row['isAdult'],
        row['rating_group'],
        row['more_than_one_country'],
        row['grouped_titleType'],
        row['produced'],
        row['Year_bin'],
        row['runtime_bin'],
        row['Votes_bin'],
        row['Credits_bin'],
        row['regions_bin'],
        row['Images_bin'],
        row['Reviews'],
        *[col for col in genres_dummies.columns if row[col] == 1]  # Generi attivi
    ], axis=1
).tolist()

# %%
X[0]
# Out:
# ['no_episodes',
#  'no_adult',
#  'good_rated',
#  '1_country',
#  'tvseries_related',
#  'US',
#  '(1994.8, 2024.0]_year',
#  '(29.0, 53.0]_minutes',
#  '(5.056, 13.624]_votes',
#  '(17.0, 35.0]_credits',
#  '1_regions',
#  '(0.0, 1.099]_images',
#  'No_reviews',
#  'genre_Action/Adventure',
#  'genre_Comedy/Family']

# %% [markdown]
# # Pattern Mining

# %%
from fim import fpgrowth

# %%
help(fpgrowth)
# Out:
# Help on built-in function fpgrowth in module fim:
#
# fpgrowth(...)
#     fpgrowth (tracts, target='s', supp=10, zmin=1, zmax=None, report='a',
#               eval='x', agg='x', thresh=10, prune=Nobe, algo='s', mode='',
#               border=None)
#     Find frequent item sets with the FP-growth algorithm.
#     tracts  transaction database to mine (mandatory)
#             The database must be an iterable of transactions;
#             each transaction must be an iterable of items;
#             each item must be a hashable object.
#             If the database is a dictionary, the transactions are
#             the keys, the values their (integer) multiplicities.
#     target  type of frequent item sets to find     (default: s)
#             s/a   sets/all   all     frequent item sets
#             c     closed     closed  frequent item sets
#             m     maximal    maximal frequent item sets
#             g     gens       generators
#             r     rules      association rules
#     supp    minimum support of an item set         (default: 10)
#             (positive: percentage, negative: absolute number)
#     conf    minimum confidence of an assoc. rule   (default: 80%)
#     zmin    minimum number of items per item set   (default: 1)
#     zmax    maximum number of items per item set   (default: no limit)
#     report  values to report with an item set      (default: a)
#             a     absolute item set support (number of transactions)
#             s     relative item set support as a fraction
#             S     relative item set support as a percentage
#             e     value of item set evaluation measure
#             E     value of item set evaluation measure as a percentage
#             (     combine values in a tuple (must be first character)
#             [     combine values in a list  (must be first character)
#             #     pattern spectrum as a dictionary  (no patterns)
#             =     pattern spectrum as a list        (no patterns)
#             |     pattern spectrum as three columns (no patterns)
#             for target 'r' (association rules) also available:
#             b     absolute body set  support (number of transactions)
#             x     relative body set  support as a fraction
#             X     relative body set  support as a percentage
#             h     absolute head item support (number of transactions)
#             y     relative head item support as a fraction
#             Y     relative head item support as a percentage
#             c     rule confidence as a fraction
#             C     rule confidence as a percentage
#             l     lift value of a rule (confidence/prior)
#             L     lift value of a rule as a percentage
#             Q     support of the empty set (total number of transactions)
#     eval    measure for item set evaluation        (default: x)
#             x     none       no measure / zero (default)
#             b     ldratio    binary logarithm of support quotient       (+)
#             c     conf       rule confidence                            (+)
#             d     confdiff   absolute confidence difference to prior    (+)
#             l     lift       lift value (confidence divided by prior)   (+)
#             a     liftdiff   absolute difference of lift value to 1     (+)
#             q     liftquot   difference of lift quotient to 1           (+)
#             v     cvct       conviction (inverse lift for negated head) (+)
#             e     cvctdiff   absolute difference of conviction to 1     (+)
#             r     cvctquot   difference of conviction quotient to 1     (+)
#             k     cprob      conditional probability ratio              (+)
#             j     import     importance (binary log. of prob. ratio)    (+)
#             z     cert       certainty factor (relative conf. change)   (+)
#             n     chi2       normalized chi^2 measure                   (+)
#             p     chi2pval   p-value from (unnormalized) chi^2 measure  (-)
#             y     yates      normalized chi^2 with Yates' correction    (+)
#             t     yatespval  p-value from Yates-corrected chi^2 measure (-)
#             i     info       information difference to prior            (+)
#             g     infopval   p-value from G statistic/info. difference  (-)
#             f     fetprob    Fisher's exact test (table probability)    (-)
#             h     fetchi2    Fisher's exact test (chi^2 measure)        (-)
#             m     fetinfo    Fisher's exact test (mutual information)   (-)
#             s     fetsupp    Fisher's exact test (support)              (-)
#             Measures marked with (+) must meet or exceed the threshold,
#             measures marked with (-) must not exceed the threshold
#             in order for the item set to be reported.
#     agg     evaluation measure aggregation mode    (default: x)
#             x     none       no aggregation (use first value)
#             m     min        minimum of individual measure values
#             n     max        maximum of individual measure values
#             a     avg        average of individual measure values
#     thresh  threshold for evaluation measure       (default: 10%)
#     prune   min. size for evaluation filtering     (default: no pruning)
#             = 0   backward filtering       (no subset check)
#             < 0   weak   forward filtering (one subset  must qualify)
#             > 0   strong forward filtering (all subsets must qualify)
#     algo    algorithm variant to use               (default: s)
#             s     simple     simple  tree nodes (only link and parent)
#             c     complex    complex tree nodes (children and siblings)
#             d     single     top-down processing on a single prefix tree
#             t     topdown    top-down processing of the prefix trees
#             Variant d does not support closed/maximal item set mining.
#     mode    operation mode indicators/flags        (default: None)
#             l     do not use a 16-items machine
#             x     do not use perfect extension pruning
#             i     do not sort items w.r.t. conditional support
#             u     do not head union tail (hut) pruning (maximal)
#             z     invalidate evaluation below expected support
#             o     use original rule support definition (body & head)
#     border  support border for filtering item sets (default: None)
#             Must be a list or tuple of (absolute) minimum support values
#             per item set size (by which the list/tuple is indexed).
#     appear  dictionary mapping items to item appearance indicators,
#             with the key None referring to the default item appearance.
#             (If None does not occur as a key or no dictionary is given,
#             the default item appearance indicator is 'both'.)
#             This parameter is only used if the target type is rules.
#             * item may not appear anywhere in a rule:
#               '-', 'n', 'none', 'neither', 'ignore'
#             * item may appear only in rule body/antecedent:
#               'i', 'in', 'inp', 'input', 'b', 'body',
#               'a', 'ante', 'antecedent'
#             * item may appear only in rule head/consequent:
#               'o', 'out',      'output', 'h', 'head',
#               'c', 'cons', 'consequent'
#             * item may appear anywhere in a rule:
#               'io', 'i&o', 'inout', 'in&out', 'bh', 'b&h', 'both'
#     returns if report is not in ['#','=','|']:
#               if the target is association rules:
#                 a list of rules (i.e. tuples with two or more elements),
#                 each consisting of a head/consequent item, a tuple with
#                 a body/antecedent item set, and the values selected by
#                 the parameter 'report', which may be combined into a
#                 tuple or a list if report[0] is '(' or '[', respectively.
#               if the target is a type of item sets:
#                 a list of patterns (i.e. tuples with one or more elements),
#                 each consisting of a tuple with a found frequent item set
#                 and the values selected by the parameter 'report', which
#                 may be combined into a tuple or list if report[0] is '('
#                 or '[', respectively
#             if report in ['#','=','|']:
#               a pattern spectrum as a dictionary mapping pattern sizes
#               to the corresponding occurrence support ranges, as a list
#               of triplets (size, min. support, max. support) or as three
#               columns for sizes and minimum and maximum support values

# %%
# frequent itemset >= min_supp
# closed: an itemset is closed if none of its immediate supersets has the same support as the itemset
# maximal: an itemset is maximal frequent if none of its immediate supersets is frequent

# %% [markdown]
# ### Frequent Itemsets

# %%
# supp = 2  # 2%
supp = 20  # 20%
zmin = 2  # minimum number of items per item set

itemsets = fpgrowth(X, target="s", supp=supp, zmin=zmin, report="S")
#target="s": Indica che vogliamo trovare i frequent itemsets con il supporto minimo indicato. Se fosse impostato a "r", si cercherebbero regole di associaction.
#report="S": Impostando questo parametro su "S", il risultato sarà una lista di itemsets frequenti accompagnata dal loro supporto.

pd.DataFrame(itemsets, columns=["frequent_itemset", "support"])
# Out:
#                         frequent_itemset    support
# 0                  (1_country, no_adult)  90.386185
# 1                (no_episodes, no_adult)  87.987441
# 2     (no_episodes, 1_country, no_adult)  81.594976
# 3               (no_episodes, 1_country)  84.000000
# 4                  (1_regions, no_adult)  56.332810
# ..                                   ...        ...
# 562               (low_rated, 1_country)  21.670330
# 563   (low_rated, no_episodes, no_adult)  21.281005
# 564  (low_rated, no_episodes, 1_country)  20.282575
# 565             (low_rated, no_episodes)  22.266876
# 566    ((1.099, 2.197]_images, no_adult)  20.069074
#
# [567 rows x 2 columns]

# %%
# Definiamo i parametri
zmin = 2  # Minimum number of items per itemset
support_values = range(10, 91, 5)  # Supporto da 20 a 90 con passo 10

# Creiamo un dizionario per memorizzare i risultati
frequent_itemsets_by_support = {}

# Ciclo per generare i frequent itemsets
for supp in support_values:
    itemsets = fpgrowth(X, target="s", supp=supp, zmin=zmin, report="S")
    # Convertiamo in DataFrame e salviamo nel dizionario
    frequent_itemsets_by_support[supp] = pd.DataFrame(itemsets, columns=["frequent_itemset", "support"])

# Stampa o esplora i risultati
for supp, dataf in frequent_itemsets_by_support.items():
    print(f"Frequent Itemsets (Support = {supp}%)")
    display(dataf)
    print("-" * 50)
# Out:
# Frequent Itemsets (Support = 10%)
#                                     frequent_itemset    support
# 0                              (1_country, no_adult)  90.386185
# 1                            (no_episodes, no_adult)  87.987441
# 2                 (no_episodes, 1_country, no_adult)  81.594976
# 3                           (no_episodes, 1_country)  84.000000
# 4                              (1_regions, no_adult)  56.332810
# ...                                              ...        ...
# 3542    ((1936.4, 1965.6]_year, 1_country, no_adult)  10.047096
# 3543              ((1936.4, 1965.6]_year, 1_country)  10.047096
# 3544  ((1936.4, 1965.6]_year, no_episodes, no_adult)  10.084772
# 3545            ((1936.4, 1965.6]_year, no_episodes)  10.084772
# 3546               ((1936.4, 1965.6]_year, no_adult)  10.499215
#
# [3547 rows x 2 columns]
# --------------------------------------------------
# Frequent Itemsets (Support = 15%)
#                                          frequent_itemset    support
# 0                                   (1_country, no_adult)  90.386185
# 1                                 (no_episodes, no_adult)  87.987441
# 2                      (no_episodes, 1_country, no_adult)  81.594976
# 3                                (no_episodes, 1_country)  84.000000
# 4                                   (1_regions, no_adult)  56.332810
# ...                                                   ...        ...
# 1155  (short, genre_Comedy/Family, no_adult, no_episodes)  15.177394
# 1156               (short, genre_Comedy/Family, no_adult)  15.177394
# 1157            (short, genre_Comedy/Family, no_episodes)  15.196232
# 1158                         (short, genre_Comedy/Family)  15.196232
# 1159                                 (short, no_episodes)  15.510204
#
# [1160 rows x 2 columns]
# --------------------------------------------------
# Frequent Itemsets (Support = 20%)
#                         frequent_itemset    support
# 0                  (1_country, no_adult)  90.386185
# 1                (no_episodes, no_adult)  87.987441
# 2     (no_episodes, 1_country, no_adult)  81.594976
# 3               (no_episodes, 1_country)  84.000000
# 4                  (1_regions, no_adult)  56.332810
# ..                                   ...        ...
# 562               (low_rated, 1_country)  21.670330
# 563   (low_rated, no_episodes, no_adult)  21.281005
# 564  (low_rated, no_episodes, 1_country)  20.282575
# 565             (low_rated, no_episodes)  22.266876
# 566    ((1.099, 2.197]_images, no_adult)  20.069074
#
# [567 rows x 2 columns]
# --------------------------------------------------
# Frequent Itemsets (Support = 25%)
#                                    frequent_itemset    support
# 0                             (1_country, no_adult)  90.386185
# 1                           (no_episodes, no_adult)  87.987441
# 2                (no_episodes, 1_country, no_adult)  81.594976
# 3                          (no_episodes, 1_country)  84.000000
# 4                             (1_regions, no_adult)  56.332810
# ..                                              ...        ...
# 258     ((29.0, 53.0]_minutes, 1_country, no_adult)  25.262166
# 259               ((29.0, 53.0]_minutes, 1_country)  25.375196
# 260              ((0.999, 17.0]_credits, 1_country)  25.456829
# 261  ((1.7910000000000001, 2.773]_votes, 1_country)  25.092622
# 262              ((-0.001, 29.0]_minutes, no_adult)  25.481947
#
# [263 rows x 2 columns]
# --------------------------------------------------
# Frequent Itemsets (Support = 30%)
#                               frequent_itemset    support
# 0                        (1_country, no_adult)  90.386185
# 1                      (no_episodes, no_adult)  87.987441
# 2           (no_episodes, 1_country, no_adult)  81.594976
# 3                     (no_episodes, 1_country)  84.000000
# 4                        (1_regions, no_adult)  56.332810
# ..                                         ...        ...
# 128  (movie, 1_country, no_adult, no_episodes)  33.412873
# 129               (movie, 1_country, no_adult)  33.412873
# 130            (movie, 1_country, no_episodes)  34.103611
# 131                         (movie, 1_country)  34.103611
# 132                       (movie, no_episodes)  38.555730
#
# [133 rows x 2 columns]
# --------------------------------------------------
# Frequent Itemsets (Support = 35%)
#                            frequent_itemset    support
# 0                     (1_country, no_adult)  90.386185
# 1                   (no_episodes, no_adult)  87.987441
# 2        (no_episodes, 1_country, no_adult)  81.594976
# 3                  (no_episodes, 1_country)  84.000000
# 4                     (1_regions, no_adult)  56.332810
# ..                                      ...        ...
# 75  (tvseries_related, 1_country, no_adult)  36.904239
# 76            (tvseries_related, 1_country)  37.010989
# 77           (movie, no_adult, no_episodes)  37.839874
# 78                        (movie, no_adult)  37.839874
# 79                     (movie, no_episodes)  38.555730
#
# [80 rows x 2 columns]
# --------------------------------------------------
# Frequent Itemsets (Support = 40%)
#                                              frequent_itemset    support
# 0                                       (1_country, no_adult)  90.386185
# 1                                     (no_episodes, no_adult)  87.987441
# 2                          (no_episodes, 1_country, no_adult)  81.594976
# 3                                    (no_episodes, 1_country)  84.000000
# 4                                       (1_regions, no_adult)  56.332810
# 5                            (1_regions, 1_country, no_adult)  54.166405
# 6                                      (1_regions, 1_country)  55.868132
# 7                          (1_regions, no_episodes, no_adult)  52.207221
# 8               (1_regions, no_episodes, 1_country, no_adult)  50.141287
# 9                         (1_regions, no_episodes, 1_country)  51.767661
# 10                                   (1_regions, no_episodes)  53.864992
# 11                                     (good_rated, no_adult)  56.219780
# 12                          (good_rated, 1_country, no_adult)  52.144427
# 13                                    (good_rated, 1_country)  53.318681
# 14                        (good_rated, no_episodes, no_adult)  50.499215
# 15             (good_rated, no_episodes, 1_country, no_adult)  46.850863
# 16                       (good_rated, no_episodes, 1_country)  48.006279
# 17                                  (good_rated, no_episodes)  51.692308
# 18                                         (Not US, no_adult)  55.277865
# 19                              (Not US, 1_country, no_adult)  51.045526
# 20                                        (Not US, 1_country)  51.704867
# 21                            (Not US, no_episodes, no_adult)  48.653061
# 22                 (Not US, no_episodes, 1_country, no_adult)  44.784929
# 23                           (Not US, no_episodes, 1_country)  45.394035
# 24                                      (Not US, no_episodes)  49.306122
# 25                          ((1994.8, 2024.0]_year, no_adult)  53.965463
# 26               ((1994.8, 2024.0]_year, 1_country, no_adult)  49.833595
# 27                         ((1994.8, 2024.0]_year, 1_country)  51.026688
# 28             ((1994.8, 2024.0]_year, no_episodes, no_adult)  47.346939
# 29  ((1994.8, 2024.0]_year, no_episodes, 1_country, no_adult)  43.572998
# 30            ((1994.8, 2024.0]_year, no_episodes, 1_country)  44.671900
# 31                       ((1994.8, 2024.0]_year, no_episodes)  48.489796
# 32                            (genre_Comedy/Family, no_adult)  53.695447
# 33                 (genre_Comedy/Family, 1_country, no_adult)  50.693878
# 34                           (genre_Comedy/Family, 1_country)  51.259027
# 35               (genre_Comedy/Family, no_episodes, no_adult)  49.494505
# 36    (genre_Comedy/Family, no_episodes, 1_country, no_adult)  46.744113
# 37              (genre_Comedy/Family, no_episodes, 1_country)  47.271586
# 38                         (genre_Comedy/Family, no_episodes)  50.047096
# 39                                     (No_reviews, no_adult)  50.461538
# 40                          (No_reviews, 1_country, no_adult)  45.525903
# 41                                    (No_reviews, 1_country)  47.051805
# 42                        (No_reviews, no_episodes, no_adult)  46.040816
# 43             (No_reviews, no_episodes, 1_country, no_adult)  41.576138
# 44                       (No_reviews, no_episodes, 1_country)  43.064364
# 45                                  (No_reviews, no_episodes)  47.572998
# 46                                        (Reviews, no_adult)  46.938776
# 47                             (Reviews, 1_country, no_adult)  44.860283
# 48                                       (Reviews, 1_country)  45.839874
# 49                           (Reviews, no_episodes, no_adult)  41.946625
# 50                (Reviews, no_episodes, 1_country, no_adult)  40.018838
# 51                          (Reviews, no_episodes, 1_country)  40.935636
# 52                                     (Reviews, no_episodes)  42.913658
# 53                                             (US, no_adult)  42.122449
# 54                                            (US, 1_country)  41.186813
# 55                                          (US, no_episodes)  41.180534
# 56                              (genre_Drama/Crime, no_adult)  41.783359
# 57                            ((0.0, 1.099]_images, no_adult)  40.740973
# --------------------------------------------------
# Frequent Itemsets (Support = 45%)
#                                            frequent_itemset    support
# 0                                     (1_country, no_adult)  90.386185
# 1                                   (no_episodes, no_adult)  87.987441
# 2                        (no_episodes, 1_country, no_adult)  81.594976
# 3                                  (no_episodes, 1_country)  84.000000
# 4                                     (1_regions, no_adult)  56.332810
# 5                          (1_regions, 1_country, no_adult)  54.166405
# 6                                    (1_regions, 1_country)  55.868132
# 7                        (1_regions, no_episodes, no_adult)  52.207221
# 8             (1_regions, no_episodes, 1_country, no_adult)  50.141287
# 9                       (1_regions, no_episodes, 1_country)  51.767661
# 10                                 (1_regions, no_episodes)  53.864992
# 11                                   (good_rated, no_adult)  56.219780
# 12                        (good_rated, 1_country, no_adult)  52.144427
# 13                                  (good_rated, 1_country)  53.318681
# 14                      (good_rated, no_episodes, no_adult)  50.499215
# 15           (good_rated, no_episodes, 1_country, no_adult)  46.850863
# 16                     (good_rated, no_episodes, 1_country)  48.006279
# 17                                (good_rated, no_episodes)  51.692308
# 18                                       (Not US, no_adult)  55.277865
# 19                            (Not US, 1_country, no_adult)  51.045526
# 20                                      (Not US, 1_country)  51.704867
# 21                          (Not US, no_episodes, no_adult)  48.653061
# 22                         (Not US, no_episodes, 1_country)  45.394035
# 23                                    (Not US, no_episodes)  49.306122
# 24                        ((1994.8, 2024.0]_year, no_adult)  53.965463
# 25             ((1994.8, 2024.0]_year, 1_country, no_adult)  49.833595
# 26                       ((1994.8, 2024.0]_year, 1_country)  51.026688
# 27           ((1994.8, 2024.0]_year, no_episodes, no_adult)  47.346939
# 28                     ((1994.8, 2024.0]_year, no_episodes)  48.489796
# 29                          (genre_Comedy/Family, no_adult)  53.695447
# 30               (genre_Comedy/Family, 1_country, no_adult)  50.693878
# 31                         (genre_Comedy/Family, 1_country)  51.259027
# 32             (genre_Comedy/Family, no_episodes, no_adult)  49.494505
# 33  (genre_Comedy/Family, no_episodes, 1_country, no_adult)  46.744113
# 34            (genre_Comedy/Family, no_episodes, 1_country)  47.271586
# 35                       (genre_Comedy/Family, no_episodes)  50.047096
# 36                                   (No_reviews, no_adult)  50.461538
# 37                        (No_reviews, 1_country, no_adult)  45.525903
# 38                                  (No_reviews, 1_country)  47.051805
# 39                      (No_reviews, no_episodes, no_adult)  46.040816
# 40                                (No_reviews, no_episodes)  47.572998
# 41                                      (Reviews, no_adult)  46.938776
# 42                                     (Reviews, 1_country)  45.839874
# --------------------------------------------------
# Frequent Itemsets (Support = 50%)
#                                  frequent_itemset    support
# 0                           (1_country, no_adult)  90.386185
# 1                         (no_episodes, no_adult)  87.987441
# 2              (no_episodes, 1_country, no_adult)  81.594976
# 3                        (no_episodes, 1_country)  84.000000
# 4                           (1_regions, no_adult)  56.332810
# 5                (1_regions, 1_country, no_adult)  54.166405
# 6                          (1_regions, 1_country)  55.868132
# 7              (1_regions, no_episodes, no_adult)  52.207221
# 8   (1_regions, no_episodes, 1_country, no_adult)  50.141287
# 9             (1_regions, no_episodes, 1_country)  51.767661
# 10                       (1_regions, no_episodes)  53.864992
# 11                         (good_rated, no_adult)  56.219780
# 12              (good_rated, 1_country, no_adult)  52.144427
# 13                        (good_rated, 1_country)  53.318681
# 14            (good_rated, no_episodes, no_adult)  50.499215
# 15                      (good_rated, no_episodes)  51.692308
# 16                             (Not US, no_adult)  55.277865
# 17                  (Not US, 1_country, no_adult)  51.045526
# 18                            (Not US, 1_country)  51.704867
# 19              ((1994.8, 2024.0]_year, no_adult)  53.965463
# 20             ((1994.8, 2024.0]_year, 1_country)  51.026688
# 21                (genre_Comedy/Family, no_adult)  53.695447
# 22     (genre_Comedy/Family, 1_country, no_adult)  50.693878
# 23               (genre_Comedy/Family, 1_country)  51.259027
# 24             (genre_Comedy/Family, no_episodes)  50.047096
# 25                         (No_reviews, no_adult)  50.461538
# --------------------------------------------------
# Frequent Itemsets (Support = 55%)
#                      frequent_itemset    support
# 0               (1_country, no_adult)  90.386185
# 1             (no_episodes, no_adult)  87.987441
# 2  (no_episodes, 1_country, no_adult)  81.594976
# 3            (no_episodes, 1_country)  84.000000
# 4               (1_regions, no_adult)  56.332810
# 5              (1_regions, 1_country)  55.868132
# 6              (good_rated, no_adult)  56.219780
# 7                  (Not US, no_adult)  55.277865
# --------------------------------------------------
# Frequent Itemsets (Support = 60%)
#                      frequent_itemset    support
# 0               (1_country, no_adult)  90.386185
# 1             (no_episodes, no_adult)  87.987441
# 2  (no_episodes, 1_country, no_adult)  81.594976
# 3            (no_episodes, 1_country)  84.000000
# --------------------------------------------------
# Frequent Itemsets (Support = 65%)
#                      frequent_itemset    support
# 0               (1_country, no_adult)  90.386185
# 1             (no_episodes, no_adult)  87.987441
# 2  (no_episodes, 1_country, no_adult)  81.594976
# 3            (no_episodes, 1_country)  84.000000
# --------------------------------------------------
# Frequent Itemsets (Support = 70%)
#                      frequent_itemset    support
# 0               (1_country, no_adult)  90.386185
# 1             (no_episodes, no_adult)  87.987441
# 2  (no_episodes, 1_country, no_adult)  81.594976
# 3            (no_episodes, 1_country)  84.000000
# --------------------------------------------------
# Frequent Itemsets (Support = 75%)
#                      frequent_itemset    support
# 0               (1_country, no_adult)  90.386185
# 1             (no_episodes, no_adult)  87.987441
# 2  (no_episodes, 1_country, no_adult)  81.594976
# 3            (no_episodes, 1_country)  84.000000
# --------------------------------------------------
# Frequent Itemsets (Support = 80%)
#                      frequent_itemset    support
# 0               (1_country, no_adult)  90.386185
# 1             (no_episodes, no_adult)  87.987441
# 2  (no_episodes, 1_country, no_adult)  81.594976
# 3            (no_episodes, 1_country)  84.000000
# --------------------------------------------------
# Frequent Itemsets (Support = 85%)
#           frequent_itemset    support
# 0    (1_country, no_adult)  90.386185
# 1  (no_episodes, no_adult)  87.987441
# --------------------------------------------------
# Frequent Itemsets (Support = 90%)
#         frequent_itemset    support
# 0  (1_country, no_adult)  90.386185
# --------------------------------------------------

# %%
# Calcoliamo il numero di frequent itemsets per ciascun supporto
num_itemsets = [len(frequent_itemsets_by_support[supp]) for supp in support_values]

# Creazione del grafico a linee
plt.figure(figsize=(10, 6))
plt.plot(support_values, num_itemsets, marker="o", color="skyblue", linestyle="--", linewidth=2)
plt.xlabel("Support (%)")
plt.ylabel("Number of Frequent Itemsets")
plt.title("Number of Frequent Itemsets by Support")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# ### Closed Itemsets

# %%
# supp = 2  # 2%
supp = 20  # 20%
zmin = 2  # minimum number of items per item set

itemsets = fpgrowth(X, target="c", supp=supp, zmin=zmin, report="S")
pd.DataFrame(itemsets, columns=["closed_itemset", "support"])
# Out:
#                           closed_itemset    support
# 0      ((1.099, 2.197]_images, no_adult)  20.069074
# 1    (low_rated, no_episodes, 1_country)  20.282575
# 2     (low_rated, no_episodes, no_adult)  21.281005
# 3               (low_rated, no_episodes)  22.266876
# 4       (low_rated, 1_country, no_adult)  20.665620
# ..                                   ...        ...
# 543                (1_regions, no_adult)  56.332810
# 544   (no_episodes, 1_country, no_adult)  81.594976
# 545             (no_episodes, 1_country)  84.000000
# 546              (no_episodes, no_adult)  87.987441
# 547                (1_country, no_adult)  90.386185
#
# [548 rows x 2 columns]

# %%
# Definiamo i parametri
zmin = 2  # Minimum number of items per itemset
support_values = range(10, 91, 5)  # Supporto da 20 a 90 con passo 10

# Creiamo un dizionario per memorizzare i risultati
closed_itemsets_by_support = {}

# Ciclo per generare i frequent itemsets
for supp in support_values:
    itemsets = fpgrowth(X, target="c", supp=supp, zmin=zmin, report="S")
    # Convertiamo in DataFrame e salviamo nel dizionario
    closed_itemsets_by_support[supp] = pd.DataFrame(itemsets, columns=["closed_itemset", "support"])

# Stampa o esplora i risultati
for supp, dataf in closed_itemsets_by_support.items():
    print(f"Closed Itemsets (Support = {supp}%)")
    display(dataf)
    print("-" * 50)
# Out:
# Closed Itemsets (Support = 10%)
#                                                 closed_itemset    support
# 0               ((1936.4, 1965.6]_year, no_episodes, no_adult)  10.084772
# 1                 ((1936.4, 1965.6]_year, 1_country, no_adult)  10.047096
# 2                            ((1936.4, 1965.6]_year, no_adult)  10.499215
# 3     (high_rated, (1994.8, 2024.0]_year, 1_country, no_adult)  10.009419
# 4               (high_rated, (1994.8, 2024.0]_year, 1_country)  10.109890
# ...                                                        ...        ...
# 3248                                     (1_regions, no_adult)  56.332810
# 3249                        (no_episodes, 1_country, no_adult)  81.594976
# 3250                                  (no_episodes, 1_country)  84.000000
# 3251                                   (no_episodes, no_adult)  87.987441
# 3252                                     (1_country, no_adult)  90.386185
#
# [3253 rows x 2 columns]
# --------------------------------------------------
# Closed Itemsets (Support = 15%)
#                                            closed_itemset    support
# 0     (short, genre_Comedy/Family, no_adult, no_episodes)  15.177394
# 1               (short, genre_Comedy/Family, no_episodes)  15.196232
# 2                          (short, no_adult, no_episodes)  15.491366
# 3                                    (short, no_episodes)  15.510204
# 4                         ((-inf, 0.0]_images, 1_regions)  15.290424
# ...                                                   ...        ...
# 1093                                (1_regions, no_adult)  56.332810
# 1094                   (no_episodes, 1_country, no_adult)  81.594976
# 1095                             (no_episodes, 1_country)  84.000000
# 1096                              (no_episodes, no_adult)  87.987441
# 1097                                (1_country, no_adult)  90.386185
#
# [1098 rows x 2 columns]
# --------------------------------------------------
# Closed Itemsets (Support = 20%)
#                           closed_itemset    support
# 0      ((1.099, 2.197]_images, no_adult)  20.069074
# 1    (low_rated, no_episodes, 1_country)  20.282575
# 2     (low_rated, no_episodes, no_adult)  21.281005
# 3               (low_rated, no_episodes)  22.266876
# 4       (low_rated, 1_country, no_adult)  20.665620
# ..                                   ...        ...
# 543                (1_regions, no_adult)  56.332810
# 544   (no_episodes, 1_country, no_adult)  81.594976
# 545             (no_episodes, 1_country)  84.000000
# 546              (no_episodes, no_adult)  87.987441
# 547                (1_country, no_adult)  90.386185
#
# [548 rows x 2 columns]
# --------------------------------------------------
# Closed Itemsets (Support = 25%)
#                                      closed_itemset    support
# 0                ((-0.001, 29.0]_minutes, no_adult)  25.481947
# 1    ((1.7910000000000001, 2.773]_votes, 1_country)  25.092622
# 2                ((0.999, 17.0]_credits, 1_country)  25.456829
# 3       ((29.0, 53.0]_minutes, 1_country, no_adult)  25.262166
# 4                 ((29.0, 53.0]_minutes, 1_country)  25.375196
# ..                                              ...        ...
# 252                           (1_regions, no_adult)  56.332810
# 253              (no_episodes, 1_country, no_adult)  81.594976
# 254                        (no_episodes, 1_country)  84.000000
# 255                         (no_episodes, no_adult)  87.987441
# 256                           (1_country, no_adult)  90.386185
#
# [257 rows x 2 columns]
# --------------------------------------------------
# Closed Itemsets (Support = 30%)
#                                 closed_itemset    support
# 0    (movie, 1_country, no_adult, no_episodes)  33.412873
# 1              (movie, 1_country, no_episodes)  34.103611
# 2               (movie, no_adult, no_episodes)  37.839874
# 3                         (movie, no_episodes)  38.555730
# 4      (tvseries_related, 1_regions, no_adult)  30.153846
# ..                                         ...        ...
# 125                      (1_regions, no_adult)  56.332810
# 126         (no_episodes, 1_country, no_adult)  81.594976
# 127                   (no_episodes, 1_country)  84.000000
# 128                    (no_episodes, no_adult)  87.987441
# 129                      (1_country, no_adult)  90.386185
#
# [130 rows x 2 columns]
# --------------------------------------------------
# Closed Itemsets (Support = 35%)
#                              closed_itemset    support
# 0            (movie, no_adult, no_episodes)  37.839874
# 1                      (movie, no_episodes)  38.555730
# 2   (tvseries_related, 1_country, no_adult)  36.904239
# 3             (tvseries_related, 1_country)  37.010989
# 4              (tvseries_related, no_adult)  38.718995
# ..                                      ...        ...
# 74                    (1_regions, no_adult)  56.332810
# 75       (no_episodes, 1_country, no_adult)  81.594976
# 76                 (no_episodes, 1_country)  84.000000
# 77                  (no_episodes, no_adult)  87.987441
# 78                    (1_country, no_adult)  90.386185
#
# [79 rows x 2 columns]
# --------------------------------------------------
# Closed Itemsets (Support = 40%)
#                                                closed_itemset    support
# 0                             ((0.0, 1.099]_images, no_adult)  40.740973
# 1                               (genre_Drama/Crime, no_adult)  41.783359
# 2                                           (US, no_episodes)  41.180534
# 3                                             (US, 1_country)  41.186813
# 4                                              (US, no_adult)  42.122449
# 5                 (Reviews, no_episodes, 1_country, no_adult)  40.018838
# 6                           (Reviews, no_episodes, 1_country)  40.935636
# 7                            (Reviews, no_episodes, no_adult)  41.946625
# 8                                      (Reviews, no_episodes)  42.913658
# 9                              (Reviews, 1_country, no_adult)  44.860283
# 10                                       (Reviews, 1_country)  45.839874
# 11                                        (Reviews, no_adult)  46.938776
# 12             (No_reviews, no_episodes, 1_country, no_adult)  41.576138
# 13                       (No_reviews, no_episodes, 1_country)  43.064364
# 14                        (No_reviews, no_episodes, no_adult)  46.040816
# 15                                  (No_reviews, no_episodes)  47.572998
# 16                          (No_reviews, 1_country, no_adult)  45.525903
# 17                                    (No_reviews, 1_country)  47.051805
# 18                                     (No_reviews, no_adult)  50.461538
# 19    (genre_Comedy/Family, no_episodes, 1_country, no_adult)  46.744113
# 20              (genre_Comedy/Family, no_episodes, 1_country)  47.271586
# 21               (genre_Comedy/Family, no_episodes, no_adult)  49.494505
# 22                         (genre_Comedy/Family, no_episodes)  50.047096
# 23                 (genre_Comedy/Family, 1_country, no_adult)  50.693878
# 24                           (genre_Comedy/Family, 1_country)  51.259027
# 25                            (genre_Comedy/Family, no_adult)  53.695447
# 26  ((1994.8, 2024.0]_year, no_episodes, 1_country, no_adult)  43.572998
# 27            ((1994.8, 2024.0]_year, no_episodes, 1_country)  44.671900
# 28             ((1994.8, 2024.0]_year, no_episodes, no_adult)  47.346939
# 29                       ((1994.8, 2024.0]_year, no_episodes)  48.489796
# 30               ((1994.8, 2024.0]_year, 1_country, no_adult)  49.833595
# 31                         ((1994.8, 2024.0]_year, 1_country)  51.026688
# 32                          ((1994.8, 2024.0]_year, no_adult)  53.965463
# 33                 (Not US, no_episodes, 1_country, no_adult)  44.784929
# 34                           (Not US, no_episodes, 1_country)  45.394035
# 35                            (Not US, no_episodes, no_adult)  48.653061
# 36                                      (Not US, no_episodes)  49.306122
# 37                              (Not US, 1_country, no_adult)  51.045526
# 38                                        (Not US, 1_country)  51.704867
# 39                                         (Not US, no_adult)  55.277865
# 40             (good_rated, no_episodes, 1_country, no_adult)  46.850863
# 41                       (good_rated, no_episodes, 1_country)  48.006279
# 42                        (good_rated, no_episodes, no_adult)  50.499215
# 43                                  (good_rated, no_episodes)  51.692308
# 44                          (good_rated, 1_country, no_adult)  52.144427
# 45                                    (good_rated, 1_country)  53.318681
# 46                                     (good_rated, no_adult)  56.219780
# 47              (1_regions, no_episodes, 1_country, no_adult)  50.141287
# 48                        (1_regions, no_episodes, 1_country)  51.767661
# 49                         (1_regions, no_episodes, no_adult)  52.207221
# 50                                   (1_regions, no_episodes)  53.864992
# 51                           (1_regions, 1_country, no_adult)  54.166405
# 52                                     (1_regions, 1_country)  55.868132
# 53                                      (1_regions, no_adult)  56.332810
# 54                         (no_episodes, 1_country, no_adult)  81.594976
# 55                                   (no_episodes, 1_country)  84.000000
# 56                                    (no_episodes, no_adult)  87.987441
# 57                                      (1_country, no_adult)  90.386185
# --------------------------------------------------
# Closed Itemsets (Support = 45%)
#                                              closed_itemset    support
# 0                                      (Reviews, 1_country)  45.839874
# 1                                       (Reviews, no_adult)  46.938776
# 2                       (No_reviews, no_episodes, no_adult)  46.040816
# 3                                 (No_reviews, no_episodes)  47.572998
# 4                         (No_reviews, 1_country, no_adult)  45.525903
# 5                                   (No_reviews, 1_country)  47.051805
# 6                                    (No_reviews, no_adult)  50.461538
# 7   (genre_Comedy/Family, no_episodes, 1_country, no_adult)  46.744113
# 8             (genre_Comedy/Family, no_episodes, 1_country)  47.271586
# 9              (genre_Comedy/Family, no_episodes, no_adult)  49.494505
# 10                       (genre_Comedy/Family, no_episodes)  50.047096
# 11               (genre_Comedy/Family, 1_country, no_adult)  50.693878
# 12                         (genre_Comedy/Family, 1_country)  51.259027
# 13                          (genre_Comedy/Family, no_adult)  53.695447
# 14           ((1994.8, 2024.0]_year, no_episodes, no_adult)  47.346939
# 15                     ((1994.8, 2024.0]_year, no_episodes)  48.489796
# 16             ((1994.8, 2024.0]_year, 1_country, no_adult)  49.833595
# 17                       ((1994.8, 2024.0]_year, 1_country)  51.026688
# 18                        ((1994.8, 2024.0]_year, no_adult)  53.965463
# 19                         (Not US, no_episodes, 1_country)  45.394035
# 20                          (Not US, no_episodes, no_adult)  48.653061
# 21                                    (Not US, no_episodes)  49.306122
# 22                            (Not US, 1_country, no_adult)  51.045526
# 23                                      (Not US, 1_country)  51.704867
# 24                                       (Not US, no_adult)  55.277865
# 25           (good_rated, no_episodes, 1_country, no_adult)  46.850863
# 26                     (good_rated, no_episodes, 1_country)  48.006279
# 27                      (good_rated, no_episodes, no_adult)  50.499215
# 28                                (good_rated, no_episodes)  51.692308
# 29                        (good_rated, 1_country, no_adult)  52.144427
# 30                                  (good_rated, 1_country)  53.318681
# 31                                   (good_rated, no_adult)  56.219780
# 32            (1_regions, no_episodes, 1_country, no_adult)  50.141287
# 33                      (1_regions, no_episodes, 1_country)  51.767661
# 34                       (1_regions, no_episodes, no_adult)  52.207221
# 35                                 (1_regions, no_episodes)  53.864992
# 36                         (1_regions, 1_country, no_adult)  54.166405
# 37                                   (1_regions, 1_country)  55.868132
# 38                                    (1_regions, no_adult)  56.332810
# 39                       (no_episodes, 1_country, no_adult)  81.594976
# 40                                 (no_episodes, 1_country)  84.000000
# 41                                  (no_episodes, no_adult)  87.987441
# 42                                    (1_country, no_adult)  90.386185
# --------------------------------------------------
# Closed Itemsets (Support = 50%)
#                                    closed_itemset    support
# 0                          (No_reviews, no_adult)  50.461538
# 1              (genre_Comedy/Family, no_episodes)  50.047096
# 2      (genre_Comedy/Family, 1_country, no_adult)  50.693878
# 3                (genre_Comedy/Family, 1_country)  51.259027
# 4                 (genre_Comedy/Family, no_adult)  53.695447
# 5              ((1994.8, 2024.0]_year, 1_country)  51.026688
# 6               ((1994.8, 2024.0]_year, no_adult)  53.965463
# 7                   (Not US, 1_country, no_adult)  51.045526
# 8                             (Not US, 1_country)  51.704867
# 9                              (Not US, no_adult)  55.277865
# 10            (good_rated, no_episodes, no_adult)  50.499215
# 11                      (good_rated, no_episodes)  51.692308
# 12              (good_rated, 1_country, no_adult)  52.144427
# 13                        (good_rated, 1_country)  53.318681
# 14                         (good_rated, no_adult)  56.219780
# 15  (1_regions, no_episodes, 1_country, no_adult)  50.141287
# 16            (1_regions, no_episodes, 1_country)  51.767661
# 17             (1_regions, no_episodes, no_adult)  52.207221
# 18                       (1_regions, no_episodes)  53.864992
# 19               (1_regions, 1_country, no_adult)  54.166405
# 20                         (1_regions, 1_country)  55.868132
# 21                          (1_regions, no_adult)  56.332810
# 22             (no_episodes, 1_country, no_adult)  81.594976
# 23                       (no_episodes, 1_country)  84.000000
# 24                        (no_episodes, no_adult)  87.987441
# 25                          (1_country, no_adult)  90.386185
# --------------------------------------------------
# Closed Itemsets (Support = 55%)
#                        closed_itemset    support
# 0                  (Not US, no_adult)  55.277865
# 1              (good_rated, no_adult)  56.219780
# 2              (1_regions, 1_country)  55.868132
# 3               (1_regions, no_adult)  56.332810
# 4  (no_episodes, 1_country, no_adult)  81.594976
# 5            (no_episodes, 1_country)  84.000000
# 6             (no_episodes, no_adult)  87.987441
# 7               (1_country, no_adult)  90.386185
# --------------------------------------------------
# Closed Itemsets (Support = 60%)
#                        closed_itemset    support
# 0  (no_episodes, 1_country, no_adult)  81.594976
# 1            (no_episodes, 1_country)  84.000000
# 2             (no_episodes, no_adult)  87.987441
# 3               (1_country, no_adult)  90.386185
# --------------------------------------------------
# Closed Itemsets (Support = 65%)
#                        closed_itemset    support
# 0  (no_episodes, 1_country, no_adult)  81.594976
# 1            (no_episodes, 1_country)  84.000000
# 2             (no_episodes, no_adult)  87.987441
# 3               (1_country, no_adult)  90.386185
# --------------------------------------------------
# Closed Itemsets (Support = 70%)
#                        closed_itemset    support
# 0  (no_episodes, 1_country, no_adult)  81.594976
# 1            (no_episodes, 1_country)  84.000000
# 2             (no_episodes, no_adult)  87.987441
# 3               (1_country, no_adult)  90.386185
# --------------------------------------------------
# Closed Itemsets (Support = 75%)
#                        closed_itemset    support
# 0  (no_episodes, 1_country, no_adult)  81.594976
# 1            (no_episodes, 1_country)  84.000000
# 2             (no_episodes, no_adult)  87.987441
# 3               (1_country, no_adult)  90.386185
# --------------------------------------------------
# Closed Itemsets (Support = 80%)
#                        closed_itemset    support
# 0  (no_episodes, 1_country, no_adult)  81.594976
# 1            (no_episodes, 1_country)  84.000000
# 2             (no_episodes, no_adult)  87.987441
# 3               (1_country, no_adult)  90.386185
# --------------------------------------------------
# Closed Itemsets (Support = 85%)
#             closed_itemset    support
# 0  (no_episodes, no_adult)  87.987441
# 1    (1_country, no_adult)  90.386185
# --------------------------------------------------
# Closed Itemsets (Support = 90%)
#           closed_itemset    support
# 0  (1_country, no_adult)  90.386185
# --------------------------------------------------

# %%
# Calcoliamo il numero di frequent itemsets per ciascun supporto
num_itemsets = [len(closed_itemsets_by_support[supp]) for supp in support_values]

# Creazione del grafico a linee
plt.figure(figsize=(10, 6))
plt.plot(support_values, num_itemsets, marker="o", color="skyblue", linestyle="--", linewidth=2)
plt.xlabel("Support (%)")
plt.ylabel("Number of Closed Itemsets")
plt.title("Number of Closed Itemsets by Support")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# ### Maximal Itemsets

# %%
# supp = 2  # 2%
supp = 20  # 20%
zmin = 2  # minimum number of items per item set

itemsets = fpgrowth(X, target="m", supp=supp, zmin=zmin, report="S")
pd.DataFrame(itemsets, columns=["maximal_itemset", "support"])
# Out:
#                                                           maximal_itemset  \
# 0                                       ((1.099, 2.197]_images, no_adult)
# 1                                     (low_rated, no_episodes, 1_country)
# 2                                      (low_rated, no_episodes, no_adult)
# 3                                        (low_rated, 1_country, no_adult)
# 4                   ((90.0, 570.0]_minutes, movie, no_adult, no_episodes)
# ..                                                                    ...
# 87  ((1994.8, 2024.0]_year, good_rated, no_episodes, 1_country, no_adult)
# 88   ((1994.8, 2024.0]_year, 1_regions, no_episodes, 1_country, no_adult)
# 89                 (Not US, good_rated, no_episodes, 1_country, no_adult)
# 90                  (Not US, 1_regions, no_episodes, 1_country, no_adult)
# 91              (good_rated, 1_regions, no_episodes, 1_country, no_adult)
#
#       support
# 0   20.069074
# 1   20.282575
# 2   21.281005
# 3   20.665620
# 4   20.929356
# ..        ...
# 87  24.533752
# 88  29.532182
# 89  25.638932
# 90  24.414443
# 91  29.764521
#
# [92 rows x 2 columns]

# %%
# Definiamo i parametri
zmin = 2  # Minimum number of items per itemset
support_values = range(10, 91, 5)  # Supporto da 20 a 90 con passo 10

# Creiamo un dizionario per memorizzare i risultati
maximal_itemsets_by_support = {}

# Ciclo per generare i frequent itemsets
for supp in support_values:
    itemsets = fpgrowth(X, target="m", supp=supp, zmin=zmin, report="S")
    # Convertiamo in DataFrame e salviamo nel dizionario
    maximal_itemsets_by_support[supp] = pd.DataFrame(itemsets, columns=["maximal_itemset", "support"])

# Stampa o esplora i risultati
for supp, dataf in maximal_itemsets_by_support.items():
    print(f"Maximal Itemsets (Support = {supp}%)")
    display(dataf)
    print("-" * 50)
# Out:
# Maximal Itemsets (Support = 10%)
#                                                                                            maximal_itemset  \
# 0                                                           ((1936.4, 1965.6]_year, no_episodes, no_adult)
# 1                                                             ((1936.4, 1965.6]_year, 1_country, no_adult)
# 2                                                 (high_rated, (1994.8, 2024.0]_year, 1_country, no_adult)
# 3                                                (high_rated, 1_regions, no_episodes, 1_country, no_adult)
# 4                   (short, (-0.001, 29.0]_minutes, genre_Comedy/Family, 1_regions, no_adult, no_episodes)
# ..                                                                                                     ...
# 443  (genre_Comedy/Family, (1994.8, 2024.0]_year, good_rated, 1_regions, no_episodes, 1_country, no_adult)
# 444                            (genre_Comedy/Family, Not US, good_rated, no_episodes, 1_country, no_adult)
# 445                                       ((1994.8, 2024.0]_year, Not US, good_rated, 1_regions, no_adult)
# 446                          ((1994.8, 2024.0]_year, Not US, good_rated, no_episodes, 1_country, no_adult)
# 447                                      (Not US, good_rated, 1_regions, no_episodes, 1_country, no_adult)
#
#        support
# 0    10.084772
# 1    10.047096
# 2    10.009419
# 3    10.235479
# 4    10.241758
# ..         ...
# 443  10.291994
# 444  13.751962
# 445  10.109890
# 446  14.160126
# 447  14.040816
#
# [448 rows x 2 columns]
# --------------------------------------------------
# Maximal Itemsets (Support = 15%)
#                                                                       maximal_itemset  \
# 0                                 (short, genre_Comedy/Family, no_adult, no_episodes)
# 1                                                     ((-inf, 0.0]_images, 1_regions)
# 2                              ((-inf, 0.0]_images, no_episodes, 1_country, no_adult)
# 3                                       ((2.197, 8.162]_images, No_reviews, no_adult)
# 4                                      ((2.197, 8.162]_images, no_episodes, no_adult)
# ..                                                                                ...
# 179                   ((1994.8, 2024.0]_year, Not US, 1_regions, 1_country, no_adult)
# 180                 ((1994.8, 2024.0]_year, Not US, no_episodes, 1_country, no_adult)
# 181  ((1994.8, 2024.0]_year, good_rated, 1_regions, no_episodes, 1_country, no_adult)
# 182                              (Not US, good_rated, 1_regions, 1_country, no_adult)
# 183                            (Not US, good_rated, no_episodes, 1_country, no_adult)
#
#        support
# 0    15.177394
# 1    15.290424
# 2    15.629513
# 3    15.598116
# 4    16.697017
# ..         ...
# 179  16.897959
# 180  24.502355
# 181  17.262166
# 182  15.629513
# 183  25.638932
#
# [184 rows x 2 columns]
# --------------------------------------------------
# Maximal Itemsets (Support = 20%)
#                                                           maximal_itemset  \
# 0                                       ((1.099, 2.197]_images, no_adult)
# 1                                     (low_rated, no_episodes, 1_country)
# 2                                      (low_rated, no_episodes, no_adult)
# 3                                        (low_rated, 1_country, no_adult)
# 4                   ((90.0, 570.0]_minutes, movie, no_adult, no_episodes)
# ..                                                                    ...
# 87  ((1994.8, 2024.0]_year, good_rated, no_episodes, 1_country, no_adult)
# 88   ((1994.8, 2024.0]_year, 1_regions, no_episodes, 1_country, no_adult)
# 89                 (Not US, good_rated, no_episodes, 1_country, no_adult)
# 90                  (Not US, 1_regions, no_episodes, 1_country, no_adult)
# 91              (good_rated, 1_regions, no_episodes, 1_country, no_adult)
#
#       support
# 0   20.069074
# 1   20.282575
# 2   21.281005
# 3   20.665620
# 4   20.929356
# ..        ...
# 87  24.533752
# 88  29.532182
# 89  25.638932
# 90  24.414443
# 91  29.764521
#
# [92 rows x 2 columns]
# --------------------------------------------------
# Maximal Itemsets (Support = 25%)
#                                                          maximal_itemset  \
# 0                                     ((-0.001, 29.0]_minutes, no_adult)
# 1                         ((1.7910000000000001, 2.773]_votes, 1_country)
# 2                                     ((0.999, 17.0]_credits, 1_country)
# 3                            ((29.0, 53.0]_minutes, 1_country, no_adult)
# 4                        (genre_Action/Adventure, no_episodes, no_adult)
# 5                                    (genre_Action/Adventure, 1_country)
# 6                        ((1965.6, 1994.8]_year, no_episodes, 1_country)
# 7                         ((1965.6, 1994.8]_year, no_episodes, no_adult)
# 8                           ((1965.6, 1994.8]_year, 1_country, no_adult)
# 9                          (movie, (1.933, 24.333]_regions, no_episodes)
# 10                                (movie, Not US, no_adult, no_episodes)
# 11                             (movie, 1_country, no_adult, no_episodes)
# 12                              (tvseries_related, good_rated, no_adult)
# 13                  (tvseries_related, 1_regions, no_episodes, no_adult)
# 14                    (tvseries_related, 1_regions, 1_country, no_adult)
# 15                  (tvseries_related, no_episodes, 1_country, no_adult)
# 16                       ((1.933, 24.333]_regions, No_reviews, no_adult)
# 17                           ((1.933, 24.333]_regions, Not US, no_adult)
# 18           ((1.933, 24.333]_regions, no_episodes, 1_country, no_adult)
# 19                 ((0.0, 1.099]_images, 1_regions, 1_country, no_adult)
# 20               ((0.0, 1.099]_images, no_episodes, 1_country, no_adult)
# 21                                 (genre_Drama/Crime, Not US, no_adult)
# 22                             (genre_Drama/Crime, good_rated, no_adult)
# 23                 (genre_Drama/Crime, no_episodes, 1_country, no_adult)
# 24                                         (US, No_reviews, no_episodes)
# 25                                            (US, No_reviews, no_adult)
# 26                                                      (US, good_rated)
# 27                     (US, 1_regions, no_episodes, 1_country, no_adult)
# 28                 (Reviews, genre_Comedy/Family, no_episodes, no_adult)
# 29                   (Reviews, genre_Comedy/Family, 1_country, no_adult)
# 30               (Reviews, (1994.8, 2024.0]_year, no_episodes, no_adult)
# 31                 (Reviews, (1994.8, 2024.0]_year, 1_country, no_adult)
# 32                   (Reviews, Not US, no_episodes, 1_country, no_adult)
# 33                            (Reviews, good_rated, 1_country, no_adult)
# 34                (Reviews, 1_regions, no_episodes, 1_country, no_adult)
# 35                           (No_reviews, genre_Comedy/Family, no_adult)
# 36                         (No_reviews, (1994.8, 2024.0]_year, no_adult)
# 37                                                  (No_reviews, Not US)
# 38                       (No_reviews, good_rated, no_episodes, no_adult)
# 39                         (No_reviews, good_rated, 1_country, no_adult)
# 40                        (No_reviews, no_episodes, 1_country, no_adult)
# 41   (genre_Comedy/Family, (1994.8, 2024.0]_year, no_episodes, no_adult)
# 42     (genre_Comedy/Family, (1994.8, 2024.0]_year, 1_country, no_adult)
# 43                  (genre_Comedy/Family, Not US, no_episodes, no_adult)
# 44                    (genre_Comedy/Family, Not US, 1_country, no_adult)
# 45   (genre_Comedy/Family, good_rated, no_episodes, 1_country, no_adult)
# 46    (genre_Comedy/Family, 1_regions, no_episodes, 1_country, no_adult)
# 47                ((1994.8, 2024.0]_year, Not US, no_episodes, no_adult)
# 48                  ((1994.8, 2024.0]_year, Not US, 1_country, no_adult)
# 49           ((1994.8, 2024.0]_year, good_rated, no_episodes, 1_country)
# 50            ((1994.8, 2024.0]_year, good_rated, no_episodes, no_adult)
# 51              ((1994.8, 2024.0]_year, good_rated, 1_country, no_adult)
# 52  ((1994.8, 2024.0]_year, 1_regions, no_episodes, 1_country, no_adult)
# 53                (Not US, good_rated, no_episodes, 1_country, no_adult)
# 54                            (Not US, 1_regions, no_episodes, no_adult)
# 55                              (Not US, 1_regions, 1_country, no_adult)
# 56             (good_rated, 1_regions, no_episodes, 1_country, no_adult)
#
#       support
# 0   25.481947
# 1   25.092622
# 2   25.456829
# 3   25.262166
# 4   25.952904
# 5   25.262166
# 6   25.375196
# 7   26.178964
# 8   26.197802
# 9   25.205651
# 10  25.902669
# 11  33.412873
# 12  25.915228
# 13  26.028257
# 14  28.948195
# 15  28.113030
# 16  25.689168
# 17  26.398744
# 18  30.342229
# 19  25.676609
# 20  34.963893
# 21  26.605965
# 22  25.243328
# 23  34.781790
# 24  25.105181
# 25  25.594976
# 26  25.312402
# 27  25.726845
# 28  25.927786
# 29  26.901099
# 30  25.042386
# 31  27.434851
# 32  25.237049
# 33  25.412873
# 34  29.381476
# 35  25.651491
# 36  25.255887
# 37  25.180534
# 38  26.599686
# 39  26.731554
# 40  41.576138
# 41  26.141287
# 42  27.145997
# 43  26.235479
# 44  27.516484
# 45  26.756672
# 46  31.208791
# 47  26.568289
# 48  29.029827
# 49  25.167975
# 50  26.662480
# 51  28.138148
# 52  29.532182
# 53  25.638932
# 54  25.362637
# 55  27.315542
# 56  29.764521
# --------------------------------------------------
# Maximal Itemsets (Support = 30%)
#                                                        maximal_itemset  \
# 0                            (movie, 1_country, no_adult, no_episodes)
# 1                              (tvseries_related, 1_regions, no_adult)
# 2                              (tvseries_related, 1_country, no_adult)
# 3          ((1.933, 24.333]_regions, no_episodes, 1_country, no_adult)
# 4              ((0.0, 1.099]_images, no_episodes, 1_country, no_adult)
# 5                (genre_Drama/Crime, no_episodes, 1_country, no_adult)
# 6                               (US, no_episodes, 1_country, no_adult)
# 7                                          (Reviews, Not US, no_adult)
# 8                         (Reviews, 1_regions, no_episodes, 1_country)
# 9                          (Reviews, 1_regions, no_episodes, no_adult)
# 10                           (Reviews, 1_regions, 1_country, no_adult)
# 11                         (Reviews, no_episodes, 1_country, no_adult)
# 12                                            (No_reviews, good_rated)
# 13                      (No_reviews, no_episodes, 1_country, no_adult)
# 14                         (genre_Comedy/Family, good_rated, no_adult)
# 15  (genre_Comedy/Family, 1_regions, no_episodes, 1_country, no_adult)
# 16                           ((1994.8, 2024.0]_year, Not US, no_adult)
# 17                       ((1994.8, 2024.0]_year, good_rated, no_adult)
# 18          ((1994.8, 2024.0]_year, 1_regions, no_episodes, 1_country)
# 19           ((1994.8, 2024.0]_year, 1_regions, no_episodes, no_adult)
# 20             ((1994.8, 2024.0]_year, 1_regions, 1_country, no_adult)
# 21           ((1994.8, 2024.0]_year, no_episodes, 1_country, no_adult)
# 22                                      (Not US, good_rated, no_adult)
# 23                          (Not US, no_episodes, 1_country, no_adult)
# 24                     (good_rated, 1_regions, no_episodes, 1_country)
# 25                      (good_rated, 1_regions, no_episodes, no_adult)
# 26                        (good_rated, 1_regions, 1_country, no_adult)
# 27                      (good_rated, no_episodes, 1_country, no_adult)
#
#       support
# 0   33.412873
# 1   30.153846
# 2   36.904239
# 3   30.342229
# 4   34.963893
# 5   34.781790
# 6   36.810047
# 7   30.411303
# 8   30.028257
# 9   30.530612
# 10  32.313972
# 11  40.018838
# 12  30.323391
# 13  41.576138
# 14  30.963893
# 15  31.208791
# 16  31.290424
# 17  30.492936
# 18  30.335950
# 19  30.932496
# 20  32.295133
# 21  43.572998
# 22  31.886970
# 23  44.784929
# 24  30.574568
# 25  31.095761
# 26  31.918367
# 27  46.850863
# --------------------------------------------------
# Maximal Itemsets (Support = 35%)
#                                               maximal_itemset    support
# 0                              (movie, no_adult, no_episodes)  37.839874
# 1                     (tvseries_related, 1_country, no_adult)  36.904239
# 2                        ((1.933, 24.333]_regions, 1_country)  35.723705
# 3                         ((1.933, 24.333]_regions, no_adult)  39.108320
# 4               ((0.0, 1.099]_images, no_episodes, 1_country)  35.026688
# 5                ((0.0, 1.099]_images, no_episodes, no_adult)  37.186813
# 6                  ((0.0, 1.099]_images, 1_country, no_adult)  38.398744
# 7                 (genre_Drama/Crime, no_episodes, 1_country)  35.026688
# 8                  (genre_Drama/Crime, no_episodes, no_adult)  38.392465
# 9                    (genre_Drama/Crime, 1_country, no_adult)  37.883830
# 10                     (US, no_episodes, 1_country, no_adult)  36.810047
# 11                (Reviews, no_episodes, 1_country, no_adult)  40.018838
# 12             (No_reviews, no_episodes, 1_country, no_adult)  41.576138
# 13    (genre_Comedy/Family, no_episodes, 1_country, no_adult)  46.744113
# 14  ((1994.8, 2024.0]_year, no_episodes, 1_country, no_adult)  43.572998
# 15                 (Not US, no_episodes, 1_country, no_adult)  44.784929
# 16             (good_rated, no_episodes, 1_country, no_adult)  46.850863
# 17              (1_regions, no_episodes, 1_country, no_adult)  50.141287
# --------------------------------------------------
# Maximal Itemsets (Support = 40%)
#                                               maximal_itemset    support
# 0                             ((0.0, 1.099]_images, no_adult)  40.740973
# 1                               (genre_Drama/Crime, no_adult)  41.783359
# 2                                           (US, no_episodes)  41.180534
# 3                                             (US, 1_country)  41.186813
# 4                                              (US, no_adult)  42.122449
# 5                 (Reviews, no_episodes, 1_country, no_adult)  40.018838
# 6              (No_reviews, no_episodes, 1_country, no_adult)  41.576138
# 7     (genre_Comedy/Family, no_episodes, 1_country, no_adult)  46.744113
# 8   ((1994.8, 2024.0]_year, no_episodes, 1_country, no_adult)  43.572998
# 9                  (Not US, no_episodes, 1_country, no_adult)  44.784929
# 10             (good_rated, no_episodes, 1_country, no_adult)  46.850863
# 11              (1_regions, no_episodes, 1_country, no_adult)  50.141287
# --------------------------------------------------
# Maximal Itemsets (Support = 45%)
#                                             maximal_itemset    support
# 0                                      (Reviews, 1_country)  45.839874
# 1                                       (Reviews, no_adult)  46.938776
# 2                       (No_reviews, no_episodes, no_adult)  46.040816
# 3                         (No_reviews, 1_country, no_adult)  45.525903
# 4   (genre_Comedy/Family, no_episodes, 1_country, no_adult)  46.744113
# 5            ((1994.8, 2024.0]_year, no_episodes, no_adult)  47.346939
# 6              ((1994.8, 2024.0]_year, 1_country, no_adult)  49.833595
# 7                          (Not US, no_episodes, 1_country)  45.394035
# 8                           (Not US, no_episodes, no_adult)  48.653061
# 9                             (Not US, 1_country, no_adult)  51.045526
# 10           (good_rated, no_episodes, 1_country, no_adult)  46.850863
# 11            (1_regions, no_episodes, 1_country, no_adult)  50.141287
# --------------------------------------------------
# Maximal Itemsets (Support = 50%)
#                                  maximal_itemset    support
# 0                         (No_reviews, no_adult)  50.461538
# 1             (genre_Comedy/Family, no_episodes)  50.047096
# 2     (genre_Comedy/Family, 1_country, no_adult)  50.693878
# 3             ((1994.8, 2024.0]_year, 1_country)  51.026688
# 4              ((1994.8, 2024.0]_year, no_adult)  53.965463
# 5                  (Not US, 1_country, no_adult)  51.045526
# 6            (good_rated, no_episodes, no_adult)  50.499215
# 7              (good_rated, 1_country, no_adult)  52.144427
# 8  (1_regions, no_episodes, 1_country, no_adult)  50.141287
# --------------------------------------------------
# Maximal Itemsets (Support = 55%)
#                       maximal_itemset    support
# 0                  (Not US, no_adult)  55.277865
# 1              (good_rated, no_adult)  56.219780
# 2              (1_regions, 1_country)  55.868132
# 3               (1_regions, no_adult)  56.332810
# 4  (no_episodes, 1_country, no_adult)  81.594976
# --------------------------------------------------
# Maximal Itemsets (Support = 60%)
#                       maximal_itemset    support
# 0  (no_episodes, 1_country, no_adult)  81.594976
# --------------------------------------------------
# Maximal Itemsets (Support = 65%)
#                       maximal_itemset    support
# 0  (no_episodes, 1_country, no_adult)  81.594976
# --------------------------------------------------
# Maximal Itemsets (Support = 70%)
#                       maximal_itemset    support
# 0  (no_episodes, 1_country, no_adult)  81.594976
# --------------------------------------------------
# Maximal Itemsets (Support = 75%)
#                       maximal_itemset    support
# 0  (no_episodes, 1_country, no_adult)  81.594976
# --------------------------------------------------
# Maximal Itemsets (Support = 80%)
#                       maximal_itemset    support
# 0  (no_episodes, 1_country, no_adult)  81.594976
# --------------------------------------------------
# Maximal Itemsets (Support = 85%)
#            maximal_itemset    support
# 0  (no_episodes, no_adult)  87.987441
# 1    (1_country, no_adult)  90.386185
# --------------------------------------------------
# Maximal Itemsets (Support = 90%)
#          maximal_itemset    support
# 0  (1_country, no_adult)  90.386185
# --------------------------------------------------

# %%
# Calcoliamo il numero di frequent itemsets per ciascun supporto
num_itemsets = [len(maximal_itemsets_by_support[supp]) for supp in support_values]

# Creazione del grafico a linee
plt.figure(figsize=(10, 6))
plt.plot(support_values, num_itemsets, marker="o", color="skyblue", linestyle="--", linewidth=2)
plt.xlabel("Support (%)")
plt.ylabel("Number of Maximal Itemsets")
plt.title("Number of Maximal Itemsets by Support")
plt.grid(True, linestyle="--", alpha=0.7)
plt.show()

# %%
# Definiamo i parametri
# zmin_values = range(2, df.shape[1] + 1) # Minimum number of items per itemset
zmin_values = np.arange(2, df.shape[1] + 1) # Minimum number of items per itemset
supp = 20  # Supporto da 20 a 90 con passo 10

# Creiamo un dizionario per memorizzare i risultati
maximal_itemsets_by_zmin = {}

# Ciclo per generare i frequent itemsets
for zmin in zmin_values:
    itemsets = fpgrowth(X, target="m", supp=supp, zmin=zmin, report="S")
    # Convertiamo in DataFrame e salviamo nel dizionario
    maximal_itemsets_by_zmin[zmin] = pd.DataFrame(itemsets, columns=["maximal_itemset", "support"])

# Stampa o esplora i risultati
for zmin, dataf in maximal_itemsets_by_zmin.items():
    print(f"Maximal Itemsets (Z_min = {zmin})")
    display(dataf)
    print("-" * 50)
# Out:
# Maximal Itemsets (Z_min = 2)
#                                                           maximal_itemset  \
# 0                                       ((1.099, 2.197]_images, no_adult)
# 1                                     (low_rated, no_episodes, 1_country)
# 2                                      (low_rated, no_episodes, no_adult)
# 3                                        (low_rated, 1_country, no_adult)
# 4                   ((90.0, 570.0]_minutes, movie, no_adult, no_episodes)
# ..                                                                    ...
# 87  ((1994.8, 2024.0]_year, good_rated, no_episodes, 1_country, no_adult)
# 88   ((1994.8, 2024.0]_year, 1_regions, no_episodes, 1_country, no_adult)
# 89                 (Not US, good_rated, no_episodes, 1_country, no_adult)
# 90                  (Not US, 1_regions, no_episodes, 1_country, no_adult)
# 91              (good_rated, 1_regions, no_episodes, 1_country, no_adult)
#
#       support
# 0   20.069074
# 1   20.282575
# 2   21.281005
# 3   20.665620
# 4   20.929356
# ..        ...
# 87  24.533752
# 88  29.532182
# 89  25.638932
# 90  24.414443
# 91  29.764521
#
# [92 rows x 2 columns]
# --------------------------------------------------
# Maximal Itemsets (Z_min = 3)
#                                                           maximal_itemset  \
# 0                                     (low_rated, no_episodes, 1_country)
# 1                                      (low_rated, no_episodes, no_adult)
# 2                                        (low_rated, 1_country, no_adult)
# 3                   ((90.0, 570.0]_minutes, movie, no_adult, no_episodes)
# 4                            ((90.0, 570.0]_minutes, 1_country, no_adult)
# ..                                                                    ...
# 86  ((1994.8, 2024.0]_year, good_rated, no_episodes, 1_country, no_adult)
# 87   ((1994.8, 2024.0]_year, 1_regions, no_episodes, 1_country, no_adult)
# 88                 (Not US, good_rated, no_episodes, 1_country, no_adult)
# 89                  (Not US, 1_regions, no_episodes, 1_country, no_adult)
# 90              (good_rated, 1_regions, no_episodes, 1_country, no_adult)
#
#       support
# 0   20.282575
# 1   21.281005
# 2   20.665620
# 3   20.929356
# 4   20.113030
# ..        ...
# 86  24.533752
# 87  29.532182
# 88  25.638932
# 89  24.414443
# 90  29.764521
#
# [91 rows x 2 columns]
# --------------------------------------------------
# Maximal Itemsets (Z_min = 4)
#                                                           maximal_itemset  \
# 0                   ((90.0, 570.0]_minutes, movie, no_adult, no_episodes)
# 1                ((17.0, 35.0]_credits, no_episodes, 1_country, no_adult)
# 2                ((3.664, 5.056]_votes, no_episodes, 1_country, no_adult)
# 3                ((35.0, 66.0]_credits, no_episodes, 1_country, no_adult)
# 4              ((5.056, 13.624]_votes, No_reviews, no_episodes, no_adult)
# ..                                                                    ...
# 65  ((1994.8, 2024.0]_year, good_rated, no_episodes, 1_country, no_adult)
# 66   ((1994.8, 2024.0]_year, 1_regions, no_episodes, 1_country, no_adult)
# 67                 (Not US, good_rated, no_episodes, 1_country, no_adult)
# 68                  (Not US, 1_regions, no_episodes, 1_country, no_adult)
# 69              (good_rated, 1_regions, no_episodes, 1_country, no_adult)
#
#       support
# 0   20.929356
# 1   20.345369
# 2   20.332810
# 3   21.092622
# 4   20.948195
# ..        ...
# 65  24.533752
# 66  29.532182
# 67  25.638932
# 68  24.414443
# 69  29.764521
#
# [70 rows x 2 columns]
# --------------------------------------------------
# Maximal Itemsets (Z_min = 5)
#                                                                     maximal_itemset  \
# 0   ((-0.001, 29.0]_minutes, genre_Comedy/Family, no_episodes, 1_country, no_adult)
# 1                (movie, (1.933, 24.333]_regions, 1_country, no_adult, no_episodes)
# 2                             (movie, No_reviews, 1_country, no_adult, no_episodes)
# 3                                 (movie, Not US, 1_country, no_adult, no_episodes)
# 4                   (tvseries_related, 1_regions, no_episodes, 1_country, no_adult)
# 5               ((1.933, 24.333]_regions, Not US, no_episodes, 1_country, no_adult)
# 6                   ((0.0, 1.099]_images, Not US, no_episodes, 1_country, no_adult)
# 7               ((0.0, 1.099]_images, good_rated, no_episodes, 1_country, no_adult)
# 8                ((0.0, 1.099]_images, 1_regions, no_episodes, 1_country, no_adult)
# 9                 (genre_Drama/Crime, No_reviews, no_episodes, 1_country, no_adult)
# 10                    (genre_Drama/Crime, Not US, no_episodes, 1_country, no_adult)
# 11                (genre_Drama/Crime, good_rated, no_episodes, 1_country, no_adult)
# 12                               (US, No_reviews, no_episodes, 1_country, no_adult)
# 13                      (US, genre_Comedy/Family, no_episodes, 1_country, no_adult)
# 14                               (US, good_rated, no_episodes, 1_country, no_adult)
# 15                                (US, 1_regions, no_episodes, 1_country, no_adult)
# 16                   (Reviews, genre_Comedy/Family, 1_regions, 1_country, no_adult)
# 17                 (Reviews, genre_Comedy/Family, no_episodes, 1_country, no_adult)
# 18                 (Reviews, (1994.8, 2024.0]_year, 1_regions, 1_country, no_adult)
# 19               (Reviews, (1994.8, 2024.0]_year, no_episodes, 1_country, no_adult)
# 20                              (Reviews, Not US, no_episodes, 1_country, no_adult)
# 21                          (Reviews, good_rated, no_episodes, 1_country, no_adult)
# 22                           (Reviews, 1_regions, no_episodes, 1_country, no_adult)
# 23              (No_reviews, genre_Comedy/Family, no_episodes, 1_country, no_adult)
# 24                       (No_reviews, good_rated, no_episodes, 1_country, no_adult)
# 25                        (No_reviews, 1_regions, no_episodes, 1_country, no_adult)
# 26   (genre_Comedy/Family, (1994.8, 2024.0]_year, no_episodes, 1_country, no_adult)
# 27                  (genre_Comedy/Family, Not US, no_episodes, 1_country, no_adult)
# 28              (genre_Comedy/Family, good_rated, no_episodes, 1_country, no_adult)
# 29               (genre_Comedy/Family, 1_regions, no_episodes, 1_country, no_adult)
# 30                ((1994.8, 2024.0]_year, Not US, no_episodes, 1_country, no_adult)
# 31            ((1994.8, 2024.0]_year, good_rated, no_episodes, 1_country, no_adult)
# 32             ((1994.8, 2024.0]_year, 1_regions, no_episodes, 1_country, no_adult)
# 33                           (Not US, good_rated, no_episodes, 1_country, no_adult)
# 34                            (Not US, 1_regions, no_episodes, 1_country, no_adult)
# 35                        (good_rated, 1_regions, no_episodes, 1_country, no_adult)
#
#       support
# 0   21.249608
# 1   21.519623
# 2   20.590267
# 3   22.832025
# 4   24.923077
# 5   20.087912
# 6   20.188383
# 7   20.571429
# 8   23.698587
# 9   20.087912
# 10  21.538462
# 11  20.747253
# 12  22.028257
# 13  22.103611
# 14  21.211931
# 15  25.726845
# 16  20.276295
# 17  24.847724
# 18  20.954474
# 19  23.843014
# 20  25.237049
# 21  22.718995
# 22  29.381476
# 23  21.896389
# 24  24.131868
# 25  20.759812
# 26  24.514914
# 27  24.640502
# 28  26.756672
# 29  31.208791
# 30  24.502355
# 31  24.533752
# 32  29.532182
# 33  25.638932
# 34  24.414443
# 35  29.764521
# --------------------------------------------------
# Maximal Itemsets (Z_min = 6)
# Empty DataFrame
# Columns: [maximal_itemset, support]
# Index: []
# --------------------------------------------------
# Maximal Itemsets (Z_min = 7)
# Empty DataFrame
# Columns: [maximal_itemset, support]
# Index: []
# --------------------------------------------------
# Maximal Itemsets (Z_min = 8)
# Empty DataFrame
# Columns: [maximal_itemset, support]
# Index: []
# --------------------------------------------------
# Maximal Itemsets (Z_min = 9)
# Empty DataFrame
# Columns: [maximal_itemset, support]
# Index: []
# --------------------------------------------------
# Maximal Itemsets (Z_min = 10)
# Empty DataFrame
# Columns: [maximal_itemset, support]
# Index: []
# --------------------------------------------------
# Maximal Itemsets (Z_min = 11)
# Empty DataFrame
# Columns: [maximal_itemset, support]
# Index: []
# --------------------------------------------------
# Maximal Itemsets (Z_min = 12)
# Empty DataFrame
# Columns: [maximal_itemset, support]
# Index: []
# --------------------------------------------------
# Maximal Itemsets (Z_min = 13)
# Empty DataFrame
# Columns: [maximal_itemset, support]
# Index: []
# --------------------------------------------------
# Maximal Itemsets (Z_min = 14)
# Empty DataFrame
# Columns: [maximal_itemset, support]
# Index: []
# --------------------------------------------------
# Maximal Itemsets (Z_min = 15)
# Empty DataFrame
# Columns: [maximal_itemset, support]
# Index: []
# --------------------------------------------------
# Maximal Itemsets (Z_min = 16)
# Empty DataFrame
# Columns: [maximal_itemset, support]
# Index: []
# --------------------------------------------------
# Maximal Itemsets (Z_min = 17)
# Empty DataFrame
# Columns: [maximal_itemset, support]
# Index: []
# --------------------------------------------------

# %% [markdown]
# ### Support plots

# %% [markdown]
# Support vs number of itemsets

# %%
len_max_it = []
len_cl_it = []
max_supp = 25
zmin=2
for i in range(2, max_supp):
    max_itemsets = fpgrowth(X, target="m", supp=i, zmin=zmin)
    cl_itemsets = fpgrowth(X, target="c", supp=i, zmin=zmin)
    len_max_it.append(len(max_itemsets))
    len_cl_it.append(len(cl_itemsets))

plt.plot(np.arange(2, max_supp), len_max_it, label="maximal")
plt.plot(np.arange(2, max_supp), len_cl_it, label="closed")
plt.legend()
plt.xlabel("%support")
plt.ylabel("itemsets")

plt.show()

# %% [markdown]
# Support vs number of itemsets for genres

# %%
filter_1 = []
filter_2 = []
filter_3 = []
filter_4 = []
# filter_5 = []
for i in range(2, max_supp):
    max_itemsets = fpgrowth(X, target="m", supp=i, zmin=zmin)
    filter_1.append(len([item for item in max_itemsets if "genre_Action/Adventure" in item[0]]))
    filter_2.append(len([item for item in max_itemsets if "genre_Drama/Crime" in item[0]]))
    filter_3.append(len([item for item in max_itemsets if "genre_Comedy/Family" in item[0]]))
    filter_4.append(len([item for item in max_itemsets if "genre_Doc/Others" in item[0]]))
    # filter_5.append(len([item for item in max_itemsets if "Sci-Fi and Fantasy" in item[0]]))

plt.plot(np.arange(2, max_supp), filter_1, label="genre_Action/Adventure")
plt.plot(np.arange(2, max_supp), filter_2, label="genre_Drama/Crime")
plt.plot(np.arange(2, max_supp), filter_3, label="genre_Comedy/Family")
plt.plot(np.arange(2, max_supp), filter_4, label="genre_Doc/Others")
# plt.plot(np.arange(2, max_supp), filter_5, label="Sci-Fi and Fantasy")
plt.legend()
plt.xticks()
plt.xlabel("%support")
plt.ylabel("Maximal itemsets")

plt.show()

# 'Comedy', 'Action and Adventure', 'Other', 'Drama', 'Sci-Fi and Fantasy'

# %% [markdown]
# Support vs number of itemsets for grouped_titleType

# %%
filter_1 = []
filter_2 = []
filter_3 = []
filter_4 = []
# filter_5 = []
for i in range(2, max_supp):
    max_itemsets = fpgrowth(X, target="m", supp=i, zmin=zmin)
    filter_1.append(len([item for item in max_itemsets if "movie" in item[0]]))
    filter_2.append(len([item for item in max_itemsets if "short" in item[0]]))
    filter_3.append(len([item for item in max_itemsets if "tvseries_related" in item[0]]))
    filter_4.append(len([item for item in max_itemsets if "other" in item[0]]))
    # filter_5.append(len([item for item in max_itemsets if "Sci-Fi and Fantasy" in item[0]]))

plt.plot(np.arange(2, max_supp), filter_1, label="movie")
plt.plot(np.arange(2, max_supp), filter_2, label="short")
plt.plot(np.arange(2, max_supp), filter_3, label="tvseries_related")
plt.plot(np.arange(2, max_supp), filter_4, label="other")
# plt.plot(np.arange(2, max_supp), filter_5, label="Sci-Fi and Fantasy")
plt.legend()
plt.xticks()
plt.xlabel("%support")
plt.ylabel("Maximal itemsets")

plt.show()

# grouped_titleType
# movie               
# other               
# short               
# tvseries_related

# %%
len_max_it = []
len_cl_it = []
len_fr_it = []

# Numero totale di transazioni
total_transactions = len(X)

# Step 1: Definizione della griglia di parametri
supp_values = np.linspace(10, 50, 5)  # Supporto minimo da 10% a 50%
zmin_values = np.arange(5, df.shape[1] + 1)  # zmin da 2 fino al numero di colonne

# Set per eliminare duplicati
top_closed = set()
top_maximal = set()
top_frequent = set()
        
for supp in supp_values:
    for zmin in zmin_values:
        fr_itemsets = fpgrowth(X, target="s", supp=supp, zmin=zmin)
        max_itemsets = fpgrowth(X, target="m", supp=supp, zmin=zmin)
        cl_itemsets = fpgrowth(X, target="c", supp=supp, zmin=zmin)
        len_max_it.append(len(max_itemsets))
        len_cl_it.append(len(cl_itemsets))
        len_fr_it.append(len(fr_itemsets))

        # Aggiungi gli itemset ai set
        top_closed.update(cl_itemsets)
        top_maximal.update(max_itemsets)
        top_frequent.update(fr_itemsets)

        # Stampa i pattern in ordine decrescente per supporto (massimali)
        print(f"\nMassimal itemsets (supporto={supp:.2f}, zmin={zmin}):")
        for itemset, support in sorted(
            max_itemsets,
            key=lambda x: -x[1]  # Ordina per supporto decrescente
        ):
            percent_support = (support / total_transactions) * 100
            print(f"Itemset: {itemset}, Supporto: {percent_support:.2f}%")

        # Stampa i pattern in ordine decrescente per supporto (chiusi)
        print(f"\nClosed itemsets (supporto={supp:.2f}, zmin={zmin}):")
        for itemset, support in sorted(
            cl_itemsets,
            key=lambda x: -x[1]  # Ordina per supporto decrescente
        ):
            percent_support = (support / total_transactions) * 100
            print(f"Itemset: {itemset}, Supporto: {percent_support:.2f}%")

        # Stampa i pattern in ordine decrescente per supporto (frequenti)
        print(f"\nFrequent itemsets (supporto={supp:.2f}, zmin={zmin}):")
        for itemset, support in sorted(
            fr_itemsets,
            key=lambda x: -x[1]  # Ordina per supporto decrescente
        ):
            percent_support = (support / total_transactions) * 100
            print(f"Itemset: {itemset}, Supporto: {percent_support:.2f}%")


# Filtra i top 3 itemset con il supporto maggiore
top_closed = sorted(top_closed, key=lambda x: -x[1])[:3]
top_maximal = sorted(top_maximal, key=lambda x: -x[1])[:3]
top_frequent = sorted(top_frequent, key=lambda x: -x[1])[:3]

# Stampa i risultati finali
print("\nTop 3 Closed Itemsets by Support:")
for itemset, support in top_closed:
    percent_support = (support / total_transactions) * 100
    print(f"Itemset: {itemset}, Supporto: {percent_support:.2f}%")

print("\nTop 3 Maximal Itemsets by Support:")
for itemset, support in top_maximal:
    percent_support = (support / total_transactions) * 100
    print(f"Itemset: {itemset}, Supporto: {percent_support:.2f}%")

print("\nTop 3 Frequent Itemsets by Support:")
for itemset, support in top_frequent:
    percent_support = (support / total_transactions) * 100
    print(f"Itemset: {itemset}, Supporto: {percent_support:.2f}%")





# plt.plot(np.arange(2, 50), len_max_it, label="maximal")
# plt.plot(np.arange(2, 50), len_cl_it, label="closed")
# plt.legend()
# plt.xlabel("%support")
# plt.ylabel("itemsets")

# plt.show()
# Out:
# Massimal itemsets (supporto=10.00, zmin=5):
# Itemset: ('(0.0, 1.099]_images', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 15.64%
# Itemset: ('movie', '(1.933, 24.333]_regions', 'No_reviews', '1_country', 'no_adult', 'no_episodes'), Supporto: 15.58%
# Itemset: ('movie', '(1994.8, 2024.0]_year', '1_country', 'no_adult', 'no_episodes'), Supporto: 15.03%
# Itemset: ('(1.933, 24.333]_regions', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.97%
# Itemset: ('(0.0, 1.099]_images', 'genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.74%
# Itemset: ('(1965.6, 1994.8]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.68%
# Itemset: ('(29.0, 53.0]_minutes', 'tvseries_related', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.66%
# Itemset: ('(1965.6, 1994.8]_year', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.66%
# Itemset: ('US', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.61%
# Itemset: ('genre_Action/Adventure', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.60%
# Itemset: ('(0.0, 1.099]_images', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.40%
# Itemset: ('movie', '(1.933, 24.333]_regions', 'Not US', '1_country', 'no_adult', 'no_episodes'), Supporto: 14.38%
# Itemset: ('(0.0, 1.099]_images', 'Reviews', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.29%
# Itemset: ('genre_Action/Adventure', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.22%
# Itemset: ('tvseries_related', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.19%
# Itemset: ('(1994.8, 2024.0]_year', 'Not US', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.16%
# Itemset: ('Reviews', 'Not US', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.10%
# Itemset: ('(0.0, 1.099]_images', 'genre_Drama/Crime', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.09%
# Itemset: ('(1965.6, 1994.8]_year', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.08%
# Itemset: ('genre_Drama/Crime', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.06%
# Itemset: ('Not US', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 14.04%
# Itemset: ('short', '(-0.001, 29.0]_minutes', 'genre_Comedy/Family', '1_country', 'no_adult', 'no_episodes'), Supporto: 13.90%
# Itemset: ('(0.999, 17.0]_credits', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 13.86%
# Itemset: ('(0.0, 1.099]_images', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 13.84%
# Itemset: ('genre_Comedy/Family', 'Not US', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 13.75%
# Itemset: ('(1.7910000000000001, 2.773]_votes', 'Reviews', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 13.74%
# Itemset: ('(1.933, 24.333]_regions', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 13.65%
# Itemset: ('(53.0, 90.0]_minutes', 'movie', '1_country', 'no_adult', 'no_episodes'), Supporto: 13.65%
# Itemset: ('(1965.6, 1994.8]_year', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 13.62%
# Itemset: ('(2.773, 3.664]_votes', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 13.60%
# Itemset: ('genre_Comedy/Family', '(1994.8, 2024.0]_year', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 13.51%
# Itemset: ('tvseries_related', 'Reviews', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 13.43%
# Itemset: ('(90.0, 570.0]_minutes', 'movie', 'Not US', '1_country', 'no_adult', 'no_episodes'), Supporto: 13.42%
# Itemset: ('genre_Action/Adventure', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 13.31%
# Itemset: ('genre_Drama/Crime', 'US', 'no_episodes', '1_country', 'no_adult'), Supporto: 13.24%
# Itemset: ('(3.664, 5.056]_votes', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 13.03%
# Itemset: ('(2.773, 3.664]_votes', 'Reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 13.01%
# Itemset: ('movie', 'genre_Comedy/Family', '1_country', 'no_adult', 'no_episodes'), Supporto: 12.93%
# Itemset: ('No_reviews', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.90%
# Itemset: ('genre_Action/Adventure', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.88%
# Itemset: ('tvseries_related', '(1994.8, 2024.0]_year', 'Not US', '1_country', 'no_adult'), Supporto: 12.88%
# Itemset: ('movie', 'genre_Drama/Crime', 'Not US', '1_country', 'no_adult', 'no_episodes'), Supporto: 12.87%
# Itemset: ('US', 'Reviews', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.87%
# Itemset: ('US', 'No_reviews', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.85%
# Itemset: ('(1.7910000000000001, 2.773]_votes', 'Reviews', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.80%
# Itemset: ('(35.0, 66.0]_credits', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.75%
# Itemset: ('(66.0, 1885.0]_credits', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.75%
# Itemset: ('tvseries_related', 'Not US', '1_regions', '1_country', 'no_adult'), Supporto: 12.75%
# Itemset: ('(66.0, 1885.0]_credits', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.74%
# Itemset: ('No_reviews', 'genre_Comedy/Family', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.72%
# Itemset: ('genre_Drama/Crime', 'Not US', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.71%
# Itemset: ('(35.0, 66.0]_credits', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.62%
# Itemset: ('US', 'No_reviews', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.60%
# Itemset: ('(1965.6, 1994.8]_year', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.58%
# Itemset: ('(3.664, 5.056]_votes', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.56%
# Itemset: ('(17.0, 35.0]_credits', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.47%
# Itemset: ('(0.0, 1.099]_images', 'Reviews', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.46%
# Itemset: ('(-inf, 0.0]_images', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.46%
# Itemset: ('genre_Doc/Others', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.39%
# Itemset: ('genre_Drama/Crime', 'No_reviews', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.34%
# Itemset: ('(-inf, 0.0]_images', 'Reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.33%
# Itemset: ('movie', '(1.933, 24.333]_regions', 'genre_Drama/Crime', '1_country', 'no_adult', 'no_episodes'), Supporto: 12.28%
# Itemset: ('genre_Action/Adventure', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.28%
# Itemset: ('movie', 'No_reviews', 'Not US', '1_country', 'no_adult', 'no_episodes'), Supporto: 12.24%
# Itemset: ('(17.0, 35.0]_credits', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.23%
# Itemset: ('movie', 'Not US', 'good_rated', '1_country', 'no_adult', 'no_episodes'), Supporto: 12.16%
# Itemset: ('No_reviews', 'genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.16%
# Itemset: ('(5.056, 13.624]_votes', 'movie', 'No_reviews', 'no_adult', 'no_episodes'), Supporto: 12.15%
# Itemset: ('tvseries_related', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.13%
# Itemset: ('US', 'No_reviews', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.09%
# Itemset: ('Reviews', 'genre_Comedy/Family', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.08%
# Itemset: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 12.02%
# Itemset: ('(90.0, 570.0]_minutes', 'movie', '(1.933, 24.333]_regions', '1_country', 'no_adult', 'no_episodes'), Supporto: 11.99%
# Itemset: ('(1.933, 24.333]_regions', '(1994.8, 2024.0]_year', 'Not US', '1_country', 'no_adult'), Supporto: 11.99%
# Itemset: ('(0.0, 1.099]_images', 'US', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.97%
# Itemset: ('(3.664, 5.056]_votes', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.93%
# Itemset: ('tvseries_related', 'genre_Comedy/Family', '(1994.8, 2024.0]_year', '1_country', 'no_adult'), Supporto: 11.93%
# Itemset: ('genre_Doc/Others', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.92%
# Itemset: ('tvseries_related', 'Not US', 'good_rated', '1_country', 'no_adult'), Supporto: 11.91%
# Itemset: ('tvseries_related', 'Reviews', 'Not US', '1_country', 'no_adult'), Supporto: 11.90%
# Itemset: ('(35.0, 66.0]_credits', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.81%
# Itemset: ('(90.0, 570.0]_minutes', 'movie', 'No_reviews', '1_country', 'no_adult', 'no_episodes'), Supporto: 11.74%
# Itemset: ('(0.0, 1.099]_images', 'Not US', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.73%
# Itemset: ('(17.0, 35.0]_credits', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.70%
# Itemset: ('(0.0, 1.099]_images', 'Reviews', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.70%
# Itemset: ('(0.0, 1.099]_images', 'genre_Comedy/Family', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.68%
# Itemset: ('(1.7910000000000001, 2.773]_votes', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.67%
# Itemset: ('(2.773, 3.664]_votes', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.64%
# Itemset: ('(29.0, 53.0]_minutes', 'tvseries_related', 'genre_Comedy/Family', '1_country', 'no_adult'), Supporto: 11.63%
# Itemset: ('low_rated', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.60%
# Itemset: ('(0.999, 17.0]_credits', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.59%
# Itemset: ('(2.197, 8.162]_images', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.58%
# Itemset: ('movie', 'genre_Drama/Crime', 'No_reviews', '1_country', 'no_adult', 'no_episodes'), Supporto: 11.58%
# Itemset: ('tvseries_related', 'No_reviews', 'good_rated', '1_country', 'no_adult'), Supporto: 11.57%
# Itemset: ('low_rated', 'movie', '1_country', 'no_adult', 'no_episodes'), Supporto: 11.55%
# Itemset: ('movie', '(1994.8, 2024.0]_year', 'Not US', 'no_adult', 'no_episodes'), Supporto: 11.54%
# Itemset: ('genre_Drama/Crime', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.54%
# Itemset: ('No_reviews', 'Not US', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.54%
# Itemset: ('tvseries_related', 'No_reviews', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.50%
# Itemset: ('(1965.6, 1994.8]_year', 'Reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.49%
# Itemset: ('(0.0, 1.099]_images', 'Not US', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.48%
# Itemset: ('(2.773, 3.664]_votes', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.47%
# Itemset: ('movie', 'genre_Drama/Crime', 'good_rated', 'no_adult', 'no_episodes'), Supporto: 11.47%
# Itemset: ('movie', 'No_reviews', '(1994.8, 2024.0]_year', 'no_adult', 'no_episodes'), Supporto: 11.45%
# Itemset: ('(17.0, 35.0]_credits', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.43%
# Itemset: ('(35.0, 66.0]_credits', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.43%
# Itemset: ('(1.933, 24.333]_regions', 'genre_Comedy/Family', 'Not US', '1_country', 'no_adult'), Supporto: 11.43%
# Itemset: ('(0.999, 17.0]_credits', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.42%
# Itemset: ('(29.0, 53.0]_minutes', 'tvseries_related', 'good_rated', '1_regions', '1_country', 'no_adult'), Supporto: 11.39%
# Itemset: ('(1965.6, 1994.8]_year', 'genre_Drama/Crime', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.38%
# Itemset: ('(1.933, 24.333]_regions', 'Not US', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.38%
# Itemset: ('(29.0, 53.0]_minutes', 'tvseries_related', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.38%
# Itemset: ('genre_Doc/Others', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.37%
# Itemset: ('(1.933, 24.333]_regions', 'No_reviews', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.36%
# Itemset: ('(35.0, 66.0]_credits', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.32%
# Itemset: ('movie', '(1.933, 24.333]_regions', 'No_reviews', 'Not US', 'no_adult', 'no_episodes'), Supporto: 11.30%
# Itemset: ('(29.0, 53.0]_minutes', 'Reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.29%
# Itemset: ('(1.7910000000000001, 2.773]_votes', 'Reviews', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.28%
# Itemset: ('low_rated', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.28%
# Itemset: ('(1.7910000000000001, 2.773]_votes', 'Reviews', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.27%
# Itemset: ('(0.0, 1.099]_images', 'Reviews', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.27%
# Itemset: ('(1.933, 24.333]_regions', '(0.0, 1.099]_images', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.27%
# Itemset: ('genre_Action/Adventure', 'US', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.25%
# Itemset: ('(90.0, 570.0]_minutes', 'movie', 'good_rated', 'no_adult', 'no_episodes'), Supporto: 11.22%
# Itemset: ('genre_Action/Adventure', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.16%
# Itemset: ('(0.0, 1.099]_images', '(1994.8, 2024.0]_year', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.14%
# Itemset: ('(1965.6, 1994.8]_year', '(0.0, 1.099]_images', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.10%
# Itemset: ('(0.0, 1.099]_images', 'Reviews', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.10%
# Itemset: ('genre_Drama/Crime', '(1994.8, 2024.0]_year', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.08%
# Itemset: ('(66.0, 1885.0]_credits', 'US', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.08%
# Itemset: ('(0.999, 17.0]_credits', 'Reviews', 'Not US', '1_country', 'no_adult'), Supporto: 11.08%
# Itemset: ('(1.099, 2.197]_images', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.06%
# Itemset: ('(3.664, 5.056]_votes', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.06%
# Itemset: ('No_reviews', '(1994.8, 2024.0]_year', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.05%
# Itemset: ('(53.0, 90.0]_minutes', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.01%
# Itemset: ('No_reviews', 'genre_Comedy/Family', 'Not US', '1_country', 'no_adult'), Supporto: 11.01%
# Itemset: ('(2.773, 3.664]_votes', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.01%
# Itemset: ('US', 'genre_Comedy/Family', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.01%
# Itemset: ('(17.0, 35.0]_credits', 'Reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 11.00%
# Itemset: ('(90.0, 570.0]_minutes', 'movie', 'genre_Drama/Crime', '1_country', 'no_adult', 'no_episodes'), Supporto: 11.00%
# Itemset: ('(66.0, 1885.0]_credits', '(5.056, 13.624]_votes', 'No_reviews', 'no_episodes', 'no_adult'), Supporto: 11.00%
# Itemset: ('tvseries_related', '(0.0, 1.099]_images', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.99%
# Itemset: ('(66.0, 1885.0]_credits', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.98%
# Itemset: ('(1.933, 24.333]_regions', 'genre_Drama/Crime', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.96%
# Itemset: ('genre_Doc/Others', 'Reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.96%
# Itemset: ('(29.0, 53.0]_minutes', 'tvseries_related', 'Not US', '1_country', 'no_adult'), Supporto: 10.96%
# Itemset: ('(0.0, 1.099]_images', 'genre_Comedy/Family', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.93%
# Itemset: ('genre_Drama/Crime', 'No_reviews', '(1994.8, 2024.0]_year', 'no_episodes', 'no_adult'), Supporto: 10.93%
# Itemset: ('(5.056, 13.624]_votes', 'No_reviews', '(1994.8, 2024.0]_year', 'no_episodes', 'no_adult'), Supporto: 10.92%
# Itemset: ('No_reviews', 'genre_Comedy/Family', '(1994.8, 2024.0]_year', '1_country', 'no_adult'), Supporto: 10.91%
# Itemset: ('movie', '(1.933, 24.333]_regions', 'good_rated', '1_country', 'no_adult', 'no_episodes'), Supporto: 10.91%
# Itemset: ('(29.0, 53.0]_minutes', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.87%
# Itemset: ('genre_Drama/Crime', 'Reviews', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.87%
# Itemset: ('genre_Drama/Crime', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.87%
# Itemset: ('Reviews', 'genre_Comedy/Family', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.86%
# Itemset: ('(1.933, 24.333]_regions', '(1994.8, 2024.0]_year', 'Not US', 'no_episodes', 'no_adult'), Supporto: 10.86%
# Itemset: ('(5.056, 13.624]_votes', 'US', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.84%
# Itemset: ('(-0.001, 29.0]_minutes', '(0.0, 1.099]_images', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.84%
# Itemset: ('(1965.6, 1994.8]_year', 'movie', '1_country', 'no_adult', 'no_episodes'), Supporto: 10.84%
# Itemset: ('tvseries_related', 'Reviews', '(1994.8, 2024.0]_year', '1_regions', '1_country', 'no_adult'), Supporto: 10.84%
# Itemset: ('(1.933, 24.333]_regions', 'genre_Comedy/Family', 'Not US', 'no_episodes', 'no_adult'), Supporto: 10.82%
# Itemset: ('tvseries_related', '(0.0, 1.099]_images', 'good_rated', '1_country', 'no_adult'), Supporto: 10.81%
# Itemset: ('(0.0, 1.099]_images', '(1994.8, 2024.0]_year', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.81%
# Itemset: ('Reviews', '(1994.8, 2024.0]_year', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.80%
# Itemset: ('movie', '1_regions', '1_country', 'no_adult', 'no_episodes'), Supporto: 10.79%
# Itemset: ('movie', '(0.0, 1.099]_images', 'Not US', '1_country', 'no_adult', 'no_episodes'), Supporto: 10.79%
# Itemset: ('(1.7910000000000001, 2.773]_votes', 'Reviews', 'good_rated', '1_country', 'no_adult'), Supporto: 10.76%
# Itemset: ('low_rated', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.76%
# Itemset: ('US', 'No_reviews', '(1994.8, 2024.0]_year', 'no_episodes', 'no_adult'), Supporto: 10.76%
# Itemset: ('No_reviews', 'genre_Comedy/Family', 'Not US', 'no_episodes', 'no_adult'), Supporto: 10.76%
# Itemset: ('(53.0, 90.0]_minutes', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.75%
# Itemset: ('movie', '(1.933, 24.333]_regions', 'genre_Drama/Crime', 'No_reviews', 'no_adult', 'no_episodes'), Supporto: 10.73%
# Itemset: ('(3.664, 5.056]_votes', '(0.0, 1.099]_images', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.73%
# Itemset: ('(5.056, 13.624]_votes', 'No_reviews', 'genre_Comedy/Family', 'no_episodes', 'no_adult'), Supporto: 10.73%
# Itemset: ('(5.056, 13.624]_votes', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.73%
# Itemset: ('(0.0, 1.099]_images', 'genre_Comedy/Family', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.72%
# Itemset: ('(29.0, 53.0]_minutes', 'tvseries_related', '(1994.8, 2024.0]_year', '1_regions', '1_country', 'no_adult'), Supporto: 10.71%
# Itemset: ('tvseries_related', 'US', 'genre_Comedy/Family', '1_country', 'no_adult'), Supporto: 10.70%
# Itemset: ('No_reviews', 'genre_Comedy/Family', '(1994.8, 2024.0]_year', 'no_episodes', 'no_adult'), Supporto: 10.69%
# Itemset: ('tvseries_related', 'genre_Drama/Crime', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.69%
# Itemset: ('No_reviews', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.69%
# Itemset: ('tvseries_related', '(1994.8, 2024.0]_year', 'good_rated', '1_regions', '1_country', 'no_adult'), Supporto: 10.67%
# Itemset: ('genre_Drama/Crime', 'No_reviews', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.67%
# Itemset: ('tvseries_related', 'US', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.65%
# Itemset: ('tvseries_related', '(1994.8, 2024.0]_year', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.65%
# Itemset: ('(0.0, 1.099]_images', 'genre_Drama/Crime', 'Not US', '1_country', 'no_adult'), Supporto: 10.64%
# Itemset: ('(1.933, 24.333]_regions', 'Reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.64%
# Itemset: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.63%
# Itemset: ('movie', '(1.933, 24.333]_regions', '(1994.8, 2024.0]_year', 'no_adult', 'no_episodes'), Supporto: 10.63%
# Itemset: ('(-0.001, 29.0]_minutes', 'US', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.62%
# Itemset: ('(1.7910000000000001, 2.773]_votes', 'genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.62%
# Itemset: ('tvseries_related', 'genre_Drama/Crime', 'good_rated', '1_country', 'no_adult'), Supporto: 10.62%
# Itemset: ('(0.999, 17.0]_credits', 'Reviews', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.61%
# Itemset: ('(5.056, 13.624]_votes', 'No_reviews', 'genre_Comedy/Family', '1_country', 'no_adult'), Supporto: 10.59%
# Itemset: ('movie', 'Reviews', 'Not US', '1_country', 'no_adult', 'no_episodes'), Supporto: 10.59%
# Itemset: ('movie', 'No_reviews', 'good_rated', '1_country', 'no_adult', 'no_episodes'), Supporto: 10.59%
# Itemset: ('(1.7910000000000001, 2.773]_votes', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.58%
# Itemset: ('(0.999, 17.0]_credits', 'genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.58%
# Itemset: ('movie', 'US', '1_country', 'no_adult', 'no_episodes'), Supporto: 10.58%
# Itemset: ('(1.7910000000000001, 2.773]_votes', 'Not US', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.57%
# Itemset: ('(29.0, 53.0]_minutes', 'tvseries_related', 'good_rated', '1_regions', 'no_episodes', 'no_adult'), Supporto: 10.55%
# Itemset: ('(5.056, 13.624]_votes', 'No_reviews', '(1994.8, 2024.0]_year', '1_country', 'no_adult'), Supporto: 10.53%
# Itemset: ('tvseries_related', 'Reviews', 'good_rated', '1_regions', '1_country', 'no_adult'), Supporto: 10.53%
# Itemset: ('(5.056, 13.624]_votes', 'No_reviews', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.51%
# Itemset: ('(0.999, 17.0]_credits', '(0.0, 1.099]_images', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.51%
# Itemset: ('(1.933, 24.333]_regions', 'No_reviews', '(1994.8, 2024.0]_year', '1_country', 'no_adult'), Supporto: 10.50%
# Itemset: ('(90.0, 570.0]_minutes', 'movie', '(1.933, 24.333]_regions', 'No_reviews', 'no_adult', 'no_episodes'), Supporto: 10.49%
# Itemset: ('(2.773, 3.664]_votes', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.49%
# Itemset: ('(29.0, 53.0]_minutes', 'tvseries_related', 'US', 'no_episodes', 'no_adult'), Supporto: 10.49%
# Itemset: ('(1.933, 24.333]_regions', 'No_reviews', 'genre_Comedy/Family', '1_country', 'no_adult'), Supporto: 10.49%
# Itemset: ('(5.056, 13.624]_votes', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.48%
# Itemset: ('short', 'genre_Comedy/Family', '1_regions', '1_country', 'no_adult', 'no_episodes'), Supporto: 10.47%
# Itemset: ('US', 'No_reviews', '(1994.8, 2024.0]_year', '1_country', 'no_adult'), Supporto: 10.47%
# Itemset: ('genre_Drama/Crime', 'No_reviews', '(1994.8, 2024.0]_year', '1_country', 'no_adult'), Supporto: 10.47%
# Itemset: ('(-0.001, 29.0]_minutes', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.44%
# Itemset: ('tvseries_related', 'Reviews', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.44%
# Itemset: ('tvseries_related', 'genre_Comedy/Family', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.43%
# Itemset: ('genre_Drama/Crime', 'US', 'No_reviews', 'no_episodes', 'no_adult'), Supporto: 10.43%
# Itemset: ('(1.933, 24.333]_regions', 'No_reviews', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.42%
# Itemset: ('Reviews', 'Not US', 'good_rated', '1_regions', '1_country', 'no_adult'), Supporto: 10.42%
# Itemset: ('tvseries_related', 'Reviews', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.40%
# Itemset: ('(66.0, 1885.0]_credits', '(5.056, 13.624]_votes', 'No_reviews', '1_country', 'no_adult'), Supporto: 10.39%
# Itemset: ('genre_Drama/Crime', 'Reviews', '1_regions', '1_country', 'no_adult'), Supporto: 10.39%
# Itemset: ('(-inf, 0.0]_images', 'Reviews', '1_regions', 'no_episodes', '1_country'), Supporto: 10.39%
# Itemset: ('genre_Drama/Crime', 'Not US', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.38%
# Itemset: ('US', '(1994.8, 2024.0]_year', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.37%
# Itemset: ('(35.0, 66.0]_credits', 'genre_Drama/Crime', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.36%
# Itemset: ('(-0.001, 29.0]_minutes', '(0.999, 17.0]_credits', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.36%
# Itemset: ('(29.0, 53.0]_minutes', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.36%
# Itemset: ('tvseries_related', 'Reviews', 'genre_Comedy/Family', '1_regions', 'no_adult'), Supporto: 10.36%
# Itemset: ('Reviews', '(1994.8, 2024.0]_year', 'Not US', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.35%
# Itemset: ('(-inf, 0.0]_images', 'Reviews', '1_regions', '1_country', 'no_adult'), Supporto: 10.34%
# Itemset: ('(2.773, 3.664]_votes', 'Reviews', '1_regions', '1_country', 'no_adult'), Supporto: 10.34%
# Itemset: ('(5.056, 13.624]_votes', 'movie', '1_country', 'no_adult', 'no_episodes'), Supporto: 10.34%
# Itemset: ('(3.664, 5.056]_votes', 'US', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.33%
# Itemset: ('(66.0, 1885.0]_credits', 'genre_Drama/Crime', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.33%
# Itemset: ('US', 'Reviews', '(1994.8, 2024.0]_year', '1_country', 'no_adult'), Supporto: 10.33%
# Itemset: ('low_rated', '(1.933, 24.333]_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.32%
# Itemset: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.30%
# Itemset: ('(1.933, 24.333]_regions', 'Reviews', 'Not US', '1_country', 'no_adult'), Supporto: 10.30%
# Itemset: ('genre_Comedy/Family', '(1994.8, 2024.0]_year', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.29%
# Itemset: ('(90.0, 570.0]_minutes', 'movie', '(1.933, 24.333]_regions', 'Not US', 'no_adult', 'no_episodes'), Supporto: 10.29%
# Itemset: ('(1.933, 24.333]_regions', 'No_reviews', 'genre_Comedy/Family', 'no_episodes', 'no_adult'), Supporto: 10.27%
# Itemset: ('(0.0, 1.099]_images', 'genre_Drama/Crime', 'Not US', 'no_episodes', 'no_adult'), Supporto: 10.27%
# Itemset: ('(29.0, 53.0]_minutes', 'tvseries_related', 'genre_Drama/Crime', '1_country', 'no_adult'), Supporto: 10.25%
# Itemset: ('(1965.6, 1994.8]_year', 'good_rated', '1_regions', '1_country', 'no_adult'), Supporto: 10.25%
# Itemset: ('(1.933, 24.333]_regions', 'US', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.25%
# Itemset: ('(90.0, 570.0]_minutes', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.25%
# Itemset: ('short', '(-0.001, 29.0]_minutes', 'genre_Comedy/Family', '1_regions', 'no_adult', 'no_episodes'), Supporto: 10.24%
# Itemset: ('(29.0, 53.0]_minutes', 'tvseries_related', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.24%
# Itemset: ('high_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.24%
# Itemset: ('(29.0, 53.0]_minutes', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', 'no_adult'), Supporto: 10.24%
# Itemset: ('(1.933, 24.333]_regions', 'genre_Drama/Crime', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.23%
# Itemset: ('(-0.001, 29.0]_minutes', 'Reviews', 'genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.22%
# Itemset: ('genre_Doc/Others', 'US', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.22%
# Itemset: ('(5.056, 13.624]_votes', 'movie', '(1.933, 24.333]_regions', 'no_adult', 'no_episodes'), Supporto: 10.22%
# Itemset: ('(0.999, 17.0]_credits', 'Reviews', 'Not US', 'no_episodes', 'no_adult'), Supporto: 10.22%
# Itemset: ('(1.933, 24.333]_regions', 'No_reviews', '(1994.8, 2024.0]_year', 'no_episodes', 'no_adult'), Supporto: 10.22%
# Itemset: ('(0.0, 1.099]_images', 'No_reviews', 'good_rated', '1_country', 'no_adult'), Supporto: 10.20%
# Itemset: ('No_reviews', '(1994.8, 2024.0]_year', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.20%
# Itemset: ('(66.0, 1885.0]_credits', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.19%
# Itemset: ('tvseries_related', 'Not US', '1_regions', 'no_episodes', 'no_adult'), Supporto: 10.19%
# Itemset: ('(0.0, 1.099]_images', 'Reviews', 'genre_Comedy/Family', '1_regions', 'no_adult'), Supporto: 10.18%
# Itemset: ('(1.7910000000000001, 2.773]_votes', 'Reviews', 'Not US', '1_regions', '1_country', 'no_adult'), Supporto: 10.17%
# Itemset: ('(29.0, 53.0]_minutes', 'tvseries_related', 'Reviews', 'no_episodes', 'no_adult'), Supporto: 10.17%
# Itemset: ('movie', '(1.933, 24.333]_regions', 'genre_Drama/Crime', 'Not US', 'no_adult', 'no_episodes'), Supporto: 10.17%
# Itemset: ('(-0.001, 29.0]_minutes', 'US', '1_regions', 'no_episodes', 'no_adult'), Supporto: 10.16%
# Itemset: ('(29.0, 53.0]_minutes', 'Reviews', '(1994.8, 2024.0]_year', '1_country', 'no_adult'), Supporto: 10.16%
# Itemset: ('genre_Drama/Crime', 'Reviews', '1_regions', 'no_episodes', 'no_adult'), Supporto: 10.16%
# Itemset: ('(53.0, 90.0]_minutes', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.15%
# Itemset: ('(1.7910000000000001, 2.773]_votes', '(1994.8, 2024.0]_year', 'Not US', '1_country', 'no_adult'), Supporto: 10.15%
# Itemset: ('(0.0, 1.099]_images', 'No_reviews', 'good_rated', 'no_episodes', 'no_adult'), Supporto: 10.15%
# Itemset: ('(2.197, 8.162]_images', '(5.056, 13.624]_votes', 'No_reviews', 'no_episodes', 'no_adult'), Supporto: 10.15%
# Itemset: ('(-0.001, 29.0]_minutes', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.15%
# Itemset: ('(0.0, 1.099]_images', 'Reviews', '(1994.8, 2024.0]_year', '1_regions', '1_country', 'no_adult'), Supporto: 10.14%
# Itemset: ('short', '(-0.001, 29.0]_minutes', '1_regions', '1_country', 'no_adult', 'no_episodes'), Supporto: 10.14%
# Itemset: ('(1.7910000000000001, 2.773]_votes', 'Reviews', 'good_rated', 'no_episodes', 'no_adult'), Supporto: 10.14%
# Itemset: ('tvseries_related', 'Reviews', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.14%
# Itemset: ('(5.056, 13.624]_votes', '(1.933, 24.333]_regions', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.12%
# Itemset: ('Reviews', 'genre_Comedy/Family', 'Not US', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.12%
# Itemset: ('(1994.8, 2024.0]_year', 'Not US', 'good_rated', '1_regions', 'no_adult'), Supporto: 10.11%
# Itemset: ('(53.0, 90.0]_minutes', 'movie', '(1.933, 24.333]_regions', 'no_adult', 'no_episodes'), Supporto: 10.10%
# Itemset: ('(29.0, 53.0]_minutes', 'tvseries_related', 'US', '1_regions', '1_country', 'no_adult'), Supporto: 10.09%
# Itemset: ('Reviews', '(1994.8, 2024.0]_year', 'Not US', 'good_rated', 'no_adult'), Supporto: 10.09%
# Itemset: ('(1.7910000000000001, 2.773]_votes', 'Reviews', '(1994.8, 2024.0]_year', '1_regions', '1_country', 'no_adult'), Supporto: 10.08%
# Itemset: ('(0.999, 17.0]_credits', 'Reviews', 'genre_Comedy/Family', '1_country', 'no_adult'), Supporto: 10.08%
# Itemset: ('US', 'No_reviews', '(1994.8, 2024.0]_year', 'no_episodes', '1_country'), Supporto: 10.08%
# Itemset: ('(29.0, 53.0]_minutes', 'tvseries_related', 'Reviews', '1_regions', '1_country', 'no_adult'), Supporto: 10.07%
# Itemset: ('(0.999, 17.0]_credits', 'Reviews', 'Not US', 'no_episodes', '1_country'), Supporto: 10.06%
# Itemset: ('(-inf, 0.0]_images', 'Reviews', '1_regions', 'no_episodes', 'no_adult'), Supporto: 10.05%
# Itemset: ('(-inf, 0.0]_images', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.05%
# Itemset: ('(1.7910000000000001, 2.773]_votes', '(0.999, 17.0]_credits', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.05%
# Itemset: ('(5.056, 13.624]_votes', 'genre_Drama/Crime', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.03%
# Itemset: ('(1965.6, 1994.8]_year', 'good_rated', '1_regions', 'no_episodes', 'no_adult'), Supporto: 10.03%
# Itemset: ('tvseries_related', 'US', 'genre_Comedy/Family', 'no_episodes', 'no_adult'), Supporto: 10.03%
# Itemset: ('(-0.001, 29.0]_minutes', '(0.0, 1.099]_images', 'genre_Comedy/Family', 'no_episodes', 'no_adult'), Supporto: 10.03%
# Itemset: ('US', 'Reviews', '(1994.8, 2024.0]_year', 'no_episodes', 'no_adult'), Supporto: 10.02%
# Itemset: ('(29.0, 53.0]_minutes', 'US', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.02%
# Itemset: ('US', 'genre_Comedy/Family', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.02%
# Itemset: ('movie', '(1994.8, 2024.0]_year', 'Not US', '1_country', 'no_episodes'), Supporto: 10.01%
# Itemset: ('US', 'Reviews', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.01%
# Itemset: ('(3.664, 5.056]_votes', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.00%
# Itemset: ('genre_Drama/Crime', '(1994.8, 2024.0]_year', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 10.00%
#
# Closed itemsets (supporto=10.00, zmin=5):
# Itemset: ('genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 31.21%
# Itemset: ('good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 29.76%
# Itemset: ('(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 29.53%
# Itemset: ('Reviews', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 29.38%
# Itemset: ('genre_Comedy/Family', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 26.76%
# Itemset: ('US', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 25.73%
# Itemset: ('Not US', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 25.64%
# Itemset: ('Reviews', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 25.24%
# Itemset: ('tvseries_related', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.92%
# Itemset: ('Reviews', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.85%
# Itemset: ('genre_Comedy/Family', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.64%
# Itemset: ('(1994.8, 2024.0]_year', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.53%
# Itemset: ('genre_Comedy/Family', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.51%
# Itemset: ('(1994.8, 2024.0]_year', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.50%
# Itemset: ('Not US', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.41%
# Itemset: ('No_reviews', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.13%
# Itemset: ('Reviews', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 23.84%
# Itemset: ('(0.0, 1.099]_images', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 23.70%
# Itemset: ('movie', 'Not US', '1_country', 'no_adult', 'no_episodes'), Supporto: 22.83%
# Itemset: ('Reviews', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 22.72%
# Itemset: ('US', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 22.10%
# Itemset: ('US', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 22.03%
# Itemset: ('No_reviews', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 21.90%
# Itemset: ('genre_Drama/Crime', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 21.54%
# Itemset: ('movie', '(1.933, 24.333]_regions', '1_country', 'no_adult', 'no_episodes'), Supporto: 21.52%
# Itemset: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 21.25%
# Itemset: ('US', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 21.21%
# Itemset: ('Reviews', '(1994.8, 2024.0]_year', '1_regions', '1_country', 'no_adult'), Supporto: 20.95%
# Itemset: ('No_reviews', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.76%
# Itemset: ('genre_Drama/Crime', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.75%
# Itemset: ('movie', 'No_reviews', '1_country', 'no_adult', 'no_episodes'), Supporto: 20.59%
# Itemset: ('(0.0, 1.099]_images', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.57%
# Itemset: ('Reviews', 'genre_Comedy/Family', '1_regions', '1_country', 'no_adult'), Supporto: 20.28%
# Itemset: ('(0.0, 1.099]_images', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.19%
# Itemset: ('(1.933, 24.333]_regions', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.09%
# Itemset: ('genre_Drama/Crime', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.09%
# Itemset: ('(0.0, 1.099]_images', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 19.91%
# Itemset: ('Reviews', 'genre_Comedy/Family', '1_regions', 'no_episodes', 'no_adult'), Supporto: 19.82%
# Itemset: ('No_reviews', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 19.73%
# Itemset: ('(1.933, 24.333]_regions', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 19.70%
# Itemset: ('Reviews', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', 'no_adult'), Supporto: 19.62%
# Itemset: ('No_reviews', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 19.55%
# Itemset: ('tvseries_related', 'good_rated', '1_regions', '1_country', 'no_adult'), Supporto: 19.49%
# Itemset: ('tvseries_related', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 19.37%
# Itemset: ('(0.0, 1.099]_images', 'Reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 19.32%
# Itemset: ('genre_Comedy/Family', 'good_rated', '1_regions', '1_country', 'no_adult'), Supporto: 19.16%
# Itemset: ('Reviews', 'genre_Comedy/Family', '1_regions', 'no_episodes', '1_country'), Supporto: 19.11%
# Itemset: ('Reviews', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country'), Supporto: 19.11%
# Itemset: ('US', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 19.07%
# Itemset: ('Reviews', 'genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 19.05%
# Itemset: ('genre_Comedy/Family', '(1994.8, 2024.0]_year', '1_regions', '1_country', 'no_adult'), Supporto: 18.98%
# Itemset: ('(0.0, 1.099]_images', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 18.94%
# Itemset: ('genre_Comedy/Family', 'good_rated', '1_regions', 'no_episodes', 'no_adult'), Supporto: 18.92%
# Itemset: ('Reviews', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 18.84%
# Itemset: ('genre_Drama/Crime', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 18.77%
# Itemset: ('Reviews', 'Not US', '1_regions', '1_country', 'no_adult'), Supporto: 18.76%
# Itemset: ('genre_Comedy/Family', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', 'no_adult'), Supporto: 18.71%
# Itemset: ('(1994.8, 2024.0]_year', 'good_rated', '1_regions', '1_country', 'no_adult'), Supporto: 18.60%
# Itemset: ('(-0.001, 29.0]_minutes', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 18.41%
# Itemset: ('Reviews', 'good_rated', '1_regions', '1_country', 'no_adult'), Supporto: 18.40%
# Itemset: ('movie', '(1.933, 24.333]_regions', 'No_reviews', 'no_adult', 'no_episodes'), Supporto: 18.34%
# Itemset: ('genre_Comedy/Family', 'good_rated', '1_regions', 'no_episodes', '1_country'), Supporto: 18.33%
# Itemset: ('(90.0, 570.0]_minutes', 'movie', '1_country', 'no_adult', 'no_episodes'), Supporto: 18.22%
# Itemset: ('genre_Comedy/Family', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 18.18%
# Itemset: ('(5.056, 13.624]_votes', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 18.17%
# Itemset: ('(1.7910000000000001, 2.773]_votes', 'Reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 18.13%
# Itemset: ('tvseries_related', 'good_rated', '1_regions', 'no_episodes', 'no_adult'), Supporto: 18.11%
# Itemset: ('genre_Comedy/Family', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country'), Supporto: 18.10%
# Itemset: ('(1994.8, 2024.0]_year', 'good_rated', '1_regions', 'no_episodes', 'no_adult'), Supporto: 18.07%
# Itemset: ('movie', 'genre_Drama/Crime', '1_country', 'no_adult', 'no_episodes'), Supporto: 17.97%
# Itemset: ('genre_Comedy/Family', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 17.97%
# Itemset: ('(1994.8, 2024.0]_year', 'good_rated', '1_regions', 'no_episodes', '1_country'), Supporto: 17.74%
# Itemset: ('Reviews', 'good_rated', '1_regions', 'no_episodes', 'no_adult'), Supporto: 17.59%
# Itemset: ('genre_Drama/Crime', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 17.54%
# Itemset: ('(29.0, 53.0]_minutes', 'tvseries_related', '1_regions', '1_country', 'no_adult'), Supporto: 17.41%
# Itemset: ('tvseries_related', 'good_rated', '1_regions', 'no_episodes', '1_country'), Supporto: 17.34%
# Itemset: ('tvseries_related', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 17.34%
# Itemset: ('(1994.8, 2024.0]_year', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 17.26%
# Itemset: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', '1_regions', 'no_episodes', 'no_adult'), Supporto: 17.26%
# Itemset: ('movie', 'good_rated', '1_country', 'no_adult', 'no_episodes'), Supporto: 17.21%
# Itemset: ('Reviews', 'good_rated', '1_regions', 'no_episodes', '1_country'), Supporto: 17.17%
# Itemset: ('US', 'genre_Comedy/Family', '1_regions', 'no_episodes', 'no_adult'), Supporto: 17.12%
# Itemset: ('Reviews', 'Not US', '1_regions', 'no_episodes', 'no_adult'), Supporto: 17.12%
# Itemset: ('Reviews', '(1994.8, 2024.0]_year', 'Not US', '1_country', 'no_adult'), Supporto: 17.11%
# Itemset: ('US', 'genre_Comedy/Family', '1_regions', '1_country', 'no_adult'), Supporto: 17.00%
# Itemset: ('tvseries_related', '(1994.8, 2024.0]_year', '1_regions', '1_country', 'no_adult'), Supporto: 16.95%
# Itemset: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', '1_regions', '1_country', 'no_adult'), Supporto: 16.92%
# Itemset: ('(1994.8, 2024.0]_year', 'Not US', '1_regions', '1_country', 'no_adult'), Supporto: 16.90%
# Itemset: ('Reviews', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 16.87%
# Itemset: ('movie', '(1.933, 24.333]_regions', 'Not US', 'no_adult', 'no_episodes'), Supporto: 16.86%
# Itemset: ('(29.0, 53.0]_minutes', 'tvseries_related', 'no_episodes', '1_country', 'no_adult'), Supporto: 16.82%
# Itemset: ('(1994.8, 2024.0]_year', 'Not US', 'good_rated', '1_country', 'no_adult'), Supporto: 16.80%
# Itemset: ('US', 'genre_Comedy/Family', '1_regions', 'no_episodes', '1_country'), Supporto: 16.78%
# Itemset: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', '1_regions', 'no_episodes', '1_country'), Supporto: 16.73%
# Itemset: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 16.72%
# Itemset: ('Reviews', 'Not US', '1_regions', 'no_episodes', '1_country'), Supporto: 16.69%
# Itemset: ('tvseries_related', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 16.65%
# Itemset: ('tvseries_related', 'genre_Comedy/Family', '1_regions', '1_country', 'no_adult'), Supporto: 16.62%
# Itemset: ('US', 'genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 16.53%
# Itemset: ('Reviews', 'Not US', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 16.51%
# Itemset: ('Reviews', 'genre_Comedy/Family', 'Not US', '1_country', 'no_adult'), Supporto: 16.50%
# Itemset: ('US', 'good_rated', '1_regions', 'no_episodes', 'no_adult'), Supporto: 16.46%
# Itemset: ('(1.7910000000000001, 2.773]_votes', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 16.46%
# Itemset: ('US', 'good_rated', '1_regions', 'no_episodes', '1_country'), Supporto: 16.41%
# Itemset: ('tvseries_related', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 16.38%
# Itemset: ('tvseries_related', 'Reviews', '1_regions', '1_country', 'no_adult'), Supporto: 16.36%
# Itemset: ('US', 'good_rated', '1_regions', '1_country', 'no_adult'), Supporto: 16.29%
# Itemset: ('(1.933, 24.333]_regions', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 16.27%
# Itemset: ('Reviews', 'genre_Comedy/Family', '(1994.8, 2024.0]_year', '1_country', 'no_adult'), Supporto: 16.23%
# Itemset: ('Reviews', 'Not US', 'good_rated', '1_country', 'no_adult'), Supporto: 16.22%
# Itemset: ('(29.0, 53.0]_minutes', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 16.21%
# Itemset: ('tvseries_related', 'US', '1_regions', '1_country', 'no_adult'), Supporto: 16.20%
# Itemset: ('tvseries_related', 'US', 'no_episodes', '1_country', 'no_adult'), Supporto: 15.99%
# Itemset: ('genre_Comedy/Family', 'Not US', '1_regions', '1_country', 'no_adult'), Supporto: 15.91%
# Itemset: ('tvseries_related', 'US', '1_regions', 'no_episodes', 'no_adult'), Supporto: 15.84%
# Itemset: ('tvseries_related', 'Reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 15.80%
# Itemset: ('movie', '(1.933, 24.333]_regions', 'No_reviews', '1_country', 'no_episodes'), Supporto: 15.79%
# Itemset: ('(0.0, 1.099]_images', 'Reviews', '1_regions', '1_country', 'no_adult'), Supporto: 15.77%
# Itemset: ('US', 'good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 15.72%
# Itemset: ('(0.0, 1.099]_images', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 15.64%
# Itemset: ('Not US', 'good_rated', '1_regions', '1_country', 'no_adult'), Supporto: 15.63%
# Itemset: ('movie', '(1.933, 24.333]_regions', 'No_reviews', '1_country', 'no_adult', 'no_episodes'), Supporto: 15.58%
# Itemset: ('(0.0, 1.099]_images', 'genre_Comedy/Family', '1_regions', '1_country', 'no_adult'), Supporto: 15.57%
# Itemset: ('genre_Comedy/Family', 'Not US', 'good_rated', '1_country', 'no_adult'), Supporto: 15.54%
# Itemset: ('tvseries_related', 'genre_Comedy/Family', '1_regions', 'no_episodes', 'no_adult'), Supporto: 15.53%
# Itemset: ('(1994.8, 2024.0]_year', 'Not US', '1_regions', 'no_episodes', 'no_adult'), Supporto: 15.50%
# Itemset: ('Reviews', 'genre_Comedy/Family', 'Not US', 'no_episodes', 'no_adult'), Supporto: 15.48%
# Itemset: ('(0.0, 1.099]_images', 'good_rated', '1_regions', '1_country', 'no_adult'), Supporto: 15.47%
# Itemset: ('Reviews', 'genre_Comedy/Family', '(1994.8, 2024.0]_year', 'no_episodes', 'no_adult'), Supporto: 15.45%
# Itemset: ('genre_Comedy/Family', '(1994.8, 2024.0]_year', 'Not US', '1_country', 'no_adult'), Supporto: 15.45%
# Itemset: ('US', '(1994.8, 2024.0]_year', '1_regions', 'no_episodes', 'no_adult'), Supporto: 15.43%
# ...
# Itemset: ('(0.0, 1.099]_images', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.57%
# Itemset: ('Reviews', 'genre_Comedy/Family', '1_regions', '1_country', 'no_adult'), Supporto: 20.28%
# Itemset: ('(0.0, 1.099]_images', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.19%
# Itemset: ('(1.933, 24.333]_regions', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.09%
# Itemset: ('genre_Drama/Crime', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.09%
#
# Closed itemsets (supporto=20.00, zmin=5):
# Itemset: ('genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 31.21%
# Itemset: ('good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 29.76%
# Itemset: ('(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 29.53%
# Itemset: ('Reviews', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 29.38%
# Itemset: ('genre_Comedy/Family', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 26.76%
# Itemset: ('US', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 25.73%
# Itemset: ('Not US', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 25.64%
# Itemset: ('Reviews', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 25.24%
# Itemset: ('tvseries_related', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.92%
# Itemset: ('Reviews', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.85%
# Itemset: ('genre_Comedy/Family', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.64%
# Itemset: ('(1994.8, 2024.0]_year', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.53%
# Itemset: ('genre_Comedy/Family', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.51%
# Itemset: ('(1994.8, 2024.0]_year', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.50%
# Itemset: ('Not US', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.41%
# Itemset: ('No_reviews', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.13%
# Itemset: ('Reviews', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 23.84%
# Itemset: ('(0.0, 1.099]_images', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 23.70%
# Itemset: ('movie', 'Not US', '1_country', 'no_adult', 'no_episodes'), Supporto: 22.83%
# Itemset: ('Reviews', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 22.72%
# Itemset: ('US', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 22.10%
# Itemset: ('US', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 22.03%
# Itemset: ('No_reviews', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 21.90%
# Itemset: ('genre_Drama/Crime', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 21.54%
# Itemset: ('movie', '(1.933, 24.333]_regions', '1_country', 'no_adult', 'no_episodes'), Supporto: 21.52%
# Itemset: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 21.25%
# Itemset: ('US', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 21.21%
# Itemset: ('Reviews', '(1994.8, 2024.0]_year', '1_regions', '1_country', 'no_adult'), Supporto: 20.95%
# Itemset: ('No_reviews', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.76%
# Itemset: ('genre_Drama/Crime', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.75%
# Itemset: ('movie', 'No_reviews', '1_country', 'no_adult', 'no_episodes'), Supporto: 20.59%
# Itemset: ('(0.0, 1.099]_images', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.57%
# Itemset: ('Reviews', 'genre_Comedy/Family', '1_regions', '1_country', 'no_adult'), Supporto: 20.28%
# Itemset: ('(0.0, 1.099]_images', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.19%
# Itemset: ('(1.933, 24.333]_regions', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.09%
# Itemset: ('genre_Drama/Crime', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.09%
#
# Frequent itemsets (supporto=20.00, zmin=5):
# Itemset: ('genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 31.21%
# Itemset: ('good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 29.76%
# Itemset: ('(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 29.53%
# Itemset: ('Reviews', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 29.38%
# Itemset: ('genre_Comedy/Family', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 26.76%
# Itemset: ('US', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 25.73%
# Itemset: ('Not US', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 25.64%
# Itemset: ('Reviews', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 25.24%
# Itemset: ('tvseries_related', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.92%
# Itemset: ('Reviews', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.85%
# Itemset: ('genre_Comedy/Family', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.64%
# Itemset: ('(1994.8, 2024.0]_year', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.53%
# Itemset: ('genre_Comedy/Family', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.51%
# Itemset: ('(1994.8, 2024.0]_year', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.50%
# Itemset: ('Not US', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.41%
# Itemset: ('No_reviews', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 24.13%
# Itemset: ('Reviews', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult'), Supporto: 23.84%
# Itemset: ('(0.0, 1.099]_images', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 23.70%
# Itemset: ('movie', 'Not US', '1_country', 'no_adult', 'no_episodes'), Supporto: 22.83%
# Itemset: ('Reviews', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 22.72%
# Itemset: ('US', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 22.10%
# Itemset: ('US', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 22.03%
# Itemset: ('No_reviews', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 21.90%
# Itemset: ('genre_Drama/Crime', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 21.54%
# Itemset: ('movie', '(1.933, 24.333]_regions', '1_country', 'no_adult', 'no_episodes'), Supporto: 21.52%
# Itemset: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult'), Supporto: 21.25%
# Itemset: ('US', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 21.21%
# Itemset: ('Reviews', '(1994.8, 2024.0]_year', '1_regions', '1_country', 'no_adult'), Supporto: 20.95%
# Itemset: ('No_reviews', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.76%
# Itemset: ('genre_Drama/Crime', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.75%
# Itemset: ('movie', 'No_reviews', '1_country', 'no_adult', 'no_episodes'), Supporto: 20.59%
# Itemset: ('(0.0, 1.099]_images', 'good_rated', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.57%
# Itemset: ('Reviews', 'genre_Comedy/Family', '1_regions', '1_country', 'no_adult'), Supporto: 20.28%
# Itemset: ('(0.0, 1.099]_images', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.19%
# Itemset: ('genre_Drama/Crime', 'No_reviews', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.09%
# Itemset: ('(1.933, 24.333]_regions', 'Not US', 'no_episodes', '1_country', 'no_adult'), Supporto: 20.09%
#
# Massimal itemsets (supporto=20.00, zmin=6):
#
# Closed itemsets (supporto=20.00, zmin=6):
#
# Frequent itemsets (supporto=20.00, zmin=6):
#
# Massimal itemsets (supporto=20.00, zmin=7):
#
# Closed itemsets (supporto=20.00, zmin=7):
#
# Frequent itemsets (supporto=20.00, zmin=7):
#
# Massimal itemsets (supporto=20.00, zmin=8):
#
# Closed itemsets (supporto=20.00, zmin=8):
#
# Frequent itemsets (supporto=20.00, zmin=8):
#
# Massimal itemsets (supporto=20.00, zmin=9):
#
# Closed itemsets (supporto=20.00, zmin=9):
#
# Frequent itemsets (supporto=20.00, zmin=9):
#
# Massimal itemsets (supporto=20.00, zmin=10):
#
# Closed itemsets (supporto=20.00, zmin=10):
#
# Frequent itemsets (supporto=20.00, zmin=10):
#
# Massimal itemsets (supporto=20.00, zmin=11):
#
# Closed itemsets (supporto=20.00, zmin=11):
#
# Frequent itemsets (supporto=20.00, zmin=11):
#
# Massimal itemsets (supporto=20.00, zmin=12):
#
# Closed itemsets (supporto=20.00, zmin=12):
#
# Frequent itemsets (supporto=20.00, zmin=12):
#
# Massimal itemsets (supporto=20.00, zmin=13):
#
# Closed itemsets (supporto=20.00, zmin=13):
#
# Frequent itemsets (supporto=20.00, zmin=13):
#
# Massimal itemsets (supporto=20.00, zmin=14):
#
# Closed itemsets (supporto=20.00, zmin=14):
#
# Frequent itemsets (supporto=20.00, zmin=14):
#
# Massimal itemsets (supporto=20.00, zmin=15):
#
# Closed itemsets (supporto=20.00, zmin=15):
#
# Frequent itemsets (supporto=20.00, zmin=15):
#
# Massimal itemsets (supporto=20.00, zmin=16):
#
# Closed itemsets (supporto=20.00, zmin=16):
#
# Frequent itemsets (supporto=20.00, zmin=16):
#
# Massimal itemsets (supporto=20.00, zmin=17):
#
# Closed itemsets (supporto=20.00, zmin=17):
#
# Frequent itemsets (supporto=20.00, zmin=17):
#
# Massimal itemsets (supporto=30.00, zmin=5):
# Itemset: ('genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 31.21%
#
# Closed itemsets (supporto=30.00, zmin=5):
# Itemset: ('genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 31.21%
#
# Frequent itemsets (supporto=30.00, zmin=5):
# Itemset: ('genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 31.21%
#
# Massimal itemsets (supporto=30.00, zmin=6):
#
# Closed itemsets (supporto=30.00, zmin=6):
#
# Frequent itemsets (supporto=30.00, zmin=6):
#
# Massimal itemsets (supporto=30.00, zmin=7):
#
# Closed itemsets (supporto=30.00, zmin=7):
#
# Frequent itemsets (supporto=30.00, zmin=7):
#
# Massimal itemsets (supporto=30.00, zmin=8):
#
# Closed itemsets (supporto=30.00, zmin=8):
#
# Frequent itemsets (supporto=30.00, zmin=8):
#
# Massimal itemsets (supporto=30.00, zmin=9):
#
# Closed itemsets (supporto=30.00, zmin=9):
#
# Frequent itemsets (supporto=30.00, zmin=9):
#
# Massimal itemsets (supporto=30.00, zmin=10):
#
# Closed itemsets (supporto=30.00, zmin=10):
#
# Frequent itemsets (supporto=30.00, zmin=10):
#
# Massimal itemsets (supporto=30.00, zmin=11):
#
# Closed itemsets (supporto=30.00, zmin=11):
#
# Frequent itemsets (supporto=30.00, zmin=11):
#
# Massimal itemsets (supporto=30.00, zmin=12):
#
# Closed itemsets (supporto=30.00, zmin=12):
#
# Frequent itemsets (supporto=30.00, zmin=12):
#
# Massimal itemsets (supporto=30.00, zmin=13):
#
# Closed itemsets (supporto=30.00, zmin=13):
#
# Frequent itemsets (supporto=30.00, zmin=13):
#
# Massimal itemsets (supporto=30.00, zmin=14):
#
# Closed itemsets (supporto=30.00, zmin=14):
#
# Frequent itemsets (supporto=30.00, zmin=14):
#
# Massimal itemsets (supporto=30.00, zmin=15):
#
# Closed itemsets (supporto=30.00, zmin=15):
#
# Frequent itemsets (supporto=30.00, zmin=15):
#
# Massimal itemsets (supporto=30.00, zmin=16):
#
# Closed itemsets (supporto=30.00, zmin=16):
#
# Frequent itemsets (supporto=30.00, zmin=16):
#
# Massimal itemsets (supporto=30.00, zmin=17):
#
# Closed itemsets (supporto=30.00, zmin=17):
#
# Frequent itemsets (supporto=30.00, zmin=17):
#
# Massimal itemsets (supporto=40.00, zmin=5):
#
# Closed itemsets (supporto=40.00, zmin=5):
#
# Frequent itemsets (supporto=40.00, zmin=5):
#
# Massimal itemsets (supporto=40.00, zmin=6):
#
# Closed itemsets (supporto=40.00, zmin=6):
#
# Frequent itemsets (supporto=40.00, zmin=6):
#
# Massimal itemsets (supporto=40.00, zmin=7):
#
# Closed itemsets (supporto=40.00, zmin=7):
#
# Frequent itemsets (supporto=40.00, zmin=7):
#
# Massimal itemsets (supporto=40.00, zmin=8):
#
# Closed itemsets (supporto=40.00, zmin=8):
#
# Frequent itemsets (supporto=40.00, zmin=8):
#
# Massimal itemsets (supporto=40.00, zmin=9):
#
# Closed itemsets (supporto=40.00, zmin=9):
#
# Frequent itemsets (supporto=40.00, zmin=9):
#
# Massimal itemsets (supporto=40.00, zmin=10):
#
# Closed itemsets (supporto=40.00, zmin=10):
#
# Frequent itemsets (supporto=40.00, zmin=10):
#
# Massimal itemsets (supporto=40.00, zmin=11):
#
# Closed itemsets (supporto=40.00, zmin=11):
#
# Frequent itemsets (supporto=40.00, zmin=11):
#
# Massimal itemsets (supporto=40.00, zmin=12):
#
# Closed itemsets (supporto=40.00, zmin=12):
#
# Frequent itemsets (supporto=40.00, zmin=12):
#
# Massimal itemsets (supporto=40.00, zmin=13):
#
# Closed itemsets (supporto=40.00, zmin=13):
#
# Frequent itemsets (supporto=40.00, zmin=13):
#
# Massimal itemsets (supporto=40.00, zmin=14):
#
# Closed itemsets (supporto=40.00, zmin=14):
#
# Frequent itemsets (supporto=40.00, zmin=14):
#
# Massimal itemsets (supporto=40.00, zmin=15):
#
# Closed itemsets (supporto=40.00, zmin=15):
#
# Frequent itemsets (supporto=40.00, zmin=15):
#
# Massimal itemsets (supporto=40.00, zmin=16):
#
# Closed itemsets (supporto=40.00, zmin=16):
#
# Frequent itemsets (supporto=40.00, zmin=16):
#
# Massimal itemsets (supporto=40.00, zmin=17):
#
# Closed itemsets (supporto=40.00, zmin=17):
#
# Frequent itemsets (supporto=40.00, zmin=17):
#
# Massimal itemsets (supporto=50.00, zmin=5):
#
# Closed itemsets (supporto=50.00, zmin=5):
#
# Frequent itemsets (supporto=50.00, zmin=5):
#
# Massimal itemsets (supporto=50.00, zmin=6):
#
# Closed itemsets (supporto=50.00, zmin=6):
#
# Frequent itemsets (supporto=50.00, zmin=6):
#
# Massimal itemsets (supporto=50.00, zmin=7):
#
# Closed itemsets (supporto=50.00, zmin=7):
#
# Frequent itemsets (supporto=50.00, zmin=7):
#
# Massimal itemsets (supporto=50.00, zmin=8):
#
# Closed itemsets (supporto=50.00, zmin=8):
#
# Frequent itemsets (supporto=50.00, zmin=8):
#
# Massimal itemsets (supporto=50.00, zmin=9):
#
# Closed itemsets (supporto=50.00, zmin=9):
#
# Frequent itemsets (supporto=50.00, zmin=9):
#
# Massimal itemsets (supporto=50.00, zmin=10):
#
# Closed itemsets (supporto=50.00, zmin=10):
#
# Frequent itemsets (supporto=50.00, zmin=10):
#
# Massimal itemsets (supporto=50.00, zmin=11):
#
# Closed itemsets (supporto=50.00, zmin=11):
#
# Frequent itemsets (supporto=50.00, zmin=11):
#
# Massimal itemsets (supporto=50.00, zmin=12):
#
# Closed itemsets (supporto=50.00, zmin=12):
#
# Frequent itemsets (supporto=50.00, zmin=12):
#
# Massimal itemsets (supporto=50.00, zmin=13):
#
# Closed itemsets (supporto=50.00, zmin=13):
#
# Frequent itemsets (supporto=50.00, zmin=13):
#
# Massimal itemsets (supporto=50.00, zmin=14):
#
# Closed itemsets (supporto=50.00, zmin=14):
#
# Frequent itemsets (supporto=50.00, zmin=14):
#
# Massimal itemsets (supporto=50.00, zmin=15):
#
# Closed itemsets (supporto=50.00, zmin=15):
#
# Frequent itemsets (supporto=50.00, zmin=15):
#
# Massimal itemsets (supporto=50.00, zmin=16):
#
# Closed itemsets (supporto=50.00, zmin=16):
#
# Frequent itemsets (supporto=50.00, zmin=16):
#
# Massimal itemsets (supporto=50.00, zmin=17):
#
# Closed itemsets (supporto=50.00, zmin=17):
#
# Frequent itemsets (supporto=50.00, zmin=17):
#
# Top 3 Closed Itemsets by Support:
# Itemset: ('genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 31.21%
# Itemset: ('good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 29.76%
# Itemset: ('(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 29.53%
#
# Top 3 Maximal Itemsets by Support:
# Itemset: ('genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 31.21%
# Itemset: ('good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 29.76%
# Itemset: ('(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 29.53%
#
# Top 3 Frequent Itemsets by Support:
# Itemset: ('genre_Comedy/Family', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 31.21%
# Itemset: ('good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 29.76%
# Itemset: ('(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult'), Supporto: 29.53%

# %% [markdown]
# ### Rules
# if the target is association rules:
#                 a list of rules (i.e. tuples with two or more elements),
#                 each consisting of a head/consequent item, a tuple with
#                 a body/antecedent item set, and the values selected by
#                 the parameter 'report', which may be combined into a
#                 tuple or a list if report[0] is '(' or '[', respectively.

# %%
conf = 60
supp = 20
zmin = 4

rules = fpgrowth(X, target="r", supp=supp, zmin=zmin, conf=conf, report="aScl")
rules_df = pd.DataFrame(
    rules,
    columns=[
        "consequent",
        "antecedent",
        "abs_support",
        "%_support",
        "confidence",
        "lift",
    ],
)


rules_df = rules_df.sort_values(by="lift", axis=0, ascending=False) #stampato in questo modo l'elenco è troncato e non scrollabile

pd.set_option('display.max_colwidth', None)

# Convertiamo il DataFrame in HTML e lo rendiamo scrollabile
display(HTML(rules_df.to_html(notebook=True, border=0)
             .replace('<table', '<table style="display:block; height:400px; overflow:auto;"')))


rules_df.shape
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table style="display:block; height:400px; overflow:auto;" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>consequent</th>
#       <th>antecedent</th>
#       <th>abs_support</th>
#       <th>%_support</th>
#       <th>confidence</th>
#       <th>lift</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1162</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, no_episodes, 1_country, no_adult)</td>
#       <td>2214</td>
#       <td>13.902669</td>
#       <td>0.654255</td>
#       <td>4.218225</td>
#     </tr>
#     <tr>
#       <th>1163</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, no_episodes, 1_country)</td>
#       <td>2216</td>
#       <td>13.915228</td>
#       <td>0.654073</td>
#       <td>4.217051</td>
#     </tr>
#     <tr>
#       <th>1161</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, no_episodes, no_adult)</td>
#       <td>2285</td>
#       <td>14.348509</td>
#       <td>0.651926</td>
#       <td>4.203206</td>
#     </tr>
#     <tr>
#       <th>1164</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, no_episodes)</td>
#       <td>2287</td>
#       <td>14.361068</td>
#       <td>0.651753</td>
#       <td>4.202089</td>
#     </tr>
#     <tr>
#       <th>1159</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, 1_country, no_adult)</td>
#       <td>2214</td>
#       <td>13.902669</td>
#       <td>0.635476</td>
#       <td>4.097151</td>
#     </tr>
#     <tr>
#       <th>1160</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, 1_country)</td>
#       <td>2216</td>
#       <td>13.915228</td>
#       <td>0.635321</td>
#       <td>4.096149</td>
#     </tr>
#     <tr>
#       <th>1158</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, no_adult)</td>
#       <td>2285</td>
#       <td>14.348509</td>
#       <td>0.630519</td>
#       <td>4.065187</td>
#     </tr>
#     <tr>
#       <th>1156</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, no_episodes, 1_country, no_adult)</td>
#       <td>2252</td>
#       <td>14.141287</td>
#       <td>0.601817</td>
#       <td>3.880137</td>
#     </tr>
#     <tr>
#       <th>1157</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, no_episodes, 1_country)</td>
#       <td>2254</td>
#       <td>14.153846</td>
#       <td>0.601548</td>
#       <td>3.878401</td>
#     </tr>
#     <tr>
#       <th>1142</th>
#       <td>(90.0, 570.0]_minutes</td>
#       <td>(movie, genre_Drama/Crime, no_adult)</td>
#       <td>2052</td>
#       <td>12.885400</td>
#       <td>0.625229</td>
#       <td>2.629196</td>
#     </tr>
#     <tr>
#       <th>1144</th>
#       <td>(90.0, 570.0]_minutes</td>
#       <td>(movie, genre_Drama/Crime, no_episodes, no_adult)</td>
#       <td>2052</td>
#       <td>12.885400</td>
#       <td>0.625229</td>
#       <td>2.629196</td>
#     </tr>
#     <tr>
#       <th>1146</th>
#       <td>(90.0, 570.0]_minutes</td>
#       <td>(movie, genre_Drama/Crime, no_episodes)</td>
#       <td>2057</td>
#       <td>12.916797</td>
#       <td>0.624279</td>
#       <td>2.625204</td>
#     </tr>
#     <tr>
#       <th>1132</th>
#       <td>movie</td>
#       <td>((90.0, 570.0]_minutes, no_episodes, no_adult)</td>
#       <td>3333</td>
#       <td>20.929356</td>
#       <td>0.956385</td>
#       <td>2.480525</td>
#     </tr>
#     <tr>
#       <th>960</th>
#       <td>(29.0, 53.0]_minutes</td>
#       <td>(tvseries_related, (1994.8, 2024.0]_year, 1_country)</td>
#       <td>2318</td>
#       <td>14.555730</td>
#       <td>0.639978</td>
#       <td>2.402557</td>
#     </tr>
#     <tr>
#       <th>958</th>
#       <td>(29.0, 53.0]_minutes</td>
#       <td>(tvseries_related, (1994.8, 2024.0]_year, 1_country, no_adult)</td>
#       <td>2307</td>
#       <td>14.486656</td>
#       <td>0.639767</td>
#       <td>2.401766</td>
#     </tr>
#     <tr>
#       <th>956</th>
#       <td>(29.0, 53.0]_minutes</td>
#       <td>(tvseries_related, (1994.8, 2024.0]_year, no_adult)</td>
#       <td>2415</td>
#       <td>15.164835</td>
#       <td>0.638720</td>
#       <td>2.397835</td>
#     </tr>
#     <tr>
#       <th>963</th>
#       <td>(29.0, 53.0]_minutes</td>
#       <td>(tvseries_related, Reviews, 1_country)</td>
#       <td>2083</td>
#       <td>13.080063</td>
#       <td>0.631595</td>
#       <td>2.371086</td>
#     </tr>
#     <tr>
#       <th>962</th>
#       <td>(29.0, 53.0]_minutes</td>
#       <td>(tvseries_related, Reviews, 1_country, no_adult)</td>
#       <td>2073</td>
#       <td>13.017268</td>
#       <td>0.630666</td>
#       <td>2.367600</td>
#     </tr>
#     <tr>
#       <th>961</th>
#       <td>(29.0, 53.0]_minutes</td>
#       <td>(tvseries_related, Reviews, no_adult)</td>
#       <td>2149</td>
#       <td>13.494505</td>
#       <td>0.629651</td>
#       <td>2.363790</td>
#     </tr>
#     <tr>
#       <th>1129</th>
#       <td>movie</td>
#       <td>((90.0, 570.0]_minutes, 1_country, no_adult)</td>
#       <td>2902</td>
#       <td>18.222920</td>
#       <td>0.906026</td>
#       <td>2.349912</td>
#     </tr>
#     <tr>
#       <th>936</th>
#       <td>tvseries_related</td>
#       <td>((29.0, 53.0]_minutes, 1_country, no_adult)</td>
#       <td>3610</td>
#       <td>22.668760</td>
#       <td>0.897340</td>
#       <td>2.311199</td>
#     </tr>
#     <tr>
#       <th>937</th>
#       <td>(29.0, 53.0]_minutes</td>
#       <td>(tvseries_related, 1_country, no_adult)</td>
#       <td>3610</td>
#       <td>22.668760</td>
#       <td>0.614259</td>
#       <td>2.306005</td>
#     </tr>
#     <tr>
#       <th>944</th>
#       <td>(29.0, 53.0]_minutes</td>
#       <td>(tvseries_related, 1_regions, no_adult)</td>
#       <td>2900</td>
#       <td>18.210361</td>
#       <td>0.603915</td>
#       <td>2.267173</td>
#     </tr>
#     <tr>
#       <th>948</th>
#       <td>(29.0, 53.0]_minutes</td>
#       <td>(tvseries_related, 1_regions, 1_country)</td>
#       <td>2781</td>
#       <td>17.463108</td>
#       <td>0.601557</td>
#       <td>2.258322</td>
#     </tr>
#     <tr>
#       <th>946</th>
#       <td>(29.0, 53.0]_minutes</td>
#       <td>(tvseries_related, 1_regions, 1_country, no_adult)</td>
#       <td>2772</td>
#       <td>17.406593</td>
#       <td>0.601302</td>
#       <td>2.257361</td>
#     </tr>
#     <tr>
#       <th>940</th>
#       <td>(29.0, 53.0]_minutes</td>
#       <td>(tvseries_related, no_episodes, no_adult)</td>
#       <td>2806</td>
#       <td>17.620094</td>
#       <td>0.601243</td>
#       <td>2.257141</td>
#     </tr>
#     <tr>
#       <th>952</th>
#       <td>(29.0, 53.0]_minutes</td>
#       <td>(tvseries_related, good_rated, 1_country, no_adult)</td>
#       <td>2360</td>
#       <td>14.819466</td>
#       <td>0.600815</td>
#       <td>2.255534</td>
#     </tr>
#     <tr>
#       <th>950</th>
#       <td>(29.0, 53.0]_minutes</td>
#       <td>(tvseries_related, good_rated, no_adult)</td>
#       <td>2479</td>
#       <td>15.566719</td>
#       <td>0.600678</td>
#       <td>2.255022</td>
#     </tr>
#     <tr>
#       <th>954</th>
#       <td>(29.0, 53.0]_minutes</td>
#       <td>(tvseries_related, good_rated, 1_country)</td>
#       <td>2361</td>
#       <td>14.825746</td>
#       <td>0.600458</td>
#       <td>2.254194</td>
#     </tr>
#     <tr>
#       <th>939</th>
#       <td>tvseries_related</td>
#       <td>((29.0, 53.0]_minutes, no_episodes, no_adult)</td>
#       <td>2806</td>
#       <td>17.620094</td>
#       <td>0.863650</td>
#       <td>2.224427</td>
#     </tr>
#     <tr>
#       <th>895</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, No_reviews, no_episodes, no_adult)</td>
#       <td>2920</td>
#       <td>18.335950</td>
#       <td>0.809313</td>
#       <td>2.099072</td>
#     </tr>
#     <tr>
#       <th>903</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, No_reviews, no_episodes)</td>
#       <td>2954</td>
#       <td>18.549451</td>
#       <td>0.799892</td>
#       <td>2.074638</td>
#     </tr>
#     <tr>
#       <th>900</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, No_reviews, no_episodes, 1_country)</td>
#       <td>2514</td>
#       <td>15.786499</td>
# (1165, 6)

# %%
specific_title_type = 'other'  # Sostituisci con il valore che vuoi cercare

# Filtra il DataFrame per il valore specifico della colonna 'grouped_titleType'
filtered_rules = rules_df[rules_df['consequent'].apply(lambda x: specific_title_type in x)]

# Ordina i risultati per il valore di 'lift' in modo decrescente
filtered_rules_sorted = filtered_rules.sort_values(by="lift", axis=0, ascending=False)

# Estrai la regola con il lift più alto
top_rule = filtered_rules_sorted.iloc[0] if not filtered_rules_sorted.empty else None

if top_rule is not None:
    print("La regola con il lift più alto per '{}' è:".format(specific_title_type))
    print(f"Antecedente: {top_rule['antecedent']}")
    print(f"Conseguente: {top_rule['consequent']}")
    print(f"Lift: {top_rule['lift']}")
    print(f"Confidence: {top_rule['confidence']}%")
    print(f"Supporto assoluto: {top_rule['abs_support']}")
    print(f"Supporto percentuale: {top_rule['%_support']}%")
else:
    print(f"Nessuna regola trovata per il valore '{specific_title_type}'.")
# Out:
# Nessuna regola trovata per il valore 'other'.

# %% [markdown]
# PROVA CLASSIFICATION PER I TITLETYPES

# %%
# Estrai tutti i valori distinti dalla colonna 'titleType'
unique_title_types = df['grouped_titleType'].dropna().unique()

# Filtra le regole che hanno 'titleType' come conseguente
title_type_rules_df = rules_df[rules_df["consequent"].isin(unique_title_types)]

# Convertiamo il DataFrame in HTML e lo rendiamo scrollabile
display(HTML(title_type_rules_df.to_html(notebook=True, border=0)
             .replace('<table', '<table style="display:block; height:400px; overflow:auto;"')))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table style="display:block; height:400px; overflow:auto;" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>consequent</th>
#       <th>antecedent</th>
#       <th>abs_support</th>
#       <th>%_support</th>
#       <th>confidence</th>
#       <th>lift</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1162</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, no_episodes, 1_country, no_adult)</td>
#       <td>2214</td>
#       <td>13.902669</td>
#       <td>0.654255</td>
#       <td>4.218225</td>
#     </tr>
#     <tr>
#       <th>1163</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, no_episodes, 1_country)</td>
#       <td>2216</td>
#       <td>13.915228</td>
#       <td>0.654073</td>
#       <td>4.217051</td>
#     </tr>
#     <tr>
#       <th>1161</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, no_episodes, no_adult)</td>
#       <td>2285</td>
#       <td>14.348509</td>
#       <td>0.651926</td>
#       <td>4.203206</td>
#     </tr>
#     <tr>
#       <th>1164</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, no_episodes)</td>
#       <td>2287</td>
#       <td>14.361068</td>
#       <td>0.651753</td>
#       <td>4.202089</td>
#     </tr>
#     <tr>
#       <th>1159</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, 1_country, no_adult)</td>
#       <td>2214</td>
#       <td>13.902669</td>
#       <td>0.635476</td>
#       <td>4.097151</td>
#     </tr>
#     <tr>
#       <th>1160</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, 1_country)</td>
#       <td>2216</td>
#       <td>13.915228</td>
#       <td>0.635321</td>
#       <td>4.096149</td>
#     </tr>
#     <tr>
#       <th>1158</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, no_adult)</td>
#       <td>2285</td>
#       <td>14.348509</td>
#       <td>0.630519</td>
#       <td>4.065187</td>
#     </tr>
#     <tr>
#       <th>1156</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, no_episodes, 1_country, no_adult)</td>
#       <td>2252</td>
#       <td>14.141287</td>
#       <td>0.601817</td>
#       <td>3.880137</td>
#     </tr>
#     <tr>
#       <th>1157</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, no_episodes, 1_country)</td>
#       <td>2254</td>
#       <td>14.153846</td>
#       <td>0.601548</td>
#       <td>3.878401</td>
#     </tr>
#     <tr>
#       <th>1132</th>
#       <td>movie</td>
#       <td>((90.0, 570.0]_minutes, no_episodes, no_adult)</td>
#       <td>3333</td>
#       <td>20.929356</td>
#       <td>0.956385</td>
#       <td>2.480525</td>
#     </tr>
#     <tr>
#       <th>1129</th>
#       <td>movie</td>
#       <td>((90.0, 570.0]_minutes, 1_country, no_adult)</td>
#       <td>2902</td>
#       <td>18.222920</td>
#       <td>0.906026</td>
#       <td>2.349912</td>
#     </tr>
#     <tr>
#       <th>936</th>
#       <td>tvseries_related</td>
#       <td>((29.0, 53.0]_minutes, 1_country, no_adult)</td>
#       <td>3610</td>
#       <td>22.668760</td>
#       <td>0.897340</td>
#       <td>2.311199</td>
#     </tr>
#     <tr>
#       <th>939</th>
#       <td>tvseries_related</td>
#       <td>((29.0, 53.0]_minutes, no_episodes, no_adult)</td>
#       <td>2806</td>
#       <td>17.620094</td>
#       <td>0.863650</td>
#       <td>2.224427</td>
#     </tr>
#     <tr>
#       <th>895</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, No_reviews, no_episodes, no_adult)</td>
#       <td>2920</td>
#       <td>18.335950</td>
#       <td>0.809313</td>
#       <td>2.099072</td>
#     </tr>
#     <tr>
#       <th>903</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, No_reviews, no_episodes)</td>
#       <td>2954</td>
#       <td>18.549451</td>
#       <td>0.799892</td>
#       <td>2.074638</td>
#     </tr>
#     <tr>
#       <th>900</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, No_reviews, no_episodes, 1_country)</td>
#       <td>2514</td>
#       <td>15.786499</td>
#       <td>0.780988</td>
#       <td>2.025608</td>
#     </tr>
#     <tr>
#       <th>874</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, Not US, no_episodes, no_adult)</td>
#       <td>2685</td>
#       <td>16.860283</td>
#       <td>0.739262</td>
#       <td>1.917386</td>
#     </tr>
#     <tr>
#       <th>883</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, Not US, no_episodes)</td>
#       <td>2708</td>
#       <td>17.004710</td>
#       <td>0.734672</td>
#       <td>1.905480</td>
#     </tr>
#     <tr>
#       <th>853</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, no_episodes, no_adult)</td>
#       <td>3961</td>
#       <td>24.872841</td>
#       <td>0.730004</td>
#       <td>1.893373</td>
#     </tr>
#     <tr>
#       <th>877</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, Not US, no_episodes, 1_country, no_adult)</td>
#       <td>2290</td>
#       <td>14.379906</td>
#       <td>0.715849</td>
#       <td>1.856660</td>
#     </tr>
#     <tr>
#       <th>1109</th>
#       <td>movie</td>
#       <td>((53.0, 90.0]_minutes, no_episodes, no_adult)</td>
#       <td>2422</td>
#       <td>15.208791</td>
#       <td>0.714244</td>
#       <td>1.852497</td>
#     </tr>
#     <tr>
#       <th>886</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, No_reviews, no_adult)</td>
#       <td>2920</td>
#       <td>18.335950</td>
#       <td>0.713762</td>
#       <td>1.851247</td>
#     </tr>
#     <tr>
#       <th>880</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, Not US, no_episodes, 1_country)</td>
#       <td>2310</td>
#       <td>14.505495</td>
#       <td>0.711426</td>
#       <td>1.845189</td>
#     </tr>
#     <tr>
#       <th>858</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, no_episodes, 1_country, no_adult)</td>
#       <td>3427</td>
#       <td>21.519623</td>
#       <td>0.709230</td>
#       <td>1.839493</td>
#     </tr>
#     <tr>
#       <th>862</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, no_episodes, 1_country)</td>
#       <td>3477</td>
#       <td>21.833595</td>
#       <td>0.701574</td>
#       <td>1.819636</td>
#     </tr>
#     <tr>
#       <th>889</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, No_reviews, 1_country, no_adult)</td>
#       <td>2481</td>
#       <td>15.579278</td>
#       <td>0.696323</td>
#       <td>1.806018</td>
#     </tr>
#     <tr>
#       <th>892</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, No_reviews, 1_country)</td>
#       <td>2514</td>
#       <td>15.786499</td>
#       <td>0.689334</td>
#       <td>1.787889</td>
#     </tr>
#     <tr>
#       <th>1110</th>
#       <td>movie</td>
#       <td>((53.0, 90.0]_minutes, no_episodes, 1_country)</td>
#       <td>2245</td>
#       <td>14.097331</td>
#       <td>0.665974</td>
#       <td>1.727304</td>
#     </tr>
#     <tr>
#       <th>1108</th>
#       <td>movie</td>
#       <td>((53.0, 90.0]_minutes, 1_country, no_adult)</td>
#       <td>2173</td>
#       <td>13.645212</td>
#       <td>0.663309</td>
#       <td>1.720390</td>
#     </tr>
#     <tr>
#       <th>829</th>
#       <td>movie</td>
#       <td>(No_reviews, Not US, no_episodes, no_adult)</td>
#       <td>2324</td>
#       <td>14.593407</td>
#       <td>0.657984</td>
#       <td>1.706579</td>
#     </tr>
#     <tr>
#       <th>830</th>
#       <td>movie</td>
#       <td>(No_reviews, Not US, no_episodes)</td>
#       <td>2337</td>
#       <td>14.675039</td>
#       <td>0.653158</td>
#       <td>1.694063</td>
#     </tr>
#     <tr>
#       <th>865</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, Not US, no_adult)</td>
#       <td>2685</td>
#       <td>16.860283</td>
#       <td>0.638677</td>
#       <td>1.656505</td>
#     </tr>
#     <tr>
#       <th>1155</th>
#       <td>movie</td>
#       <td>(low_rated, no_episodes, no_adult)</td>
#       <td>2110</td>
#       <td>13.249608</td>
#       <td>0.622603</td>
#       <td>1.614812</td>
#     </tr>
#     <tr>
#       <th>838</th>
#       <td>movie</td>
#       <td>(genre_Drama/Crime, Not US, no_episodes, no_adult)</td>
#       <td>2352</td>

# %%
# Supponiamo che 'rules' sia la lista di regole di associazione

# Itera su tutti i valori distinti
for title_type in unique_title_types:
    # Filtra le regole per il titolo corrente
    matching_rules = [r for r in rules if r[0] == title_type]
    
    # Se ci sono regole per questo titolo
    if matching_rules:
        print('\n')
        print(f"Regole per '{title_type}':")
        
        # Per ogni regola trovata
        for rule in matching_rules:
            consequent = rule[0]  # 'titleType'
            antecedent = rule[1]  # Le condizioni che portano a 'titleType'
            confidence = rule[4]
            print(f"  Conseguente: {consequent}")
            print(f"  Antecedente: {antecedent}")
            print(f"  Confidence: {confidence}")
            print("-" * 50)
# Out:
# Regole per 'tvseries_related':
#   Conseguente: tvseries_related
#   Antecedente: ('good_rated', '1_regions', 'no_adult')
#   Confidence: 0.6099585062240664
# --------------------------------------------------
#   Conseguente: tvseries_related
#   Antecedente: ('good_rated', '1_regions', '1_country', 'no_adult')
#   Confidence: 0.6106629942947078
# --------------------------------------------------
#   Conseguente: tvseries_related
#   Antecedente: ('US', '1_regions', 'no_adult')
#   Confidence: 0.6074389424154156
# --------------------------------------------------
#   Conseguente: tvseries_related
#   Antecedente: ('US', '1_regions', '1_country', 'no_adult')
#   Confidence: 0.6033676333021516
# --------------------------------------------------
#   Conseguente: tvseries_related
#   Antecedente: ('(29.0, 53.0]_minutes', '1_country', 'no_adult')
#   Confidence: 0.8973402933134477
# --------------------------------------------------
#   Conseguente: tvseries_related
#   Antecedente: ('(29.0, 53.0]_minutes', 'no_episodes', 'no_adult')
#   Confidence: 0.8636503539550631
# --------------------------------------------------
#
#
# Regole per 'movie':
#   Conseguente: movie
#   Antecedente: ('No_reviews', 'Not US', 'no_episodes', 'no_adult')
#   Confidence: 0.6579841449603624
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('No_reviews', 'Not US', 'no_episodes')
#   Confidence: 0.6531581889323644
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('genre_Drama/Crime', 'Not US', 'no_episodes', 'no_adult')
#   Confidence: 0.6204167765761013
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('genre_Drama/Crime', 'Not US', 'no_episodes')
#   Confidence: 0.6197368421052631
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('genre_Drama/Crime', 'No_reviews', 'no_episodes', 'no_adult')
#   Confidence: 0.6064356435643564
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('genre_Drama/Crime', 'No_reviews', 'no_episodes')
#   Confidence: 0.603157321720196
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', '1_country', 'no_adult')
#   Confidence: 0.6162560690523288
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'no_episodes', 'no_adult')
#   Confidence: 0.7300036859565057
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.7092301324503312
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'no_episodes', '1_country')
#   Confidence: 0.7015738498789347
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'Not US', 'no_adult')
#   Confidence: 0.6386774500475737
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'Not US', '1_country', 'no_adult')
#   Confidence: 0.615095353209777
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'Not US', '1_country')
#   Confidence: 0.6120826709062003
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'Not US', 'no_episodes', 'no_adult')
#   Confidence: 0.739262114537445
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'Not US', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.7158487027195999
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'Not US', 'no_episodes', '1_country')
#   Confidence: 0.7114259316291962
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'Not US', 'no_episodes')
#   Confidence: 0.7346717308735757
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'No_reviews', 'no_adult')
#   Confidence: 0.7137619164018577
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'No_reviews', '1_country', 'no_adult')
#   Confidence: 0.69632332304238
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'No_reviews', '1_country')
#   Confidence: 0.6893336989306279
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'No_reviews', 'no_episodes', 'no_adult')
#   Confidence: 0.8093126385809313
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'No_reviews', 'no_episodes', '1_country')
#   Confidence: 0.7809878844361603
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(1.933, 24.333]_regions', 'No_reviews', 'no_episodes')
#   Confidence: 0.7998916869753588
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(53.0, 90.0]_minutes', '1_country', 'no_adult')
#   Confidence: 0.6633089133089133
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(53.0, 90.0]_minutes', 'no_episodes', 'no_adult')
#   Confidence: 0.7142435859628428
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(53.0, 90.0]_minutes', 'no_episodes', '1_country')
#   Confidence: 0.6659744882824088
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(90.0, 570.0]_minutes', '1_country', 'no_adult')
#   Confidence: 0.9060256009990634
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('(90.0, 570.0]_minutes', 'no_episodes', 'no_adult')
#   Confidence: 0.9563845050215208
# --------------------------------------------------
#   Conseguente: movie
#   Antecedente: ('low_rated', 'no_episodes', 'no_adult')
#   Confidence: 0.6226025376217174
# --------------------------------------------------
#
#
# Regole per 'short':
#   Conseguente: short
#   Antecedente: ('(-0.001, 29.0]_minutes', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6018172100481026
# --------------------------------------------------
#   Conseguente: short
#   Antecedente: ('(-0.001, 29.0]_minutes', 'no_episodes', '1_country')
#   Confidence: 0.6015479049906592
# --------------------------------------------------
#   Conseguente: short
#   Antecedente: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', 'no_adult')
#   Confidence: 0.6305187637969095
# --------------------------------------------------
#   Conseguente: short
#   Antecedente: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', '1_country', 'no_adult')
#   Confidence: 0.6354764638346728
# --------------------------------------------------
#   Conseguente: short
#   Antecedente: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', '1_country')
#   Confidence: 0.6353211009174312
# --------------------------------------------------
#   Conseguente: short
#   Antecedente: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', 'no_episodes', 'no_adult')
#   Confidence: 0.651925820256776
# --------------------------------------------------
#   Conseguente: short
#   Antecedente: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6542553191489362
# --------------------------------------------------
#   Conseguente: short
#   Antecedente: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', 'no_episodes', '1_country')
#   Confidence: 0.654073199527745
# --------------------------------------------------
#   Conseguente: short
#   Antecedente: ('(-0.001, 29.0]_minutes', 'genre_Comedy/Family', 'no_episodes')
#   Confidence: 0.6517526360786549
# --------------------------------------------------

# %% [markdown]
# PROVA CLASSIFICATION PER GENRES

# %%
# Estrai tutti i generi attivi (le colonne binarie dei generi)
genre_columns = [col for col in df.columns if col.startswith('genre_')]

# Filtra le regole che hanno un genere come conseguente
genre_rules_df = rules_df[rules_df["consequent"].isin(genre_columns)]

# Convertiamo il DataFrame in HTML e lo rendiamo scrollabile
display(HTML(genre_rules_df.to_html(notebook=True, border=0)
             .replace('<table', '<table style="display:block; height:400px; overflow:auto;"')))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table style="display:block; height:400px; overflow:auto;" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>consequent</th>
#       <th>antecedent</th>
#       <th>abs_support</th>
#       <th>%_support</th>
#       <th>confidence</th>
#       <th>lift</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1048</th>
#       <td>genre_Comedy/Family</td>
#       <td>((-0.001, 29.0]_minutes, no_episodes, 1_country, no_adult)</td>
#       <td>3384</td>
#       <td>21.249608</td>
#       <td>0.904329</td>
#       <td>1.665870</td>
#     </tr>
#     <tr>
#       <th>1051</th>
#       <td>genre_Comedy/Family</td>
#       <td>((-0.001, 29.0]_minutes, no_episodes, 1_country)</td>
#       <td>3388</td>
#       <td>21.274725</td>
#       <td>0.904190</td>
#       <td>1.665613</td>
#     </tr>
#     <tr>
#       <th>1044</th>
#       <td>genre_Comedy/Family</td>
#       <td>((-0.001, 29.0]_minutes, no_episodes, no_adult)</td>
#       <td>3505</td>
#       <td>22.009419</td>
#       <td>0.901724</td>
#       <td>1.661070</td>
#     </tr>
#     <tr>
#       <th>1041</th>
#       <td>genre_Comedy/Family</td>
#       <td>((-0.001, 29.0]_minutes, 1_country, no_adult)</td>
#       <td>3484</td>
#       <td>21.877551</td>
#       <td>0.895170</td>
#       <td>1.648997</td>
#     </tr>
#     <tr>
#       <th>1143</th>
#       <td>genre_Drama/Crime</td>
#       <td>((90.0, 570.0]_minutes, movie, no_episodes, no_adult)</td>
#       <td>2052</td>
#       <td>12.885400</td>
#       <td>0.615662</td>
#       <td>1.463563</td>
#     </tr>
#     <tr>
#       <th>1141</th>
#       <td>genre_Drama/Crime</td>
#       <td>((90.0, 570.0]_minutes, movie, no_adult)</td>
#       <td>2052</td>
#       <td>12.885400</td>
#       <td>0.615662</td>
#       <td>1.463563</td>
#     </tr>
#     <tr>
#       <th>1145</th>
#       <td>genre_Drama/Crime</td>
#       <td>((90.0, 570.0]_minutes, movie, no_episodes)</td>
#       <td>2057</td>
#       <td>12.916797</td>
#       <td>0.610024</td>
#       <td>1.450161</td>
#     </tr>
#     <tr>
#       <th>1125</th>
#       <td>genre_Drama/Crime</td>
#       <td>((90.0, 570.0]_minutes, no_episodes, no_adult)</td>
#       <td>2102</td>
#       <td>13.199372</td>
#       <td>0.603156</td>
#       <td>1.433836</td>
#     </tr>
#     <tr>
#       <th>977</th>
#       <td>genre_Comedy/Family</td>
#       <td>((0.999, 17.0]_credits, no_episodes, 1_country, no_adult)</td>
#       <td>2326</td>
#       <td>14.605965</td>
#       <td>0.662301</td>
#       <td>1.220028</td>
#     </tr>
#     <tr>
#       <th>976</th>
#       <td>genre_Comedy/Family</td>
#       <td>((0.999, 17.0]_credits, no_episodes, no_adult)</td>
#       <td>2393</td>
#       <td>15.026688</td>
#       <td>0.655437</td>
#       <td>1.207384</td>
#     </tr>
#     <tr>
#       <th>355</th>
#       <td>genre_Comedy/Family</td>
#       <td>(Reviews, 1_regions, no_episodes, no_adult)</td>
#       <td>3156</td>
#       <td>19.817896</td>
#       <td>0.649116</td>
#       <td>1.195739</td>
#     </tr>
#     <tr>
#       <th>359</th>
#       <td>genre_Comedy/Family</td>
#       <td>(Reviews, 1_regions, no_episodes, 1_country, no_adult)</td>
#       <td>3034</td>
#       <td>19.051805</td>
#       <td>0.648429</td>
#       <td>1.194475</td>
#     </tr>
#     <tr>
#       <th>975</th>
#       <td>genre_Comedy/Family</td>
#       <td>((0.999, 17.0]_credits, 1_country, no_adult)</td>
#       <td>2470</td>
#       <td>15.510204</td>
#       <td>0.645752</td>
#       <td>1.189542</td>
#     </tr>
#     <tr>
#       <th>465</th>
#       <td>genre_Comedy/Family</td>
#       <td>(US, 1_regions, no_episodes, 1_country, no_adult)</td>
#       <td>2633</td>
#       <td>16.533752</td>
#       <td>0.642665</td>
#       <td>1.183857</td>
#     </tr>
#     <tr>
#       <th>463</th>
#       <td>genre_Comedy/Family</td>
#       <td>(US, 1_regions, no_episodes, no_adult)</td>
#       <td>2727</td>
#       <td>17.124019</td>
#       <td>0.637895</td>
#       <td>1.175069</td>
#     </tr>
#     <tr>
#       <th>367</th>
#       <td>genre_Comedy/Family</td>
#       <td>(Reviews, 1_regions, no_episodes)</td>
#       <td>3166</td>
#       <td>19.880691</td>
#       <td>0.637407</td>
#       <td>1.174171</td>
#     </tr>
#     <tr>
#       <th>363</th>
#       <td>genre_Comedy/Family</td>
#       <td>(Reviews, 1_regions, no_episodes, 1_country)</td>
#       <td>3044</td>
#       <td>19.114600</td>
#       <td>0.636554</td>
#       <td>1.172599</td>
#     </tr>
#     <tr>
#       <th>459</th>
#       <td>genre_Comedy/Family</td>
#       <td>(US, 1_regions, 1_country, no_adult)</td>
#       <td>2707</td>
#       <td>16.998430</td>
#       <td>0.633068</td>
#       <td>1.166178</td>
#     </tr>
#     <tr>
#       <th>978</th>
#       <td>genre_Comedy/Family</td>
#       <td>((0.999, 17.0]_credits, no_episodes, 1_country)</td>
#       <td>2364</td>
#       <td>14.844584</td>
#       <td>0.632255</td>
#       <td>1.164680</td>
#     </tr>
#     <tr>
#       <th>342</th>
#       <td>genre_Comedy/Family</td>
#       <td>(Reviews, 1_regions, no_adult)</td>
#       <td>3356</td>
#       <td>21.073783</td>
#       <td>0.628700</td>
#       <td>1.158131</td>
#     </tr>
#     <tr>
#       <th>457</th>
#       <td>genre_Comedy/Family</td>
#       <td>(US, 1_regions, no_adult)</td>
#       <td>2805</td>
#       <td>17.613815</td>
#       <td>0.628501</td>
#       <td>1.157765</td>
#     </tr>
#     <tr>
#       <th>347</th>
#       <td>genre_Comedy/Family</td>
#       <td>(Reviews, 1_regions, 1_country, no_adult)</td>
#       <td>3229</td>
#       <td>20.276295</td>
#       <td>0.627478</td>
#       <td>1.155880</td>
#     </tr>
#     <tr>
#       <th>106</th>
#       <td>genre_Comedy/Family</td>
#       <td>(1_regions, no_episodes, 1_country, no_adult)</td>
#       <td>4970</td>
#       <td>31.208791</td>
#       <td>0.622417</td>
#       <td>1.146558</td>
#     </tr>
#     <tr>
#       <th>628</th>
#       <td>genre_Comedy/Family</td>
#       <td>((0.0, 1.099]_images, 1_regions, no_episodes, 1_country, no_adult)</td>
#       <td>2347</td>
#       <td>14.737834</td>
#       <td>0.621887</td>
#       <td>1.145581</td>
#     </tr>
#     <tr>
#       <th>627</th>
#       <td>genre_Comedy/Family</td>
#       <td>((0.0, 1.099]_images, 1_regions, no_episodes, no_adult)</td>
#       <td>2445</td>
#       <td>15.353218</td>
#       <td>0.621663</td>
#       <td>1.145168</td>
#     </tr>
#     <tr>
#       <th>629</th>
#       <td>genre_Comedy/Family</td>
#       <td>((0.0, 1.099]_images, 1_regions, no_episodes, 1_country)</td>
#       <td>2347</td>
#       <td>14.737834</td>
#       <td>0.621393</td>
#       <td>1.144671</td>
#     </tr>
#     <tr>
#       <th>631</th>
#       <td>genre_Comedy/Family</td>
#       <td>((0.0, 1.099]_images, 1_regions, no_episodes)</td>
#       <td>2445</td>
#       <td>15.353218</td>
#       <td>0.621189</td>
#       <td>1.144296</td>
#     </tr>
#     <tr>
#       <th>336</th>
#       <td>genre_Comedy/Family</td>
#       <td>(Reviews, no_episodes, 1_country, no_adult)</td>
#       <td>3957</td>
#       <td>24.847724</td>
#       <td>0.620901</td>
#       <td>1.143764</td>
#     </tr>
#     <tr>
#       <th>382</th>
#       <td>genre_Comedy/Family</td>
#       <td>(Reviews, (1994.8, 2024.0]_year, no_episodes, 1_country, no_adult)</td>
#       <td>2356</td>
#       <td>14.794349</td>
#       <td>0.620490</td>
#       <td>1.143008</td>
#     </tr>
#     <tr>
#       <th>467</th>
#       <td>genre_Comedy/Family</td>
#       <td>(US, 1_regions, no_episodes, 1_country)</td>
#       <td>2672</td>
#       <td>16.778650</td>
#       <td>0.620385</td>
#       <td>1.142815</td>
#     </tr>
#     <tr>
#       <th>1011</th>
#       <td>genre_Comedy/Family</td>
#       <td>((1.7910000000000001, 2.773]_votes, no_episodes, 1_country, no_adult)</td>
#       <td>2148</td>
#       <td>13.488226</td>
#       <td>0.620271</td>
#       <td>1.142605</td>
#     </tr>
#     <tr>
#       <th>101</th>
#       <td>genre_Comedy/Family</td>
#       <td>(1_regions, no_episodes, no_adult)</td>
#       <td>5153</td>
#       <td>32.357928</td>
#       <td>0.619798</td>
#       <td>1.141733</td>
#     </tr>
#     <tr>
#       <th>332</th>
#       <td>genre_Comedy/Family</td>
#       <td>(Reviews, no_episodes, no_adult)</td>
#       <td>4129</td>

# %%
# Supponiamo che 'rules' sia la lista di regole di associazione

# Itera su tutti i valori distinti
for year in genre_columns:
    # Filtra le regole per il titolo corrente
    matching_rules = [r for r in rules if r[0] == year]
    
    # Se ci sono regole per questo titolo
    if matching_rules:
        print('\n')
        print(f"Regole per '{year}':")
        
        # Per ogni regola trovata
        for rule in matching_rules:
            consequent = rule[0]  # 'titleType'
            antecedent = rule[1]  # Le condizioni che portano a 'titleType'
            confidence = rule[4]
            print(f"  Conseguente: {consequent}")
            print(f"  Antecedente: {antecedent}")
            print(f"  Confidence: {confidence}")
            print("-" * 50)
# Out:
# Regole per 'genre_Comedy/Family':
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('1_regions', '1_country', 'no_adult')
#   Confidence: 0.6075817296545328
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('1_regions', 'no_episodes', 'no_adult')
#   Confidence: 0.6197979312003848
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('1_regions', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6224170319348779
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('1_regions', 'no_episodes', '1_country')
#   Confidence: 0.609049005337215
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('good_rated', '1_regions', '1_country', 'no_adult')
#   Confidence: 0.6002360810544953
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('good_rated', '1_regions', 'no_episodes', 'no_adult')
#   Confidence: 0.6084410339256866
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('good_rated', '1_regions', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6107594936708861
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Not US', '1_regions', 'no_episodes', 'no_adult')
#   Confidence: 0.6006437236939837
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Not US', '1_regions', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6010802469135802
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(1994.8, 2024.0]_year', '1_regions', 'no_episodes', 'no_adult')
#   Confidence: 0.6047503045066992
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(1994.8, 2024.0]_year', '1_regions', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6083351052519669
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', 'no_episodes', 'no_adult')
#   Confidence: 0.6181137724550898
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6209006747214812
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', 'no_episodes', '1_country')
#   Confidence: 0.6092959042797975
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', '1_regions', 'no_adult')
#   Confidence: 0.6286998875983515
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', '1_regions', '1_country', 'no_adult')
#   Confidence: 0.6274776525456666
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', '1_regions', '1_country')
#   Confidence: 0.6160136934195511
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', '1_regions', 'no_episodes', 'no_adult')
#   Confidence: 0.6491155902920609
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', '1_regions', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6484291515281043
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', '1_regions', 'no_episodes', '1_country')
#   Confidence: 0.6365537432036805
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', '1_regions', 'no_episodes')
#   Confidence: 0.63740688544393
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', 'good_rated', 'no_episodes', 'no_adult')
#   Confidence: 0.6142932212296374
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', 'good_rated', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6177446102819237
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', 'good_rated', 'no_episodes', '1_country')
#   Confidence: 0.6077633007600435
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', 'good_rated', 'no_episodes')
#   Confidence: 0.6043870967741936
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', '(1994.8, 2024.0]_year', 'no_episodes', 'no_adult')
#   Confidence: 0.6168505516549649
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', '(1994.8, 2024.0]_year', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.620489860416118
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', '(1994.8, 2024.0]_year', 'no_episodes', '1_country')
#   Confidence: 0.6131879543094496
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', '(1994.8, 2024.0]_year', 'no_episodes')
#   Confidence: 0.6094908551655956
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', '(1994.8, 2024.0]_year', '1_regions', 'no_adult')
#   Confidence: 0.6152293048745313
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', '(1994.8, 2024.0]_year', '1_regions', '1_country', 'no_adult')
#   Confidence: 0.6146239136949355
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', '(1994.8, 2024.0]_year', '1_regions', '1_country')
#   Confidence: 0.6066686338152848
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('Reviews', '(1994.8, 2024.0]_year', '1_regions')
#   Confidence: 0.6073863636363637
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('US', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6004776526782668
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('US', '1_regions', 'no_adult')
#   Confidence: 0.6285010082903877
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('US', '1_regions', '1_country', 'no_adult')
#   Confidence: 0.633068288119738
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('US', '1_regions', '1_country')
#   Confidence: 0.6113955041175161
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('US', '1_regions', 'no_episodes', 'no_adult')
#   Confidence: 0.6378947368421053
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('US', '1_regions', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6426653649011472
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('US', '1_regions', 'no_episodes', '1_country')
#   Confidence: 0.6203854190852102
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('US', '1_regions', 'no_episodes')
#   Confidence: 0.6163956337714414
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('US', 'good_rated', '1_country', 'no_adult')
#   Confidence: 0.6014372581536761
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('US', 'good_rated', 'no_episodes', 'no_adult')
#   Confidence: 0.6043225270157938
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('US', 'good_rated', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.613084665482534
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(0.0, 1.099]_images', '1_regions', 'no_adult')
#   Confidence: 0.606857679661813
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(0.0, 1.099]_images', '1_regions', '1_country', 'no_adult')
#   Confidence: 0.6062606994375153
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(0.0, 1.099]_images', '1_regions', '1_country')
#   Confidence: 0.6058162267839687
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(0.0, 1.099]_images', '1_regions', 'no_episodes', 'no_adult')
#   Confidence: 0.6216628527841342
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(0.0, 1.099]_images', '1_regions', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6218865924748278
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(0.0, 1.099]_images', '1_regions', 'no_episodes', '1_country')
#   Confidence: 0.6213926396611067
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(0.0, 1.099]_images', '1_regions', 'no_episodes')
#   Confidence: 0.6211890243902439
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(0.0, 1.099]_images', 'Reviews', 'no_episodes', 'no_adult')
#   Confidence: 0.6046296296296296
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(0.0, 1.099]_images', 'Reviews', 'no_episodes')
#   Confidence: 0.6043786617329633
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(0.999, 17.0]_credits', '1_country', 'no_adult')
#   Confidence: 0.6457516339869281
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(0.999, 17.0]_credits', 'no_episodes', 'no_adult')
#   Confidence: 0.6554368666118872
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(0.999, 17.0]_credits', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6623006833712984
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(0.999, 17.0]_credits', 'no_episodes', '1_country')
#   Confidence: 0.6322546135330303
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(1.7910000000000001, 2.773]_votes', '1_country', 'no_adult')
#   Confidence: 0.6010957474563006
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(1.7910000000000001, 2.773]_votes', 'no_episodes', 'no_adult')
#   Confidence: 0.6168795113825652
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(1.7910000000000001, 2.773]_votes', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6202714409471557
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(1.7910000000000001, 2.773]_votes', 'no_episodes', '1_country')
#   Confidence: 0.6027094277025159
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(1.7910000000000001, 2.773]_votes', 'Reviews', '1_country', 'no_adult')
#   Confidence: 0.6004360012457178
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(-0.001, 29.0]_minutes', '1_country', 'no_adult')
#   Confidence: 0.895169578622816
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(-0.001, 29.0]_minutes', 'no_episodes', 'no_adult')
#   Confidence: 0.9017236943658349
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(-0.001, 29.0]_minutes', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.9043292357028327
# --------------------------------------------------
#   Conseguente: genre_Comedy/Family
#   Antecedente: ('(-0.001, 29.0]_minutes', 'no_episodes', '1_country')
#   Confidence: 0.904190018681612
# --------------------------------------------------
#
#
# Regole per 'genre_Drama/Crime':
#   Conseguente: genre_Drama/Crime
#   Antecedente: ('(90.0, 570.0]_minutes', 'no_episodes', 'no_adult')
#   Confidence: 0.6031563845050215
# --------------------------------------------------
#   Conseguente: genre_Drama/Crime
#   Antecedente: ('(90.0, 570.0]_minutes', 'movie', 'no_adult')
#   Confidence: 0.6156615661566157
# --------------------------------------------------
#   Conseguente: genre_Drama/Crime
#   Antecedente: ('(90.0, 570.0]_minutes', 'movie', 'no_episodes', 'no_adult')
#   Confidence: 0.6156615661566157
# --------------------------------------------------
#   Conseguente: genre_Drama/Crime
#   Antecedente: ('(90.0, 570.0]_minutes', 'movie', 'no_episodes')
#   Confidence: 0.6100237247924081
# --------------------------------------------------

# %% [markdown]
# PROVA CLASSIFICATION PER YEAR

# %%
# Estrai tutti i valori distinti dalla colonna 'titleType'
unique_year = df['Year_bin'].dropna().unique()

# Filtra le regole che hanno 'titleType' come conseguente
year_rules_df = rules_df[rules_df["consequent"].isin(unique_year)]

# Visualizza la tabella con le regole filtrate
# Convertiamo il DataFrame in HTML e lo rendiamo scrollabile
display(HTML(year_rules_df.to_html(notebook=True, border=0)
             .replace('<table', '<table style="display:block; height:400px; overflow:auto;"')))
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table style="display:block; height:400px; overflow:auto;" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>consequent</th>
#       <th>antecedent</th>
#       <th>abs_support</th>
#       <th>%_support</th>
#       <th>confidence</th>
#       <th>lift</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1074</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>((66.0, 1885.0]_credits, no_episodes, no_adult)</td>
#       <td>2306</td>
#       <td>14.480377</td>
#       <td>0.696046</td>
#       <td>1.260895</td>
#     </tr>
#     <tr>
#       <th>1073</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>((66.0, 1885.0]_credits, 1_country, no_adult)</td>
#       <td>2409</td>
#       <td>15.127159</td>
#       <td>0.695640</td>
#       <td>1.260159</td>
#     </tr>
#     <tr>
#       <th>790</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(tvseries_related, Reviews, 1_country)</td>
#       <td>2245</td>
#       <td>14.097331</td>
#       <td>0.680716</td>
#       <td>1.233124</td>
#     </tr>
#     <tr>
#       <th>788</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(tvseries_related, Reviews, 1_country, no_adult)</td>
#       <td>2234</td>
#       <td>14.028257</td>
#       <td>0.679647</td>
#       <td>1.231189</td>
#     </tr>
#     <tr>
#       <th>786</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(tvseries_related, Reviews, no_adult)</td>
#       <td>2304</td>
#       <td>14.467818</td>
#       <td>0.675066</td>
#       <td>1.222890</td>
#     </tr>
#     <tr>
#       <th>991</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(genre_Doc/Others, 1_country, no_adult)</td>
#       <td>2275</td>
#       <td>14.285714</td>
#       <td>0.654865</td>
#       <td>1.186295</td>
#     </tr>
#     <tr>
#       <th>295</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(Reviews, 1_regions, no_adult)</td>
#       <td>3467</td>
#       <td>21.770801</td>
#       <td>0.649494</td>
#       <td>1.176566</td>
#     </tr>
#     <tr>
#       <th>300</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(Reviews, 1_regions, 1_country, no_adult)</td>
#       <td>3337</td>
#       <td>20.954474</td>
#       <td>0.648465</td>
#       <td>1.174702</td>
#     </tr>
#     <tr>
#       <th>304</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(Reviews, 1_regions, 1_country)</td>
#       <td>3389</td>
#       <td>21.281005</td>
#       <td>0.644542</td>
#       <td>1.167595</td>
#     </tr>
#     <tr>
#       <th>992</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(genre_Doc/Others, no_episodes, no_adult)</td>
#       <td>2071</td>
#       <td>13.004710</td>
#       <td>0.643168</td>
#       <td>1.165106</td>
#     </tr>
#     <tr>
#       <th>308</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(Reviews, 1_regions, no_episodes, no_adult)</td>
#       <td>3124</td>
#       <td>19.616954</td>
#       <td>0.642534</td>
#       <td>1.163958</td>
#     </tr>
#     <tr>
#       <th>312</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(Reviews, 1_regions, no_episodes, 1_country, no_adult)</td>
#       <td>3001</td>
#       <td>18.844584</td>
#       <td>0.641376</td>
#       <td>1.161861</td>
#     </tr>
#     <tr>
#       <th>1028</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>((1.7910000000000001, 2.773]_votes, Reviews, no_adult)</td>
#       <td>2129</td>
#       <td>13.368917</td>
#       <td>0.640686</td>
#       <td>1.160610</td>
#     </tr>
#     <tr>
#       <th>959</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>((29.0, 53.0]_minutes, tvseries_related, 1_country)</td>
#       <td>2318</td>
#       <td>14.555730</td>
#       <td>0.639978</td>
#       <td>1.159328</td>
#     </tr>
#     <tr>
#       <th>957</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>((29.0, 53.0]_minutes, tvseries_related, 1_country, no_adult)</td>
#       <td>2307</td>
#       <td>14.486656</td>
#       <td>0.639058</td>
#       <td>1.157661</td>
#     </tr>
#     <tr>
#       <th>955</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>((29.0, 53.0]_minutes, tvseries_related, no_adult)</td>
#       <td>2415</td>
#       <td>15.164835</td>
#       <td>0.638720</td>
#       <td>1.157049</td>
#     </tr>
#     <tr>
#       <th>320</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(Reviews, 1_regions, no_episodes)</td>
#       <td>3168</td>
#       <td>19.893250</td>
#       <td>0.637810</td>
#       <td>1.155399</td>
#     </tr>
#     <tr>
#       <th>316</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(Reviews, 1_regions, no_episodes, 1_country)</td>
#       <td>3044</td>
#       <td>19.114600</td>
#       <td>0.636554</td>
#       <td>1.153125</td>
#     </tr>
#     <tr>
#       <th>1029</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>((1.7910000000000001, 2.773]_votes, Reviews, 1_country, no_adult)</td>
#       <td>2043</td>
#       <td>12.828885</td>
#       <td>0.636250</td>
#       <td>1.152575</td>
#     </tr>
#     <tr>
#       <th>386</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(Reviews, genre_Comedy/Family, 1_regions, no_adult)</td>
#       <td>2133</td>
#       <td>13.394035</td>
#       <td>0.635578</td>
#       <td>1.151357</td>
#     </tr>
#     <tr>
#       <th>388</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(Reviews, genre_Comedy/Family, 1_regions, 1_country, no_adult)</td>
#       <td>2051</td>
#       <td>12.879121</td>
#       <td>0.635181</td>
#       <td>1.150638</td>
#     </tr>
#     <tr>
#       <th>392</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(Reviews, genre_Comedy/Family, 1_regions)</td>
#       <td>2138</td>
#       <td>13.425432</td>
#       <td>0.635175</td>
#       <td>1.150628</td>
#     </tr>
#     <tr>
#       <th>390</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(Reviews, genre_Comedy/Family, 1_regions, 1_country)</td>
#       <td>2056</td>
#       <td>12.910518</td>
#       <td>0.634764</td>
#       <td>1.149882</td>
#     </tr>
#     <tr>
#       <th>1030</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>((1.7910000000000001, 2.773]_votes, Reviews, 1_country)</td>
#       <td>2081</td>
#       <td>13.067504</td>
#       <td>0.633293</td>
#       <td>1.147217</td>
#     </tr>
#     <tr>
#       <th>932</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>((29.0, 53.0]_minutes, 1_country, no_adult)</td>
#       <td>2538</td>
#       <td>15.937206</td>
#       <td>0.630872</td>
#       <td>1.142833</td>
#     </tr>
#     <tr>
#       <th>1005</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>((1.7910000000000001, 2.773]_votes, 1_country, no_adult)</td>
#       <td>2399</td>
#       <td>15.064364</td>
#       <td>0.625881</td>
#       <td>1.133790</td>
#     </tr>
#     <tr>
#       <th>84</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(Not US, 1_regions, 1_country)</td>
#       <td>2729</td>
#       <td>17.136578</td>
#       <td>0.619664</td>
#       <td>1.122529</td>
#     </tr>
#     <tr>
#       <th>1006</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>((1.7910000000000001, 2.773]_votes, no_episodes, no_adult)</td>
#       <td>2230</td>
#       <td>14.003140</td>
#       <td>0.619100</td>
#       <td>1.121508</td>
#     </tr>
#     <tr>
#       <th>82</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(Not US, 1_regions, no_adult)</td>
#       <td>2790</td>
#       <td>17.519623</td>
#       <td>0.618900</td>
#       <td>1.121144</td>
#     </tr>
#     <tr>
#       <th>83</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(Not US, 1_regions, 1_country, no_adult)</td>
#       <td>2691</td>
#       <td>16.897959</td>
#       <td>0.618621</td>
#       <td>1.120639</td>
#     </tr>
#     <tr>
#       <th>993</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>(genre_Doc/Others, no_episodes, 1_country)</td>
#       <td>2072</td>
#       <td>13.010989</td>
#       <td>0.617034</td>
#       <td>1.117764</td>
#     </tr>
#     <tr>
#       <th>1007</th>
#       <td>(1994.8, 2024.0]_year</td>
#       <td>((1.7910000000000001, 2.773]_votes, no_episodes, 1_country, no_adult)</td>
#       <td>2126</td>
#       <td>13.350078</td>
#       <td>0.613919</td>
#       <td>1.112121</td>
#     </tr>
#     <tr>
#       <th>754</th>
#       <td>(1994.8, 2024.0]_year</td>

# %%
# Supponiamo che 'rules' sia la lista di regole di associazione

# Itera su tutti i valori distinti
for year in unique_year:
    # Filtra le regole per il titolo corrente
    matching_rules = [r for r in rules if r[0] == year]
    
    # Se ci sono regole per questo titolo
    if matching_rules:
        print('\n')
        print(f"Regole per '{year}':")
        
        # Per ogni regola trovata
        for rule in matching_rules:
            consequent = rule[0]  # 'titleType'
            antecedent = rule[1]  # Le condizioni che portano a 'titleType'
            confidence = rule[4]
            print(f"  Conseguente: {consequent}")
            print(f"  Antecedente: {antecedent}")
            print(f"  Confidence: {confidence}")
            print("-" * 50)
# Out:
# Regole per '(1994.8, 2024.0]_year':
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Not US', '1_regions', 'no_adult')
#   Confidence: 0.6188997338065662
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Not US', '1_regions', '1_country', 'no_adult')
#   Confidence: 0.6186206896551724
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Not US', '1_regions', '1_country')
#   Confidence: 0.6196639418710264
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Not US', '1_regions', 'no_episodes', 'no_adult')
#   Confidence: 0.6112899232483288
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Not US', '1_regions', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6111111111111112
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Not US', '1_regions', 'no_episodes', '1_country')
#   Confidence: 0.6118872237744476
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Not US', '1_regions', 'no_episodes')
#   Confidence: 0.6118855465884079
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', '1_country', 'no_adult')
#   Confidence: 0.611562150055991
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', '1_regions', 'no_adult')
#   Confidence: 0.6494941925814912
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', '1_regions', '1_country', 'no_adult')
#   Confidence: 0.6484648270501361
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', '1_regions', '1_country')
#   Confidence: 0.6445416508178015
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', '1_regions', 'no_episodes', 'no_adult')
#   Confidence: 0.6425339366515838
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', '1_regions', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6413763624706134
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', '1_regions', 'no_episodes', '1_country')
#   Confidence: 0.6365537432036805
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', '1_regions', 'no_episodes')
#   Confidence: 0.6378095429836924
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', 'good_rated', 'no_adult')
#   Confidence: 0.6051330350835884
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', 'good_rated', '1_country', 'no_adult')
#   Confidence: 0.6071163825055597
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', 'good_rated', '1_country')
#   Confidence: 0.6050072921730676
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', 'genre_Comedy/Family', 'no_adult')
#   Confidence: 0.603448275862069
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', 'genre_Comedy/Family', '1_country', 'no_adult')
#   Confidence: 0.6034080298786181
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', 'genre_Comedy/Family', '1_country')
#   Confidence: 0.6027906976744186
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', 'genre_Comedy/Family', '1_regions', 'no_adult')
#   Confidence: 0.6355780691299165
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', 'genre_Comedy/Family', '1_regions', '1_country', 'no_adult')
#   Confidence: 0.6351811706410654
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', 'genre_Comedy/Family', '1_regions', '1_country')
#   Confidence: 0.6347638159925904
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('Reviews', 'genre_Comedy/Family', '1_regions')
#   Confidence: 0.6351752822341058
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('(0.0, 1.099]_images', 'Reviews', 'no_adult')
#   Confidence: 0.600720421169299
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('tvseries_related', '1_country', 'no_adult')
#   Confidence: 0.6135783563042368
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('tvseries_related', 'Reviews', 'no_adult')
#   Confidence: 0.6750659244066803
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('tvseries_related', 'Reviews', '1_country', 'no_adult')
#   Confidence: 0.6796470946151506
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('tvseries_related', 'Reviews', '1_country')
#   Confidence: 0.6807155852031535
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('(29.0, 53.0]_minutes', '1_country', 'no_adult')
#   Confidence: 0.6308724832214765
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('(29.0, 53.0]_minutes', 'no_episodes', 'no_adult')
#   Confidence: 0.6044936903662665
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('(29.0, 53.0]_minutes', 'tvseries_related', 'no_adult')
#   Confidence: 0.6387199153663052
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('(29.0, 53.0]_minutes', 'tvseries_related', '1_country', 'no_adult')
#   Confidence: 0.6390581717451523
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('(29.0, 53.0]_minutes', 'tvseries_related', '1_country')
#   Confidence: 0.6399779127553837
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('genre_Doc/Others', '1_country', 'no_adult')
#   Confidence: 0.6548647092688543
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('genre_Doc/Others', 'no_episodes', 'no_adult')
#   Confidence: 0.643167701863354
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('genre_Doc/Others', 'no_episodes', '1_country')
#   Confidence: 0.6170339487790352
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('(1.7910000000000001, 2.773]_votes', '1_country', 'no_adult')
#   Confidence: 0.625880511348813
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('(1.7910000000000001, 2.773]_votes', 'no_episodes', 'no_adult')
#   Confidence: 0.6191004997223765
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('(1.7910000000000001, 2.773]_votes', 'no_episodes', '1_country', 'no_adult')
#   Confidence: 0.6139185677158533
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('(1.7910000000000001, 2.773]_votes', 'no_episodes', '1_country')
#   Confidence: 0.6126624274260437
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('(1.7910000000000001, 2.773]_votes', 'Reviews', 'no_adult')
#   Confidence: 0.6406861269936804
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('(1.7910000000000001, 2.773]_votes', 'Reviews', '1_country', 'no_adult')
#   Confidence: 0.6362503892868265
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('(1.7910000000000001, 2.773]_votes', 'Reviews', '1_country')
#   Confidence: 0.6332927571515521
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('(66.0, 1885.0]_credits', '1_country', 'no_adult')
#   Confidence: 0.6956396188276062
# --------------------------------------------------
#   Conseguente: (1994.8, 2024.0]_year
#   Antecedente: ('(66.0, 1885.0]_credits', 'no_episodes', 'no_adult')
#   Confidence: 0.6960458798671899
# --------------------------------------------------

# %% [markdown]
# GRAFICI RULES

# %%
len_r = []
min_sup = 1
max_sup = 26
min_conf = 50
max_conf = 91
for i in range(min_sup, max_sup):  # support
    len_r_wrt_i = []
    for j in range(min_conf, max_conf):  # confidence
        rules = fpgrowth(X, target="r", supp=i, zmin=zmin, conf=j, report="aScl")
        len_r_wrt_i.append(len(rules))  # study your characteristics/properties here

    len_r.append(len_r_wrt_i)
len_r = np.array(len_r)

# len_r sarà una matrice 2D in cui:
# ogni riga rappresenta un valore di supporto.
# ogni colonna rappresenta un valore di confidenza.
# ogni elemento nella matrice rappresenta il numero di regole generate per una combinazione di supporto e confidenza.

# %%
sns.heatmap(len_r, cmap="Blues", fmt='g')
plt.yticks(np.arange(0, max_sup-min_sup +1, 5), np.arange(min_sup, max_sup+1,5 ))
plt.xticks(np.arange(0, max_conf-min_conf+1, 5), np.arange(min_conf, max_conf+1, 5))
plt.xlabel("%confidence")
plt.ylabel("%support")
plt.show()

# %%
# Specifica il valore di supporto desiderato
specific_support = 20  # Modifica con il valore desiderato
support_index = specific_support - min_sup  # Calcola l'indice corrispondente nel range di supporto

# Prendi i dati per il supporto specificato
rules_per_conf = len_r[support_index]  # Estrae i numeri di regole per il supporto fissato


# Somma il numero di regole generate per ogni valore di confidenza
conf_values = list(range(min_conf, max_conf))

# Crea un istogramma
plt.figure(figsize=(10, 6))
plt.bar(conf_values, rules_per_conf, color='skyblue', edgecolor='black')
plt.xlabel("Confidence (%)")
plt.ylabel("Number of Rules")
# plt.title("Number of Rules by Confidence")
plt.title(f"Number of Rules by Confidence (Support = {specific_support}%)")  # Se si vuole specificare il supporto nel titolo 
# plt.xticks(conf_values, rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
# Specifica il valore di supporto desiderato
specific_support = 20  # Modifica con il valore desiderato
support_index = specific_support - min_sup  # Calcola l'indice corrispondente nel range di supporto

# Prendi i dati per il supporto specificato
rules_per_conf = len_r[support_index]  # Estrae i numeri di regole per il supporto fissato

# Somma il numero di regole generate per ogni valore di confidenza
conf_values = list(range(min_conf, max_conf))

# Crea un istogramma
plt.figure(figsize=(10, 6))
# plt.hist(conf_values, weights=rules_per_conf, bins=len(conf_values), color='skyblue', edgecolor='black', rwidth=0.85)
plt.hist(conf_values, weights=rules_per_conf, color='skyblue', edgecolor='black')
plt.xlabel("Confidence (%)")
plt.ylabel("Number of Rules")
# plt.title("Number of Rules by Confidence")
plt.title(f"Number of Rules by Confidence (Support = {specific_support}%)")  # Se si vuole specificare il supporto nel titolo
# plt.xticks(conf_values, rotation=45)
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
min_conf_values = range(50, 100, 5)  # Confidence minima dal 10% al 90%
num_rules = []

for conf in min_conf_values:
    rules = fpgrowth(X, target="r", supp=supp, zmin=zmin, conf=conf, report="aScl")
    num_rules.append(len(rules))

# Grafico
plt.plot(min_conf_values, num_rules, marker='o', color='blue')
plt.xlabel('Minimum Confidence (%)')
plt.ylabel('Number of Rules')
plt.title('Number of Rules vs Minimum Confidence')
plt.grid()
plt.show()

# %%
#  Genera le regole per il supporto e il range di confidenza specificato
rules_for_lift = []
for conf in range(min_conf, max_conf):
    rules = fpgrowth(X, target="r", supp=specific_support, zmin=zmin, conf=conf, report="aScl")
    rules_for_lift.extend(rules)  # Aggiungi tutte le regole generate per questo confidenza

# Estrai i valori di lift da tutte le regole generate
lift_values = [rule[5] for rule in rules_for_lift]  # Assumendo che il lift sia nell'indice 5

# Raggruppa i valori di lift in bin per l'istogramma
bins = np.linspace(min(lift_values), max(lift_values), 20)  # Dividi in 20 intervalli
lift_hist, bin_edges = np.histogram(lift_values, bins=bins)

# Crea l'istogramma
plt.figure(figsize=(10, 6))
plt.bar(
    (bin_edges[:-1] + bin_edges[1:]) / 2,  # Usa il centro di ogni bin
    lift_hist,
    width=np.diff(bin_edges),
    color="lightcoral",
    edgecolor="black",
    align="center"
)
plt.xlabel("Lift")
plt.ylabel("Number of Rules")
plt.title(f"Number of Rules by Lift (Support = {specific_support}%)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
# Specifica il valore di confidenza desiderato
specific_conf = 60  # Modifica con il valore desiderato
specific_support = 20  # Modifica con il supporto desiderato

# Genera le regole per il supporto e il valore di confidenza specifico
rules_for_lift = fpgrowth(X, target="r", supp=specific_support, zmin=zmin, conf=specific_conf, report="aScl")

# Estrai i valori di lift da tutte le regole generate
lift_values = [rule[5] for rule in rules_for_lift]  # Assumendo che il lift sia nell'indice 5

# Raggruppa i valori di lift in bin per l'istogramma
bins = np.linspace(min(lift_values), max(lift_values), 20)  # Dividi in 20 intervalli
lift_hist, bin_edges = np.histogram(lift_values, bins=bins)

# Crea l'istogramma
plt.figure(figsize=(10, 6))
plt.bar(
    (bin_edges[:-1] + bin_edges[1:]) / 2,  # Usa il centro di ogni bin
    lift_hist,
    width=np.diff(bin_edges),
    color="lightcoral",
    edgecolor="black",
    align="center"
)
plt.xlabel("Lift")
plt.ylabel("Number of Rules")
plt.title(f"Number of Rules by Lift (Support = {specific_support}%, Confidence = {specific_conf}%)")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %%
# Parametri
min_conf = 50
max_conf = 95
conf_step = 5
supp = 20  # Supporto fisso percentuale
zmin = 5   # Minimum itemset size

# Inizializza una lista per memorizzare i risultati
metrics_by_conf = []

# Ciclo sui valori di confidenza
for conf in range(min_conf, max_conf + 1, conf_step):
    # Genera le regole per il valore corrente di confidenza
    rules = fpgrowth(X, target="r", supp=supp, zmin=zmin, conf=conf, report="lcs")
    # Converti le regole in DataFrame
    rules_df = pd.DataFrame(rules, columns=["consequent", "antecedent", "lift", "confidence", "support"])
    # Filtra le regole con lift > 1.5
    rules_significant = rules_df[rules_df["lift"] > 1.5]
    
    # Calcola le metriche
    num_rules = len(rules_df)  # Numero totale di regole
    num_significant = len(rules_significant)  # Numero di regole con lift > 1.5
    avg_lift = rules_significant["lift"].mean() if num_significant > 0 else 0
    std_lift = rules_significant["lift"].std() if num_significant > 0 else 0
    max_lift = rules_significant["lift"].max() if num_significant > 0 else 0
    
    # Aggiungi i risultati alla lista
    metrics_by_conf.append({
        "conf": conf,
        "num_rules": num_rules,
        "num_significant": num_significant,
        "avg_lift": avg_lift,
        "std_lift": std_lift,
        "max_lift": max_lift,
    })

# Converti i risultati in DataFrame per analisi
metrics_df = pd.DataFrame(metrics_by_conf)

# Trova il conf con il massimo numero di regole significative
optimal_conf = metrics_df.loc[metrics_df["num_significant"].idxmax(), "conf"]

# Visualizza i risultati
print(f"Optimal Confidence Level: {optimal_conf}")
print(metrics_df)

# Creazione di due subplot
fig, axes = plt.subplots(2, 1, figsize=(12, 10), sharex=True)

# Primo subplot: Numero di regole significative
axes[0].plot(metrics_df["conf"], metrics_df["num_significant"], label="Number of Significant Rules (Lift > 1.5)", marker='o', color='blue')
axes[0].set_ylabel("Number of Rules")
axes[0].set_title("Number of Significant Rules by Confidence Level")
axes[0].legend()
axes[0].grid()

# Secondo subplot: Media del lift
axes[1].plot(metrics_df["conf"], metrics_df["avg_lift"], label="Average Lift", marker='s', color='green')
axes[1].set_xlabel("Confidence (%)")
axes[1].set_ylabel("Average Lift")
axes[1].set_title("Average Lift by Confidence Level")
axes[1].legend()
axes[1].grid()

# Mostra il grafico
plt.tight_layout()
plt.show()
# Out:
# Optimal Confidence Level: 50
#    conf  num_rules  num_significant  avg_lift  std_lift  max_lift
# 0    50       1026               85  2.097148  0.595005  4.218225
# 1    55        760               65  2.113709  0.679374  4.218225
# 2    60        407               39  2.114202  0.826092  4.218225
# 3    65        257               22  2.127536  0.859711  4.218225
# 4    70        208               14  1.830226  0.162547  2.099072
# 5    75        167               10  1.816444  0.192346  2.099072
# 6    80        142                5  1.714810  0.231835  2.099072
# 7    85        137                3  1.579010  0.075737  1.665870
# 8    90        104                1  1.665870       NaN  1.665870
# 9    95         64                0  0.000000  0.000000  0.000000

# %%
conf = 65
supp = 20  
zmin = 4

# Generazione delle regole
rules = fpgrowth(X, target="r", supp=supp, zmin=zmin, conf=conf, report="aScl")
rules_df = pd.DataFrame(
    rules,
    columns=[
        "consequent",
        "antecedent",
        "abs_support",
        "%_support",
        "confidence",
        "lift",
    ],
)

# Filtra le regole con lift > 1.5
rules_df = rules_df[rules_df["lift"] > 1.5]

# Ordina per lift decrescente
rules_df = rules_df.sort_values(by="lift", axis=0, ascending=False)

# Configura l'opzione per visualizzare colonne intere
pd.set_option('display.max_colwidth', None)

# Converti il DataFrame in HTML scrollabile
from IPython.core.display import display, HTML
display(HTML(rules_df.to_html(notebook=True, border=0)
             .replace('<table', '<table style="display:block; height:400px; overflow:auto;"')))

# Visualizza le dimensioni del DataFrame
rules_df.shape
# Out:
# C:\Users\tomma\AppData\Local\Temp\ipykernel_19368\3537926230.py:29: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython.display
#   from IPython.core.display import display, HTML
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table style="display:block; height:400px; overflow:auto;" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>consequent</th>
#       <th>antecedent</th>
#       <th>abs_support</th>
#       <th>%_support</th>
#       <th>confidence</th>
#       <th>lift</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>815</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, no_episodes, 1_country, no_adult)</td>
#       <td>2214</td>
#       <td>13.902669</td>
#       <td>0.654255</td>
#       <td>4.218225</td>
#     </tr>
#     <tr>
#       <th>816</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, no_episodes, 1_country)</td>
#       <td>2216</td>
#       <td>13.915228</td>
#       <td>0.654073</td>
#       <td>4.217051</td>
#     </tr>
#     <tr>
#       <th>814</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, no_episodes, no_adult)</td>
#       <td>2285</td>
#       <td>14.348509</td>
#       <td>0.651926</td>
#       <td>4.203206</td>
#     </tr>
#     <tr>
#       <th>817</th>
#       <td>short</td>
#       <td>((-0.001, 29.0]_minutes, genre_Comedy/Family, no_episodes)</td>
#       <td>2287</td>
#       <td>14.361068</td>
#       <td>0.651753</td>
#       <td>4.202089</td>
#     </tr>
#     <tr>
#       <th>799</th>
#       <td>movie</td>
#       <td>((90.0, 570.0]_minutes, no_episodes, no_adult)</td>
#       <td>3333</td>
#       <td>20.929356</td>
#       <td>0.956385</td>
#       <td>2.480525</td>
#     </tr>
#     <tr>
#       <th>796</th>
#       <td>movie</td>
#       <td>((90.0, 570.0]_minutes, 1_country, no_adult)</td>
#       <td>2902</td>
#       <td>18.222920</td>
#       <td>0.906026</td>
#       <td>2.349912</td>
#     </tr>
#     <tr>
#       <th>672</th>
#       <td>tvseries_related</td>
#       <td>((29.0, 53.0]_minutes, 1_country, no_adult)</td>
#       <td>3610</td>
#       <td>22.668760</td>
#       <td>0.897340</td>
#       <td>2.311199</td>
#     </tr>
#     <tr>
#       <th>674</th>
#       <td>tvseries_related</td>
#       <td>((29.0, 53.0]_minutes, no_episodes, no_adult)</td>
#       <td>2806</td>
#       <td>17.620094</td>
#       <td>0.863650</td>
#       <td>2.224427</td>
#     </tr>
#     <tr>
#       <th>647</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, No_reviews, no_episodes, no_adult)</td>
#       <td>2920</td>
#       <td>18.335950</td>
#       <td>0.809313</td>
#       <td>2.099072</td>
#     </tr>
#     <tr>
#       <th>655</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, No_reviews, no_episodes)</td>
#       <td>2954</td>
#       <td>18.549451</td>
#       <td>0.799892</td>
#       <td>2.074638</td>
#     </tr>
#     <tr>
#       <th>652</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, No_reviews, no_episodes, 1_country)</td>
#       <td>2514</td>
#       <td>15.786499</td>
#       <td>0.780988</td>
#       <td>2.025608</td>
#     </tr>
#     <tr>
#       <th>628</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, Not US, no_episodes, no_adult)</td>
#       <td>2685</td>
#       <td>16.860283</td>
#       <td>0.739262</td>
#       <td>1.917386</td>
#     </tr>
#     <tr>
#       <th>635</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, Not US, no_episodes)</td>
#       <td>2708</td>
#       <td>17.004710</td>
#       <td>0.734672</td>
#       <td>1.905480</td>
#     </tr>
#     <tr>
#       <th>637</th>
#       <td>(1.933, 24.333]_regions</td>
#       <td>(movie, No_reviews, no_adult)</td>
#       <td>2920</td>
#       <td>18.335950</td>
#       <td>0.759625</td>
#       <td>1.900257</td>
#     </tr>
#     <tr>
#       <th>646</th>
#       <td>(1.933, 24.333]_regions</td>
#       <td>(movie, No_reviews, no_episodes, no_adult)</td>
#       <td>2920</td>
#       <td>18.335950</td>
#       <td>0.759625</td>
#       <td>1.900257</td>
#     </tr>
#     <tr>
#       <th>614</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, no_episodes, no_adult)</td>
#       <td>3961</td>
#       <td>24.872841</td>
#       <td>0.730004</td>
#       <td>1.893373</td>
#     </tr>
#     <tr>
#       <th>640</th>
#       <td>(1.933, 24.333]_regions</td>
#       <td>(movie, No_reviews, 1_country, no_adult)</td>
#       <td>2481</td>
#       <td>15.579278</td>
#       <td>0.756633</td>
#       <td>1.892771</td>
#     </tr>
#     <tr>
#       <th>649</th>
#       <td>(1.933, 24.333]_regions</td>
#       <td>(movie, No_reviews, no_episodes, 1_country, no_adult)</td>
#       <td>2481</td>
#       <td>15.579278</td>
#       <td>0.756633</td>
#       <td>1.892771</td>
#     </tr>
#     <tr>
#       <th>654</th>
#       <td>(1.933, 24.333]_regions</td>
#       <td>(movie, No_reviews, no_episodes)</td>
#       <td>2954</td>
#       <td>18.549451</td>
#       <td>0.754727</td>
#       <td>1.888002</td>
#     </tr>
#     <tr>
#       <th>643</th>
#       <td>(1.933, 24.333]_regions</td>
#       <td>(movie, No_reviews, 1_country)</td>
#       <td>2514</td>
#       <td>15.786499</td>
#       <td>0.751120</td>
#       <td>1.878981</td>
#     </tr>
#     <tr>
#       <th>651</th>
#       <td>(1.933, 24.333]_regions</td>
#       <td>(movie, No_reviews, no_episodes, 1_country)</td>
#       <td>2514</td>
#       <td>15.786499</td>
#       <td>0.751120</td>
#       <td>1.878981</td>
#     </tr>
#     <tr>
#       <th>630</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, Not US, no_episodes, 1_country, no_adult)</td>
#       <td>2290</td>
#       <td>14.379906</td>
#       <td>0.715849</td>
#       <td>1.856660</td>
#     </tr>
#     <tr>
#       <th>785</th>
#       <td>movie</td>
#       <td>((53.0, 90.0]_minutes, no_episodes, no_adult)</td>
#       <td>2422</td>
#       <td>15.208791</td>
#       <td>0.714244</td>
#       <td>1.852497</td>
#     </tr>
#     <tr>
#       <th>638</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, No_reviews, no_adult)</td>
#       <td>2920</td>
#       <td>18.335950</td>
#       <td>0.713762</td>
#       <td>1.851247</td>
#     </tr>
#     <tr>
#       <th>632</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, Not US, no_episodes, 1_country)</td>
#       <td>2310</td>
#       <td>14.505495</td>
#       <td>0.711426</td>
#       <td>1.845189</td>
#     </tr>
#     <tr>
#       <th>618</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, no_episodes, 1_country, no_adult)</td>
#       <td>3427</td>
#       <td>21.519623</td>
#       <td>0.709230</td>
#       <td>1.839493</td>
#     </tr>
#     <tr>
#       <th>621</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, no_episodes, 1_country)</td>
#       <td>3477</td>
#       <td>21.833595</td>
#       <td>0.701574</td>
#       <td>1.819636</td>
#     </tr>
#     <tr>
#       <th>641</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, No_reviews, 1_country, no_adult)</td>
#       <td>2481</td>
#       <td>15.579278</td>
#       <td>0.696323</td>
#       <td>1.806018</td>
#     </tr>
#     <tr>
#       <th>644</th>
#       <td>movie</td>
#       <td>((1.933, 24.333]_regions, No_reviews, 1_country)</td>
#       <td>2514</td>
#       <td>15.786499</td>
#       <td>0.689334</td>
#       <td>1.787889</td>
#     </tr>
#     <tr>
#       <th>758</th>
#       <td>No_reviews</td>
#       <td>((5.056, 13.624]_votes, no_episodes, no_adult)</td>
#       <td>3336</td>
#       <td>20.948195</td>
#       <td>0.926924</td>
#       <td>1.781471</td>
#     </tr>
#     <tr>
#       <th>755</th>
#       <td>No_reviews</td>
#       <td>((5.056, 13.624]_votes, 1_country, no_adult)</td>
#       <td>3169</td>
#       <td>19.899529</td>
#       <td>0.918817</td>
#       <td>1.765890</td>
#     </tr>
#     <tr>
#       <th>712</th>
#       <td>Reviews</td>
#       <td>((1.7910000000000001, 2.773]_votes, 1_country, no_adult)</td>
#       <td>3211</td>
#       <td>20.163265</td>
#       <td>0.837725</td>
#       <td>1.746403</td>
#     </tr>
#     <tr>
#       <th>716</th>
#       <td>Reviews</td>
#       <td>((1.7910000000000001, 2.773]_votes, no_episodes, 1_country, no_adult)</td>
#       <td>2887</td>
#       <td>18.128728</td>
#       <td>0.833670</td>
#       <td>1.737950</td>
#     </tr>
#     <tr>
#       <th>656</th>
#       <td>(1.933, 24.33
# (58, 6)
